# %% [markdown]
# # PaddleHub实战——使用预训练模型进行多标签文本分类
#
# **百度试题知识点标注数据集**
# 本项目代码需要使用GPU环境来运行:
#
# 本项目将演示，如何使用PaddleHub语义预训练模型ERNIE对自定义数据集完成文本分类。
#
# 重要参考:
# - [PaddleHub 多标签分类](https://github.com/PaddlePaddle/PaddleHub/tree/release/v1.6/demo/multi_label_classification)
# - [paddle 多分类](https://aistudio.baidu.com/aistudio/projectdetail/221999)
# - [PaddleHub自定义数据集](https://github.com/PaddlePaddle/PaddleHub/wiki/PaddleHub%E9%80%82%E9%85%8D%E8%87%AA%E5%AE%9A%E4%B9%89%E6%95%B0%E6%8D%AE%E5%AE%8C%E6%88%90FineTune)

# %% [markdown]
# # 数据说明
# 原始数据集为`高中`下`地理`,`历史`,`生物`,`政治`四门学科数据，每个学科下各包含第一层知识点，如`历史`下分为`近代史`,`现代史`,`古代史`。
# 原始数据示例：
#
# > [题目]
# 我国经济体制改革首先在农村展开。率先实行包产到组、包产到户的农业生产责任制的省份是（    ）
# ①四川        ②广东        ③安徽       ④湖北A. ①③B. ①④C. ②④D. ②③题型: 单选题|难度: 简单|使用次数: 0|纠错复制收藏到空间加入选题篮查看答案解析答案：A解析：本题主要考察的是对知识的识记能力，比较容易。根据所学知识可知，在四川和安徽，率先实行包产到组、包产到户的农业生产责任制，故①③正确；②④不是。所以答案选A。知识点：
# [知识点：]
# 经济体制改革,中国的振兴
#
# 对数据处理：
# - 将数据的[知识点：]作为数据的第四层标签，显然不同数据的第四层标签数量不一致
# - 仅保留题目作为数据特征，删除[题型]及[答案解析]

# %% [markdown]
# # Step1: 加载预训练模型
# <p align="center">
# <img src="https://bj.bcebos.com/paddlehub/paddlehub-img/ernie_network_1.png" hspace='10'/> <br />
# </p>
#
#
# <p align="center">
# <img src="https://bj.bcebos.com/paddlehub/paddlehub-img/ernie_network_2.png" hspace='10'/> <br />
# </p>
#
# 很神奇，第二次及以后运行时要加入下面这两句话，是为了创建个文件夹。
# ```
# %cd /home/aistudio/
# !mkdir -p .paddlehub/cache
# ```
# 如果直接
# ``` python
# import paddlehub as hub
# module = hub.Module(name="ernie_tiny")
# ```
# 会报错
# ![](https://ai-studio-static-online.cdn.bcebos.com/9095d984e2474cbd8c1864e55eed4fefd6f110e0bc724b1ca240eb2b97f1b187)

# %%
# %cd /home/aistudio/
# !mkdir -p .paddlehub/cache
# Out:
# /home/aistudio

# %%
import paddlehub as hub
module = hub.Module(name="bert_wwm_chinese_L-12_H-768_A-12")
inputs, outputs, program = module.context(trainable=True, max_seq_len=256)
# Out:
# [2020-03-26 19:31:41,661] [    INFO] - Installing bert_wwm_chinese_L-12_H-768_A-12 module
# [2020-03-26 19:31:41,694] [    INFO] - Module bert_wwm_chinese_L-12_H-768_A-12 already installed in /home/aistudio/.paddlehub/modules/bert_wwm_chinese_L-12_H-768_A-12
# [2020-03-26 19:31:42,416] [    INFO] - Set maximum sequence length of input tensor to 256
# [2020-03-26 19:31:42,417] [    INFO] - The shape of input tensor[input_ids] set to [-1, 256, 1]
# [2020-03-26 19:31:42,417] [    INFO] - The shape of input tensor[position_ids] set to [-1, 256, 1]
# [2020-03-26 19:31:42,418] [    INFO] - The shape of input tensor[segment_ids] set to [-1, 256, 1]
# [2020-03-26 19:31:42,418] [    INFO] - The shape of input tensor[input_mask] set to [-1, 256, 1]
# [2020-03-26 19:31:42,419] [    INFO] - 199 pretrained paramaters loaded by PaddleHub

# %% [markdown]
# 其中最大序列长度`max_seq_len`是可以调整的参数，建议值128，根据任务文本长度不同可以调整该值，但最大不超过512。
#
# PaddleHub还提供BERT等模型可供选择, 模型对应的加载示例如下：
#
# | 模型名                         | PaddleHub Module                                             |
# | ------------------------------ | ------------------------------------------------------------ |
# | ERNIE, Chinese                 | `hub.Module(name='ernie')`                                   |
# | ERNIE tiny, Chinese            | `hub.Module(name='ernie_tiny')`                              |
# | ERNIE 2.0 Base, English        | `hub.Module(name='ernie_v2_eng_base')`                       |
# | ERNIE 2.0 Large, English       | `hub.Module(name='ernie_v2_eng_large')`                      |
# | BERT-Base, Uncased             | `hub.Module(name='bert_uncased_L-12_H-768_A-12')`            |
# | BERT-Large, Uncased            | `hub.Module(name='bert_uncased_L-24_H-1024_A-16')`           |
# | BERT-Base, Cased               | `hub.Module(name='bert_cased_L-12_H-768_A-12')`              |
# | BERT-Large, Cased              | `hub.Module(name='bert_cased_L-24_H-1024_A-16')`             |
# | BERT-Base, Multilingual Cased  | `hub.Module(nane='bert_multi_cased_L-12_H-768_A-12')`        |
# | BERT-Base, Chinese             | `hub.Module(name='bert_chinese_L-12_H-768_A-12')`            |
# | BERT-wwm, Chinese              | `hub.Module(name='bert_wwm_chinese_L-12_H-768_A-12')`        |
# | BERT-wwm-ext, Chinese          | `hub.Module(name='bert_wwm_ext_chinese_L-12_H-768_A-12')`    |
# | RoBERTa-wwm-ext, Chinese       | `hub.Module(name='roberta_wwm_ext_chinese_L-12_H-768_A-12')` |
# | RoBERTa-wwm-ext-large, Chinese | `hub.Module(name='roberta_wwm_ext_chinese_L-24_H-1024_A-16')` |
#
# 更多模型请参考[PaddleHub官网](https://www.paddlepaddle.org.cn/hub)。

# %% [markdown]
# # Step2: 准备数据集并使用MultiLabelClassifyReader读取数据
#
#
# 直接从之前处理的bert数据集拿过来。自己新建立一个数据预处理类即可。
#
# 其中数据集的准备代码可以参考paddle v1.6的[toxic.py](https://github.com/PaddlePaddle/PaddleHub/blob/release/v1.6/paddlehub/dataset/toxic.py)。
#
# 注意以后这个代码可能会过时，记得切换版本。
# ![](https://ai-studio-static-online.cdn.bcebos.com/7d32862be5e3444eb2e6b4d8fb9081e9f8c9cd06f4fc4190857515d6f2f8e996)
#
# 我参考的是paddle v1.2的[toxic.py](https://github.com/PaddlePaddle/PaddleHub/blob/release/v1.2/paddlehub/dataset/toxic.py)。
#
# 自定义数据集的处理参考 [自定义数据集](https://github.com/PaddlePaddle/PaddleHub/wiki/PaddleHub%E9%80%82%E9%85%8D%E8%87%AA%E5%AE%9A%E4%B9%89%E6%95%B0%E6%8D%AE%E5%AE%8C%E6%88%90FineTune)

# %%
import os
import pandas as pd
import paddlehub as hub
from paddlehub.dataset.dataset import InputExample, BaseDataset

class Baidu(BaseDataset):
    def __init__(self):
        self.dataset_dir = 'work'

        self.label_file = os.path.join(self.dataset_dir, "label.txt")
        self.label_list = [w.strip() for w in open(self.label_file).readlines()]
        self.label_map = {word:idx  for idx, word in enumerate(self.label_list)}

        self._load_train_examples()
        self._load_test_examples()
        self._load_dev_examples()

    # 我自己定义的一个函数
    def labels2index(self, labels, label_map):
        """
        :params: labels 是一串字符串，包含数个标签，标签由空格分开
        """
        index = [0] * len(label_map)
        for label in labels.split():
            index[label_map[label]] = 1
        return index

    def _load_train_examples(self):
        self.train_file = os.path.join(self.dataset_dir, "train.tsv")
        self.train_examples = self._read_csv(self.train_file)

    def _load_dev_examples(self):
        self.dev_file = os.path.join(self.dataset_dir, "dev.tsv")
        self.dev_examples = self._read_csv(self.dev_file)

    def _load_test_examples(self):
        self.test_file = os.path.join(self.dataset_dir, "test.tsv")
        self.test_examples = self._read_csv(self.test_file)

    def get_train_examples(self):
        return self.train_examples

    def get_dev_examples(self):
        return self.dev_examples

    def get_test_examples(self):
        return self.test_examples

    def get_labels(self):
        
        return self.label_list

    @property
    def num_labels(self):
        """
        Return the number of labels in the dataset.
        """
        return len(self.get_labels())

    def _read_csv(self, input_file, quotechar=None):
        """Reads a tab separated value file."""
        data = pd.read_csv(input_file, encoding="UTF-8", sep='\t')
        examples = []
        for index, row in data.iterrows():
            guid = index
            text = row["content"]
            labels = self.labels2index(row['label'], self.label_map)

            example = InputExample(guid=guid, label=labels, text_a=text)
            examples.append(example)

        return examples

# %% [markdown]
# [MultiLabelClassifyReader](https://github.com/PaddlePaddle/PaddleHub/blob/45179f3d06ed32ae60a4d8a573829b354548c4b5/paddlehub/reader/nlp_reader.py#L36)的参数：
# * `dataset`: 传入PaddleHub Dataset;
# * `vocab_path`: 传入ERNIE/BERT模型对应的词表文件路径;
# * `max_seq_len`: ERNIE模型的最大序列长度，若序列长度不足，会通过padding方式补到max_seq_len, 若序列长度大于该值，则会以截断方式让序列长度为max_seq_len;
# * `sp_model_path`: 传入 ERNIE tiny的subword切分模型路径;
# * `word_dict_path`: 传入 ERNIE tiny的词语切分模型路径;
#
# <center> <img width="600px" src="https://ai-studio-static-online.cdn.bcebos.com/c1a201c80acc46708cedc1c73614b0531b716c0299474859bf423ce0a5160170" /> </center>

# %%
dataset = Baidu()
reader = hub.reader.MultiLabelClassifyReader(
    dataset=dataset,
    vocab_path=module.get_vocab_path(),
    max_seq_len=256)
# Out:
# [2020-03-26 19:31:54,862] [    INFO] - Dataset label map = {'宇宙中的地球': 0, '地球运动的基本形式': 1, '地球的内部圈层结构及特点': 2, '社会主义是中国人民的历史性选择': 3, '减数分裂的概念': 4, '基因的分离规律的实质及应用': 5, '组成细胞的化合物': 6, '基因工程的概念': 7, '人体水盐平衡调节': 8, '拉马克的进化学说': 9, '地球的外部圈层结构及特点': 10, '人口增长与人口问题': 11, '生产活动与地域联系': 12, '复等位基因': 13, '液泡的结构和功能': 14, '人口与城市': 15, '兴奋在神经纤维上的传导': 16, '郡县制': 17, '第三产业的兴起和“新经济”的出现': 18, '太阳对地球的影响': 19, '区域可持续发展': 20, '基因工程的原理及技术': 21, '社会主义市场经济的伦理要求': 22, '地球运动的地理意义': 23, '皇帝制度': 24, '遗传与进化': 25, '生物科学与社会': 26, '中央官制——三公九卿制': 27, '避孕的原理和方法': 28, '激素调节': 29, '近代史': 30, '生物工程技术': 31, '内环境的稳态': 32, '细胞有丝分裂不同时期的特点': 33, '清末民主革命风潮': 34, '高尔基体的结构和功能': 35, '伴性遗传': 36, '文艺的春天': 37, '神经调节和体液调节的比较': 38, '海峡两岸关系的发展': 39, '科学思维常识': 40, '遗传的细胞基础': 41, '劳动就业与守法经营': 42, '古代史': 43, '政治': 44, '农业区位因素': 45, '选官、用官制度的变化': 46, '生活中的法律常识': 47, '人工授精、试管婴儿等生殖技术': 48, '生物性污染': 49, '培养基与无菌技术': 50, '遗传的分子基础': 51, '内质网的结构和功能': 52, '基因的自由组合规律的实质及应用': 53, '生态系统的营养结构': 54, '“重农抑商”政策': 55, '免疫系统的功能': 56, '生命活动离不开细胞': 57, '蛋白质的合成': 58, '稳态与环境': 59, '不完全显性': 60, '夏商两代的政治制度': 61, '走进细胞': 62, '中心体的结构和功能': 63, '细胞的多样性和统一性': 64, '胚胎移植': 65, '群落的结构': 66, '免疫系统的组成': 67, '生物技术在其他方面的应用': 68, '经济学常识': 69, '生物': 70, '组成细胞的化学元素': 71, '核糖体的结构和功能': 72, '器官移植': 73, '时事政治': 74, '分子与细胞': 75, '血糖平衡的调节': 76, '减数分裂与有丝分裂的比较': 77, '垄断组织的出现': 78, '细胞大小与物质运输的关系': 79, '生物技术实践': 80, '科学社会主义常识': 81, '人体的体温调节': 82, '历史': 83, '现代生物技术专题': 84, '兴奋在神经元之间的传递': 85, '人口迁移与人口流动': 86, '现代史': 87, '地球与地图': 88, '溶酶体的结构和功能': 89, '体液免疫的概念和过程': 90, '地球所处的宇宙环境': 91, '人体免疫系统在维持稳态中的作用': 92, '与细胞分裂有关的细胞器': 93, '公民道德与伦理常识': 94, '工业区位因素': 95, '地理': 96}

# %% [markdown]
# # Step3：选择优化策略和运行配置

# %%
strategy = hub.AdamWeightDecayStrategy(
    learning_rate=2e-5,
    weight_decay=0.01,
    warmup_proportion=0.0,
    lr_scheduler="linear_decay",
)

config = hub.RunConfig(use_cuda=True, 
                        use_data_parallel=True, 
                        use_pyreader=True, 
                        log_interval=200,
                        eval_interval=200,
                        num_epoch=5, 
                        batch_size=32, 
                        strategy=strategy)
# Out:
# [2020-03-26 19:32:06,783] [    INFO] - Checkpoint dir: ckpt_20200326193206

# %% [markdown]
# **优化策略**
#
# 针对ERNIE与BERT类任务，PaddleHub封装了适合这一任务的迁移学习优化策略`AdamWeightDecayStrategy`
#
# - `learning_rate`: Fine-tune过程中的最大学习率；
# - `weight_decay`: 模型的正则项参数，默认0.01，如果模型有过拟合倾向，可适当调高这一参数；
# - `warmup_proportion`: 如果warmup_proportion>0, 例如0.1, 则学习率会在前10%的steps中线性增长至最高值learning_rate；
# - `lr_scheduler`: 有两种策略可选(1) `linear_decay`策略学习率会在最高点后以线性方式衰减; `noam_decay`策略学习率会在最高点以多项式形式衰减；
#
# PaddleHub提供了许多优化策略，如`AdamWeightDecayStrategy`、`ULMFiTStrategy`、`DefaultFinetuneStrategy`等，详细信息参见[策略](https://github.com/PaddlePaddle/PaddleHub/wiki/PaddleHub-API:-Strategy)。
# <center> <img width="900px" src="https://ai-studio-static-online.cdn.bcebos.com/e7d3b9df642d443a8bdab1af0f3de93c0fa111ac5d3c4c9c88b2aa12f92dba64" /> </center>
#
# **运行配置**
#
# `RunConfig` 主要控制Fine-tune的训练，包含以下可控制的参数:
#
# - `log_interval`: 进度日志打印间隔，默认每10个step打印一次；
# - `eval_interval`: 模型评估的间隔，默认每100个step评估一次验证集；
# - `save_ckpt_interval`: 模型保存间隔，请根据任务大小配置，默认只保存验证集效果最好的模型和训练结束的模型；
# - `use_cuda`: 是否使用GPU训练，默认为False；
# - use_pyreader: 是否使用pyreader，默认False；
# - use_data_parallel: 是否使用并行计算，默认False。打开该功能依赖nccl库；
# - `checkpoint_dir`: 模型checkpoint保存路径, 若用户没有指定，程序会自动生成；
# - `num_epoch`: Fine-tune的轮数；
# - `batch_size`: 训练的批大小，如果使用GPU，请根据实际情况调整batch_size；
# - `enable_memory_optim`: 是否使用内存优化， 默认为True；
# - `strategy`: Fine-tune优化策略；

# %% [markdown]
# # Step4: 构建网络并创建分类迁移任务进行Fine-tune
#
# 有了合适的预训练模型和准备要迁移的数据集后，我们开始组建一个Task。
#
# 1. 获取module的上下文环境，包括输入和输出的变量，以及Paddle Program；
# 2. 从输出变量中找到用于情感分类的文本特征pooled_output；
# 3. 在pooled_output后面接入一个全连接层，生成Task；
#
# `TextClassifierTask`的参数有：
#
# > `data_reader`：读取数据的reader；
# >
# > `config`: 运行配置；
# >
# > `feature`：从预训练提取的特征；
# >
# > `feed_list`：program需要输入的变量；
# >
# > `num_classes`：数据集的类别数量；
# >
# > `metric_choic`：任务评估指标，默认为"acc"。metrics_choices支持训练过程中同时评估多个指标，作为最佳模型的判断依据，例如["matthews", "acc"]，"matthews"将作为主指标，为最佳模型的判断依据；
#
#
# <center> <img width="600px" src="https://user-images.githubusercontent.com/48793257/69508060-97c0c180-0f6f-11ea-9886-00300da42683.png" /> </center>

# %% [markdown]
# [MultiLabelClassifierTask源码](https://github.com/PaddlePaddle/PaddleHub/blob/45179f3d06ed32ae60a4d8a573829b354548c4b5/paddlehub/finetune/task/classifier_task.py)
#
# 默认的评估指标就是auc
# `metrics_choices="default"`

# %%
pooled_output = outputs["pooled_output"]

# feed_list的Tensor顺序不可以调整
feed_list = [
    inputs["input_ids"].name,
    inputs["position_ids"].name,
    inputs["segment_ids"].name,
    inputs["input_mask"].name,
]

cls_task = hub.MultiLabelClassifierTask(
    data_reader=reader,
    feature=pooled_output,
    feed_list=feed_list,
    num_classes=dataset.num_labels,
    config=config)

cls_task.finetune_and_eval()
# Out:
# 2020-03-26 19:32:13,357-WARNING: paddle.fluid.layers.py_reader() may be deprecated in the near future. Please use paddle.fluid.io.DataLoader.from_generator() instead.
# [2020-03-26 19:32:14,226] [    INFO] - Strategy with scheduler: {'warmup': 0.0, 'linear_decay': {'start_point': 0.0, 'end_learning_rate': 0}, 'noam_decay': False, 'discriminative': {'blocks': 0, 'factor': 2.6}, 'gradual_unfreeze': 0, 'slanted_triangle': {'cut_fraction': 0.0, 'ratio': 32}}, regularization: {'L2': 0.0, 'L2SP': 0.0, 'weight_decay': 0.01} and clip: {'GlobalNorm': 1.0, 'Norm': 0.0}
# [2020-03-26 19:38:35,221] [    INFO] - Try loading checkpoint from ckpt_20200326193206/ckpt.meta
# [2020-03-26 19:38:35,222] [    INFO] - PaddleHub model checkpoint not found, start from scratch...
# [2020-03-26 19:38:35,422] [    INFO] - PaddleHub finetune start
# [2020-03-26 19:41:14,034] [   TRAIN] - step 200 / 2981: loss=6.61374 auc=0.63222 auc_宇宙中的地球=0.79229 auc_地球运动的基本形式=0.64303 auc_地球的内部圈层结构及特点=0.53147 auc_社会主义是中国人民的历史性选择=0.55684 auc_减数分裂的概念=0.68863 auc_基因的分离规律的实质及应用=0.71043 auc_组成细胞的化合物=0.65224 auc_基因工程的概念=0.61323 auc_人体水盐平衡调节=0.53052 auc_拉马克的进化学说=0.54191 auc_地球的外部圈层结构及特点=0.53020 auc_人口增长与人口问题=0.50059 auc_生产活动与地域联系=0.53810 auc_复等位基因=0.61952 auc_液泡的结构和功能=0.72416 auc_人口与城市=0.51967 auc_兴奋在神经纤维上的传导=0.58905 auc_郡县制=0.65413 auc_第三产业的兴起和“新经济”的出现=0.57857 auc_太阳对地球的影响=0.56626 auc_区域可持续发展=0.42044 auc_基因工程的原理及技术=0.61689 auc_社会主义市场经济的伦理要求=0.65232 auc_地球运动的地理意义=0.62052 auc_皇帝制度=0.70307 auc_遗传与进化=0.67616 auc_生物科学与社会=0.84918 auc_中央官制——三公九卿制=0.66028 auc_避孕的原理和方法=0.89672 auc_激素调节=0.51249 auc_近代史=0.71694 auc_生物工程技术=0.55801 auc_内环境的稳态=0.73096 auc_细胞有丝分裂不同时期的特点=0.53154 auc_清末民主革命风潮=0.57255 auc_高尔基体的结构和功能=0.63204 auc_伴性遗传=0.67284 auc_文艺的春天=0.66777 auc_神经调节和体液调节的比较=0.52951 auc_海峡两岸关系的发展=0.58845 auc_科学思维常识=0.48560 auc_遗传的细胞基础=0.87736 auc_劳动就业与守法经营=0.65499 auc_古代史=0.66707 auc_政治=0.77216 auc_农业区位因素=0.41835 auc_选官、用官制度的变化=0.60243 auc_生活中的法律常识=0.46430 auc_人工授精、试管婴儿等生殖技术=0.88311 auc_生物性污染=0.92014 auc_培养基与无菌技术=0.67346 auc_遗传的分子基础=0.85353 auc_内质网的结构和功能=0.64111 auc_基因的自由组合规律的实质及应用=0.74892 auc_生态系统的营养结构=0.38495 auc_“重农抑商”政策=0.67827 auc_免疫系统的功能=0.66717 auc_生命活动离不开细胞=0.65238 auc_蛋白质的合成=0.57550 auc_稳态与环境=0.68410 auc_不完全显性=0.64923 auc_夏商两代的政治制度=0.66754 auc_走进细胞=0.64530 auc_中心体的结构和功能=0.68419 auc_细胞的多样性和统一性=0.57989 auc_胚胎移植=0.55457 auc_群落的结构=0.46351 auc_免疫系统的组成=0.68433 auc_生物技术在其他方面的应用=0.75266 auc_经济学常识=0.54104 auc_生物=0.93927 auc_组成细胞的化学元素=0.63650 auc_核糖体的结构和功能=0.70804 auc_器官移植=0.56784 auc_时事政治=0.54194 auc_分子与细胞=0.72040 auc_血糖平衡的调节=0.49341 auc_减数分裂与有丝分裂的比较=0.75447 auc_垄断组织的出现=0.53126 auc_细胞大小与物质运输的关系=0.45937 auc_生物技术实践=0.63836 auc_科学社会主义常识=0.58440 auc_人体的体温调节=0.43760 auc_历史=0.84074 auc_现代生物技术专题=0.64619 auc_兴奋在神经元之间的传递=0.55274 auc_人口迁移与人口流动=0.51045 auc_现代史=0.71421 auc_地球与地图=0.54056 auc_溶酶体的结构和功能=0.64238 auc_体液免疫的概念和过程=0.69190 auc_地球所处的宇宙环境=0.53066 auc_人体免疫系统在维持稳态中的作用=0.68289 auc_与细胞分裂有关的细胞器=0.62697 auc_公民道德与伦理常识=0.63646 auc_工业区位因素=0.42482 auc_地理=0.85523 [step/sec: 1.26]
# [2020-03-26 19:41:14,035] [    INFO] - Evaluation on dev dataset start
# 2020-03-26 19:41:17,139-WARNING: paddle.fluid.layers.py_reader() may be deprecated in the near future. Please use paddle.fluid.io.DataLoader.from_generator() instead.
# share_vars_from is set, scope is ignored.
# [2020-03-26 19:41:59,923] [    EVAL] - [dev dataset evaluation result] loss=3.14303 auc=0.73304 auc_宇宙中的地球=0.90549 auc_地球运动的基本形式=0.77099 auc_地球的内部圈层结构及特点=0.66078 auc_社会主义是中国人民的历史性选择=0.64645 auc_减数分裂的概念=0.76671 auc_基因的分离规律的实质及应用=0.81243 auc_组成细胞的化合物=0.81160 auc_基因工程的概念=0.76342 auc_人体水盐平衡调节=0.65264 auc_拉马克的进化学说=0.59010 auc_地球的外部圈层结构及特点=0.61264 auc_人口增长与人口问题=0.60330 auc_生产活动与地域联系=0.68049 auc_复等位基因=0.75717 auc_液泡的结构和功能=0.86415 auc_人口与城市=0.68292 auc_兴奋在神经纤维上的传导=0.71758 auc_郡县制=0.81317 auc_第三产业的兴起和“新经济”的出现=0.64128 auc_太阳对地球的影响=0.68412 auc_区域可持续发展=0.33712 auc_基因工程的原理及技术=0.75056 auc_社会主义市场经济的伦理要求=0.81518 auc_地球运动的地理意义=0.78065 auc_皇帝制度=0.86513 auc_遗传与进化=0.75289 auc_生物科学与社会=0.91218 auc_中央官制——三公九卿制=0.81239 auc_避孕的原理和方法=0.95772 auc_激素调节=0.52513 auc_近代史=0.82165 auc_生物工程技术=0.65098 auc_内环境的稳态=0.87316 auc_细胞有丝分裂不同时期的特点=0.58004 auc_清末民主革命风潮=0.65832 auc_高尔基体的结构和功能=0.78692 auc_伴性遗传=0.75784 auc_文艺的春天=0.75554 auc_神经调节和体液调节的比较=0.65801 auc_海峡两岸关系的发展=0.64698 auc_科学思维常识=0.39642 auc_遗传的细胞基础=0.94046 auc_劳动就业与守法经营=0.80916 auc_古代史=0.81779 auc_政治=0.90597 auc_农业区位因素=0.38702 auc_选官、用官制度的变化=0.71680 auc_生活中的法律常识=0.33167 auc_人工授精、试管婴儿等生殖技术=0.95256 auc_生物性污染=0.96700 auc_培养基与无菌技术=0.80944 auc_遗传的分子基础=0.92540 auc_内质网的结构和功能=0.80039 auc_基因的自由组合规律的实质及应用=0.83800 auc_生态系统的营养结构=0.43391 auc_“重农抑商”政策=0.84765 auc_免疫系统的功能=0.85257 auc_生命活动离不开细胞=0.75033 auc_蛋白质的合成=0.71897 auc_稳态与环境=0.83465 auc_不完全显性=0.74489 auc_夏商两代的政治制度=0.83493 auc_走进细胞=0.78561 auc_中心体的结构和功能=0.84227 auc_细胞的多样性和统一性=0.69915 auc_胚胎移植=0.57458 auc_群落的结构=0.45851 auc_免疫系统的组成=0.84578 auc_生物技术在其他方面的应用=0.87033 auc_经济学常识=0.54786 auc_生物=0.97920 auc_组成细胞的化学元素=0.79112 auc_核糖体的结构和功能=0.86069 auc_器官移植=0.63535 auc_时事政治=0.41309 auc_分子与细胞=0.84700 auc_血糖平衡的调节=0.64531 auc_减数分裂与有丝分裂的比较=0.85675 auc_垄断组织的出现=0.58685 auc_细胞大小与物质运输的关系=0.52694 auc_生物技术实践=0.78839 auc_科学社会主义常识=0.69606 auc_人体的体温调节=0.61028 auc_历史=0.93839 auc_现代生物技术专题=0.74394 auc_兴奋在神经元之间的传递=0.71845 auc_人口迁移与人口流动=0.49518 auc_现代史=0.82022 auc_地球与地图=0.63883 auc_溶酶体的结构和功能=0.80015 auc_体液免疫的概念和过程=0.84434 auc_地球所处的宇宙环境=0.64352 auc_人体免疫系统在维持稳态中的作用=0.84491 auc_与细胞分裂有关的细胞器=0.78617 auc_公民道德与伦理常识=0.79545 auc_工业区位因素=0.47464 auc_地理=0.94727 [step/sec: 3.58]
# [2020-03-26 19:41:59,924] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.73304]
# 2020-03-26 19:42:02,328-WARNING: paddle.fluid.layers.py_reader() may be deprecated in the near future. Please use paddle.fluid.io.DataLoader.from_generator() instead.
# [2020-03-26 19:44:40,735] [   TRAIN] - step 400 / 2981: loss=2.60838 auc=0.80430 auc_宇宙中的地球=0.95450 auc_地球运动的基本形式=0.83761 auc_地球的内部圈层结构及特点=0.77487 auc_社会主义是中国人民的历史性选择=0.72665 auc_减数分裂的概念=0.84571 auc_基因的分离规律的实质及应用=0.86828 auc_组成细胞的化合物=0.88685 auc_基因工程的概念=0.86225 auc_人体水盐平衡调节=0.71163 auc_拉马克的进化学说=0.63087 auc_地球的外部圈层结构及特点=0.72787 auc_人口增长与人口问题=0.71117 auc_生产活动与地域联系=0.80149 auc_复等位基因=0.86108 auc_液泡的结构和功能=0.92057 auc_人口与城市=0.80363 auc_兴奋在神经纤维上的传导=0.80638 auc_郡县制=0.90553 auc_第三产业的兴起和“新经济”的出现=0.73628 auc_太阳对地球的影响=0.78661 auc_区域可持续发展=0.35878 auc_基因工程的原理及技术=0.86108 auc_社会主义市场经济的伦理要求=0.89820 auc_地球运动的地理意义=0.87028 auc_皇帝制度=0.93599 auc_遗传与进化=0.81221 auc_生物科学与社会=0.93431 auc_中央官制——三公九卿制=0.90796 auc_避孕的原理和方法=0.97803 auc_激素调节=0.59667 auc_近代史=0.88373 auc_生物工程技术=0.77088 auc_内环境的稳态=0.92568 auc_细胞有丝分裂不同时期的特点=0.66164 auc_清末民主革命风潮=0.75121 auc_高尔基体的结构和功能=0.87556 auc_伴性遗传=0.81517 auc_文艺的春天=0.80909 auc_神经调节和体液调节的比较=0.77247 auc_海峡两岸关系的发展=0.73285 auc_科学思维常识=0.44061 auc_遗传的细胞基础=0.96347 auc_劳动就业与守法经营=0.88314 auc_古代史=0.90551 auc_政治=0.95533 auc_农业区位因素=0.48453 auc_选官、用官制度的变化=0.83206 auc_生活中的法律常识=0.31594 auc_人工授精、试管婴儿等生殖技术=0.97534 auc_生物性污染=0.98167 auc_培养基与无菌技术=0.87853 auc_遗传的分子基础=0.95787 auc_内质网的结构和功能=0.88178 auc_基因的自由组合规律的实质及应用=0.89370 auc_生态系统的营养结构=0.49223 auc_“重农抑商”政策=0.92723 auc_免疫系统的功能=0.91858 auc_生命活动离不开细胞=0.81681 auc_蛋白质的合成=0.82050 auc_稳态与环境=0.90952 auc_不完全显性=0.80018 auc_夏商两代的政治制度=0.92162 auc_走进细胞=0.84879 auc_中心体的结构和功能=0.90484 auc_细胞的多样性和统一性=0.78877 auc_胚胎移植=0.67105 auc_群落的结构=0.46029 auc_免疫系统的组成=0.91217 auc_生物技术在其他方面的应用=0.92552 auc_经济学常识=0.63896 auc_生物=0.99111 auc_组成细胞的化学元素=0.87396 auc_核糖体的结构和功能=0.91980 auc_器官移植=0.74569 auc_时事政治=0.39534 auc_分子与细胞=0.90198 auc_血糖平衡的调节=0.71311 auc_减数分裂与有丝分裂的比较=0.91453 auc_垄断组织的出现=0.69428 auc_细胞大小与物质运输的关系=0.61846 auc_生物技术实践=0.86987 auc_科学社会主义常识=0.78114 auc_人体的体温调节=0.71092 auc_历史=0.97210 auc_现代生物技术专题=0.82104 auc_兴奋在神经元之间的传递=0.82031 auc_人口迁移与人口流动=0.52634 auc_现代史=0.88834 auc_地球与地图=0.70111 auc_溶酶体的结构和功能=0.88358 auc_体液免疫的概念和过程=0.90690 auc_地球所处的宇宙环境=0.74033 auc_人体免疫系统在维持稳态中的作用=0.91046 auc_与细胞分裂有关的细胞器=0.87545 auc_公民道德与伦理常识=0.88700 auc_工业区位因素=0.55851 auc_地理=0.97694 [step/sec: 1.28]
# [2020-03-26 19:44:40,736] [    INFO] - Evaluation on dev dataset start
# [2020-03-26 19:45:21,726] [    EVAL] - [dev dataset evaluation result] loss=2.08778 auc=0.84040 auc_宇宙中的地球=0.96912 auc_地球运动的基本形式=0.86968 auc_地球的内部圈层结构及特点=0.84109 auc_社会主义是中国人民的历史性选择=0.76561 auc_减数分裂的概念=0.88244 auc_基因的分离规律的实质及应用=0.88460 auc_组成细胞的化合物=0.91518 auc_基因工程的概念=0.89868 auc_人体水盐平衡调节=0.77470 auc_拉马克的进化学说=0.64569 auc_地球的外部圈层结构及特点=0.80722 auc_人口增长与人口问题=0.78343 auc_生产活动与地域联系=0.85795 auc_复等位基因=0.89958 auc_液泡的结构和功能=0.94370 auc_人口与城市=0.86287 auc_兴奋在神经纤维上的传导=0.84951 auc_郡县制=0.93643 auc_第三产业的兴起和“新经济”的出现=0.78811 auc_太阳对地球的影响=0.83924 auc_区域可持续发展=0.37383 auc_基因工程的原理及技术=0.90189 auc_社会主义市场经济的伦理要求=0.92896 auc_地球运动的地理意义=0.90698 auc_皇帝制度=0.95706 auc_遗传与进化=0.82625 auc_生物科学与社会=0.94342 auc_中央官制——三公九卿制=0.93823 auc_避孕的原理和方法=0.98411 auc_激素调节=0.68055 auc_近代史=0.91163 auc_生物工程技术=0.83134 auc_内环境的稳态=0.94482 auc_细胞有丝分裂不同时期的特点=0.71832 auc_清末民主革命风潮=0.80632 auc_高尔基体的结构和功能=0.91320 auc_伴性遗传=0.83881 auc_文艺的春天=0.83374 auc_神经调节和体液调节的比较=0.81708 auc_海峡两岸关系的发展=0.77567 auc_科学思维常识=0.45560 auc_遗传的细胞基础=0.97074 auc_劳动就业与守法经营=0.91494 auc_古代史=0.93221 auc_政治=0.96758 auc_农业区位因素=0.59166 auc_选官、用官制度的变化=0.88015 auc_生活中的法律常识=0.35445 auc_人工授精、试管婴儿等生殖技术=0.98222 auc_生物性污染=0.98612 auc_培养基与无菌技术=0.91048 auc_遗传的分子基础=0.96735 auc_内质网的结构和功能=0.91602 auc_基因的自由组合规律的实质及应用=0.91282 auc_生态系统的营养结构=0.57885 auc_“重农抑商”政策=0.95160 auc_免疫系统的功能=0.94070 auc_生命活动离不开细胞=0.85630 auc_蛋白质的合成=0.86439 auc_稳态与环境=0.93636 auc_不完全显性=0.83275 auc_夏商两代的政治制度=0.94767 auc_走进细胞=0.87927 auc_中心体的结构和功能=0.93193 auc_细胞的多样性和统一性=0.84130 auc_胚胎移植=0.73881 auc_群落的结构=0.51392 auc_免疫系统的组成=0.93713 auc_生物技术在其他方面的应用=0.94717 auc_经济学常识=0.68380 auc_生物=0.99428 auc_组成细胞的化学元素=0.90565 auc_核糖体的结构和功能=0.94368 auc_器官移植=0.79338 auc_时事政治=0.38652 auc_分子与细胞=0.92601 auc_血糖平衡的调节=0.77545 auc_减数分裂与有丝分裂的比较=0.93502 auc_垄断组织的出现=0.75355 auc_细胞大小与物质运输的关系=0.67752 auc_生物技术实践=0.90549 auc_科学社会主义常识=0.82164 auc_人体的体温调节=0.76902 auc_历史=0.98190 auc_现代生物技术专题=0.85514 auc_兴奋在神经元之间的传递=0.86375 auc_人口迁移与人口流动=0.57888 auc_现代史=0.91002 auc_地球与地图=0.73816 auc_溶酶体的结构和功能=0.91951 auc_体液免疫的概念和过程=0.92955 auc_地球所处的宇宙环境=0.80168 auc_人体免疫系统在维持稳态中的作用=0.93453 auc_与细胞分裂有关的细胞器=0.91321 auc_公民道德与伦理常识=0.91674 auc_工业区位因素=0.63211 auc_地理=0.98522 [step/sec: 3.66]
# [2020-03-26 19:45:21,728] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.84040]
# [2020-03-26 19:48:02,156] [   TRAIN] - step 600 / 2981: loss=1.73615 auc=0.87219 auc_宇宙中的地球=0.97983 auc_地球运动的基本形式=0.89175 auc_地球的内部圈层结构及特点=0.88800 auc_社会主义是中国人民的历史性选择=0.82320 auc_减数分裂的概念=0.91550 auc_基因的分离规律的实质及应用=0.90540 auc_组成细胞的化合物=0.93324 auc_基因工程的概念=0.92617 auc_人体水盐平衡调节=0.81733 auc_拉马克的进化学说=0.67835 auc_地球的外部圈层结构及特点=0.86204 auc_人口增长与人口问题=0.83562 auc_生产活动与地域联系=0.89980 auc_复等位基因=0.92728 auc_液泡的结构和功能=0.95629 auc_人口与城市=0.90356 auc_兴奋在神经纤维上的传导=0.88427 auc_郡县制=0.95576 auc_第三产业的兴起和“新经济”的出现=0.83219 auc_太阳对地球的影响=0.88592 auc_区域可持续发展=0.41545 auc_基因工程的原理及技术=0.92992 auc_社会主义市场经济的伦理要求=0.94792 auc_地球运动的地理意义=0.93349 auc_皇帝制度=0.97041 auc_遗传与进化=0.84423 auc_生物科学与社会=0.95027 auc_中央官制——三公九卿制=0.95763 auc_避孕的原理和方法=0.98809 auc_激素调节=0.75459 auc_近代史=0.92896 auc_生物工程技术=0.87636 auc_内环境的稳态=0.95903 auc_细胞有丝分裂不同时期的特点=0.76436 auc_清末民主革命风潮=0.84452 auc_高尔基体的结构和功能=0.93601 auc_伴性遗传=0.86487 auc_文艺的春天=0.85799 auc_神经调节和体液调节的比较=0.86328 auc_海峡两岸关系的发展=0.81697 auc_科学思维常识=0.52343 auc_遗传的细胞基础=0.97631 auc_劳动就业与守法经营=0.93250 auc_古代史=0.94933 auc_政治=0.97781 auc_农业区位因素=0.69200 auc_选官、用官制度的变化=0.90667 auc_生活中的法律常识=0.42485 auc_人工授精、试管婴儿等生殖技术=0.98691 auc_生物性污染=0.98911 auc_培养基与无菌技术=0.93328 auc_遗传的分子基础=0.97516 auc_内质网的结构和功能=0.93714 auc_基因的自由组合规律的实质及应用=0.92895 auc_生态系统的营养结构=0.66512 auc_“重农抑商”政策=0.96619 auc_免疫系统的功能=0.95756 auc_生命活动离不开细胞=0.88436 auc_蛋白质的合成=0.89859 auc_稳态与环境=0.95378 auc_不完全显性=0.86447 auc_夏商两代的政治制度=0.96426 auc_走进细胞=0.90045 auc_中心体的结构和功能=0.94846 auc_细胞的多样性和统一性=0.87840 auc_胚胎移植=0.81115 auc_群落的结构=0.60817 auc_免疫系统的组成=0.95553 auc_生物技术在其他方面的应用=0.96153 auc_经济学常识=0.75943 auc_生物=0.99644 auc_组成细胞的化学元素=0.92747 auc_核糖体的结构和功能=0.95658 auc_器官移植=0.84016 auc_时事政治=0.40645 auc_分子与细胞=0.94292 auc_血糖平衡的调节=0.82050 auc_减数分裂与有丝分裂的比较=0.95240 auc_垄断组织的出现=0.80692 auc_细胞大小与物质运输的关系=0.72861 auc_生物技术实践=0.92534 auc_科学社会主义常识=0.86915 auc_人体的体温调节=0.80840 auc_历史=0.98802 auc_现代生物技术专题=0.88991 auc_兴奋在神经元之间的传递=0.89870 auc_人口迁移与人口流动=0.65946 auc_现代史=0.92751 auc_地球与地图=0.77666 auc_溶酶体的结构和功能=0.94053 auc_体液免疫的概念和过程=0.94815 auc_地球所处的宇宙环境=0.85400 auc_人体免疫系统在维持稳态中的作用=0.95295 auc_与细胞分裂有关的细胞器=0.93486 auc_公民道德与伦理常识=0.93800 auc_工业区位因素=0.70483 auc_地理=0.99029 [step/sec: 1.24]
# [2020-03-26 19:48:02,185] [    INFO] - Evaluation on dev dataset start
# [2020-03-26 19:48:43,711] [    EVAL] - [dev dataset evaluation result] loss=1.66105 auc=0.89016 auc_宇宙中的地球=0.98402 auc_地球运动的基本形式=0.90672 auc_地球的内部圈层结构及特点=0.91102 auc_社会主义是中国人民的历史性选择=0.85713 auc_减数分裂的概念=0.93045 auc_基因的分离规律的实质及应用=0.91854 auc_组成细胞的化合物=0.94344 auc_基因工程的概念=0.94152 auc_人体水盐平衡调节=0.84407 auc_拉马克的进化学说=0.70869 auc_地球的外部圈层结构及特点=0.88998 auc_人口增长与人口问题=0.86596 auc_生产活动与地域联系=0.92026 auc_复等位基因=0.94239 auc_液泡的结构和功能=0.96287 auc_人口与城市=0.92492 auc_兴奋在神经纤维上的传导=0.90638 auc_郡县制=0.96516 auc_第三产业的兴起和“新经济”的出现=0.85953 auc_太阳对地球的影响=0.90851 auc_区域可持续发展=0.45354 auc_基因工程的原理及技术=0.94370 auc_社会主义市场经济的伦理要求=0.95905 auc_地球运动的地理意义=0.94425 auc_皇帝制度=0.97649 auc_遗传与进化=0.85775 auc_生物科学与社会=0.95493 auc_中央官制——三公九卿制=0.96650 auc_避孕的原理和方法=0.99021 auc_激素调节=0.79468 auc_近代史=0.93840 auc_生物工程技术=0.90256 auc_内环境的稳态=0.96553 auc_细胞有丝分裂不同时期的特点=0.79475 auc_清末民主革命风潮=0.86926 auc_高尔基体的结构和功能=0.94606 auc_伴性遗传=0.87840 auc_文艺的春天=0.87498 auc_神经调节和体液调节的比较=0.88709 auc_海峡两岸关系的发展=0.83771 auc_科学思维常识=0.57746 auc_遗传的细胞基础=0.98090 auc_劳动就业与守法经营=0.94582 auc_古代史=0.95786 auc_政治=0.98254 auc_农业区位因素=0.75080 auc_选官、用官制度的变化=0.92574 auc_生活中的法律常识=0.46163 auc_人工授精、试管婴儿等生殖技术=0.98939 auc_生物性污染=0.99082 auc_培养基与无菌技术=0.94301 auc_遗传的分子基础=0.97965 auc_内质网的结构和功能=0.94726 auc_基因的自由组合规律的实质及应用=0.93845 auc_生态系统的营养结构=0.71853 auc_“重农抑商”政策=0.97346 auc_免疫系统的功能=0.96484 auc_生命活动离不开细胞=0.90224 auc_蛋白质的合成=0.91565 auc_稳态与环境=0.96229 auc_不完全显性=0.88198 auc_夏商两代的政治制度=0.97183 auc_走进细胞=0.91113 auc_中心体的结构和功能=0.95656 auc_细胞的多样性和统一性=0.89843 auc_胚胎移植=0.84631 auc_群落的结构=0.66362 auc_免疫系统的组成=0.96320 auc_生物技术在其他方面的应用=0.96764 auc_经济学常识=0.79701 auc_生物=0.99721 auc_组成细胞的化学元素=0.93935 auc_核糖体的结构和功能=0.96282 auc_器官移植=0.86674 auc_时事政治=0.40146 auc_分子与细胞=0.95279 auc_血糖平衡的调节=0.84804 auc_减数分裂与有丝分裂的比较=0.96110 auc_垄断组织的出现=0.84043 auc_细胞大小与物质运输的关系=0.75316 auc_生物技术实践=0.93783 auc_科学社会主义常识=0.89417 auc_人体的体温调节=0.83677 auc_历史=0.99095 auc_现代生物技术专题=0.90534 auc_兴奋在神经元之间的传递=0.91871 auc_人口迁移与人口流动=0.71397 auc_现代史=0.93500 auc_地球与地图=0.80622 auc_溶酶体的结构和功能=0.95074 auc_体液免疫的概念和过程=0.95719 auc_地球所处的宇宙环境=0.87993 auc_人体免疫系统在维持稳态中的作用=0.96100 auc_与细胞分裂有关的细胞器=0.94585 auc_公民道德与伦理常识=0.94954 auc_工业区位因素=0.75269 auc_地理=0.99277 [step/sec: 3.62]
# [2020-03-26 19:48:43,713] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.89016]
# [2020-03-26 19:51:22,437] [   TRAIN] - step 800 / 2981: loss=1.55105 auc=0.90787 auc_宇宙中的地球=0.98806 auc_地球运动的基本形式=0.92038 auc_地球的内部圈层结构及特点=0.92978 auc_社会主义是中国人民的历史性选择=0.89220 auc_减数分裂的概念=0.94462 auc_基因的分离规律的实质及应用=0.92920 auc_组成细胞的化合物=0.95095 auc_基因工程的概念=0.95345 auc_人体水盐平衡调节=0.86839 auc_拉马克的进化学说=0.73388 auc_地球的外部圈层结构及特点=0.91352 auc_人口增长与人口问题=0.89232 auc_生产活动与地域联系=0.93854 auc_复等位基因=0.95459 auc_液泡的结构和功能=0.96897 auc_人口与城市=0.94271 auc_兴奋在神经纤维上的传导=0.92363 auc_郡县制=0.97359 auc_第三产业的兴起和“新经济”的出现=0.88638 auc_太阳对地球的影响=0.93153 auc_区域可持续发展=0.50690 auc_基因工程的原理及技术=0.95585 auc_社会主义市场经济的伦理要求=0.96884 auc_地球运动的地理意义=0.95492 auc_皇帝制度=0.98208 auc_遗传与进化=0.87160 auc_生物科学与社会=0.95910 auc_中央官制——三公九卿制=0.97456 auc_避孕的原理和方法=0.99186 auc_激素调节=0.83779 auc_近代史=0.94519 auc_生物工程技术=0.92296 auc_内环境的稳态=0.97197 auc_细胞有丝分裂不同时期的特点=0.82554 auc_清末民主革命风潮=0.89306 auc_高尔基体的结构和功能=0.95642 auc_伴性遗传=0.89340 auc_文艺的春天=0.89183 auc_神经调节和体液调节的比较=0.90720 auc_海峡两岸关系的发展=0.86276 auc_科学思维常识=0.64168 auc_遗传的细胞基础=0.98407 auc_劳动就业与守法经营=0.95588 auc_古代史=0.96568 auc_政治=0.98722 auc_农业区位因素=0.80483 auc_选官、用官制度的变化=0.94207 auc_生活中的法律常识=0.51856 auc_人工授精、试管婴儿等生殖技术=0.99118 auc_生物性污染=0.99213 auc_培养基与无菌技术=0.95303 auc_遗传的分子基础=0.98291 auc_内质网的结构和功能=0.95732 auc_基因的自由组合规律的实质及应用=0.94607 auc_生态系统的营养结构=0.77039 auc_“重农抑商”政策=0.97993 auc_免疫系统的功能=0.97127 auc_生命活动离不开细胞=0.91744 auc_蛋白质的合成=0.93176 auc_稳态与环境=0.97018 auc_不完全显性=0.89836 auc_夏商两代的政治制度=0.97892 auc_走进细胞=0.92536 auc_中心体的结构和功能=0.96439 auc_细胞的多样性和统一性=0.91284 auc_胚胎移植=0.87788 auc_群落的结构=0.73236 auc_免疫系统的组成=0.97065 auc_生物技术在其他方面的应用=0.97403 auc_经济学常识=0.83358 auc_生物=0.99800 auc_组成细胞的化学元素=0.94834 auc_核糖体的结构和功能=0.96877 auc_器官移植=0.89049 auc_时事政治=0.41302 auc_分子与细胞=0.96142 auc_血糖平衡的调节=0.87354 auc_减数分裂与有丝分裂的比较=0.96826 auc_垄断组织的出现=0.87058 auc_细胞大小与物质运输的关系=0.78648 auc_生物技术实践=0.94716 auc_科学社会主义常识=0.91921 auc_人体的体温调节=0.86234 auc_历史=0.99327 auc_现代生物技术专题=0.91962 auc_兴奋在神经元之间的传递=0.93494 auc_人口迁移与人口流动=0.77567 auc_现代史=0.94368 auc_地球与地图=0.83880 auc_溶酶体的结构和功能=0.95998 auc_体液免疫的概念和过程=0.96530 auc_地球所处的宇宙环境=0.90759 auc_人体免疫系统在维持稳态中的作用=0.96849 auc_与细胞分裂有关的细胞器=0.95636 auc_公民道德与伦理常识=0.96044 auc_工业区位因素=0.79431 auc_地理=0.99476 [step/sec: 1.29]
# [2020-03-26 19:51:22,438] [    INFO] - Evaluation on dev dataset start
# [2020-03-26 19:52:03,225] [    EVAL] - [dev dataset evaluation result] loss=1.42596 auc=0.91791 auc_宇宙中的地球=0.98986 auc_地球运动的基本形式=0.92949 auc_地球的内部圈层结构及特点=0.94095 auc_社会主义是中国人民的历史性选择=0.90945 auc_减数分裂的概念=0.95181 auc_基因的分离规律的实质及应用=0.93580 auc_组成细胞的化合物=0.95610 auc_基因工程的概念=0.96006 auc_人体水盐平衡调节=0.88255 auc_拉马克的进化学说=0.75589 auc_地球的外部圈层结构及特点=0.92718 auc_人口增长与人口问题=0.90811 auc_生产活动与地域联系=0.94761 auc_复等位基因=0.96120 auc_液泡的结构和功能=0.97170 auc_人口与城市=0.95255 auc_兴奋在神经纤维上的传导=0.93369 auc_郡县制=0.97552 auc_第三产业的兴起和“新经济”的出现=0.90498 auc_太阳对地球的影响=0.94266 auc_区域可持续发展=0.54489 auc_基因工程的原理及技术=0.96192 auc_社会主义市场经济的伦理要求=0.97375 auc_地球运动的地理意义=0.96004 auc_皇帝制度=0.98272 auc_遗传与进化=0.88028 auc_生物科学与社会=0.96054 auc_中央官制——三公九卿制=0.97628 auc_避孕的原理和方法=0.99237 auc_激素调节=0.85961 auc_近代史=0.95023 auc_生物工程技术=0.93513 auc_内环境的稳态=0.97468 auc_细胞有丝分裂不同时期的特点=0.84722 auc_清末民主革命风潮=0.90790 auc_高尔基体的结构和功能=0.96122 auc_伴性遗传=0.90139 auc_文艺的春天=0.90328 auc_神经调节和体液调节的比较=0.91849 auc_海峡两岸关系的发展=0.87619 auc_科学思维常识=0.68471 auc_遗传的细胞基础=0.98594 auc_劳动就业与守法经营=0.96234 auc_古代史=0.96598 auc_政治=0.98917 auc_农业区位因素=0.83240 auc_选官、用官制度的变化=0.94924 auc_生活中的法律常识=0.56963 auc_人工授精、试管婴儿等生殖技术=0.99183 auc_生物性污染=0.99257 auc_培养基与无菌技术=0.95847 auc_遗传的分子基础=0.98477 auc_内质网的结构和功能=0.96180 auc_基因的自由组合规律的实质及应用=0.95057 auc_生态系统的营养结构=0.80056 auc_“重农抑商”政策=0.98074 auc_免疫系统的功能=0.97459 auc_生命活动离不开细胞=0.92675 auc_蛋白质的合成=0.93931 auc_稳态与环境=0.97363 auc_不完全显性=0.90806 auc_夏商两代的政治制度=0.98076 auc_走进细胞=0.93149 auc_中心体的结构和功能=0.96757 auc_细胞的多样性和统一性=0.92339 auc_胚胎移植=0.89661 auc_群落的结构=0.76687 auc_免疫系统的组成=0.97407 auc_生物技术在其他方面的应用=0.97702 auc_经济学常识=0.85533 auc_生物=0.99831 auc_组成细胞的化学元素=0.95399 auc_核糖体的结构和功能=0.97168 auc_器官移植=0.90540 auc_时事政治=0.41615 auc_分子与细胞=0.96477 auc_血糖平衡的调节=0.88668 auc_减数分裂与有丝分裂的比较=0.97193 auc_垄断组织的出现=0.89117 auc_细胞大小与物质运输的关系=0.80708 auc_生物技术实践=0.95266 auc_科学社会主义常识=0.93127 auc_人体的体温调节=0.87515 auc_历史=0.99450 auc_现代生物技术专题=0.92538 auc_兴奋在神经元之间的传递=0.94438 auc_人口迁移与人口流动=0.80748 auc_现代史=0.94748 auc_地球与地图=0.85819 auc_溶酶体的结构和功能=0.96412 auc_体液免疫的概念和过程=0.96948 auc_地球所处的宇宙环境=0.92146 auc_人体免疫系统在维持稳态中的作用=0.97220 auc_与细胞分裂有关的细胞器=0.96163 auc_公民道德与伦理常识=0.96564 auc_工业区位因素=0.82197 auc_地理=0.99576 [step/sec: 3.68]
# [2020-03-26 19:52:03,227] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.91791]
# [2020-03-26 19:54:42,157] [   TRAIN] - step 1000 / 2981: loss=1.33983 auc=0.92880 auc_宇宙中的地球=0.99197 auc_地球运动的基本形式=0.93892 auc_地球的内部圈层结构及特点=0.95402 auc_社会主义是中国人民的历史性选择=0.92562 auc_减数分裂的概念=0.95894 auc_基因的分离规律的实质及应用=0.94122 auc_组成细胞的化合物=0.96165 auc_基因工程的概念=0.96680 auc_人体水盐平衡调节=0.90153 auc_拉马克的进化学说=0.78143 auc_地球的外部圈层结构及特点=0.94256 auc_人口增长与人口问题=0.92205 auc_生产活动与地域联系=0.95648 auc_复等位基因=0.96687 auc_液泡的结构和功能=0.97540 auc_人口与城市=0.96127 auc_兴奋在神经纤维上的传导=0.94370 auc_郡县制=0.97960 auc_第三产业的兴起和“新经济”的出现=0.92087 auc_太阳对地球的影响=0.95351 auc_区域可持续发展=0.58066 auc_基因工程的原理及技术=0.96832 auc_社会主义市场经济的伦理要求=0.97782 auc_地球运动的地理意义=0.96633 auc_皇帝制度=0.98545 auc_遗传与进化=0.88696 auc_生物科学与社会=0.96207 auc_中央官制——三公九卿制=0.98050 auc_避孕的原理和方法=0.99340 auc_激素调节=0.88558 auc_近代史=0.95454 auc_生物工程技术=0.94593 auc_内环境的稳态=0.97796 auc_细胞有丝分裂不同时期的特点=0.86619 auc_清末民主革命风潮=0.92227 auc_高尔基体的结构和功能=0.96673 auc_伴性遗传=0.90902 auc_文艺的春天=0.91722 auc_神经调节和体液调节的比较=0.93115 auc_海峡两岸关系的发展=0.89374 auc_科学思维常识=0.73333 auc_遗传的细胞基础=0.98730 auc_劳动就业与守法经营=0.96710 auc_古代史=0.97036 auc_政治=0.99101 auc_农业区位因素=0.85989 auc_选官、用官制度的变化=0.95531 auc_生活中的法律常识=0.62627 auc_人工授精、试管婴儿等生殖技术=0.99297 auc_生物性污染=0.99346 auc_培养基与无菌技术=0.96406 auc_遗传的分子基础=0.98645 auc_内质网的结构和功能=0.96746 auc_基因的自由组合规律的实质及应用=0.95646 auc_生态系统的营养结构=0.83401 auc_“重农抑商”政策=0.98374 auc_免疫系统的功能=0.97815 auc_生命活动离不开细胞=0.93433 auc_蛋白质的合成=0.94896 auc_稳态与环境=0.97728 auc_不完全显性=0.92097 auc_夏商两代的政治制度=0.98399 auc_走进细胞=0.93914 auc_中心体的结构和功能=0.97179 auc_细胞的多样性和统一性=0.93548 auc_胚胎移植=0.91395 auc_群落的结构=0.80276 auc_免疫系统的组成=0.97773 auc_生物技术在其他方面的应用=0.98037 auc_经济学常识=0.87811 auc_生物=0.99868 auc_组成细胞的化学元素=0.95990 auc_核糖体的结构和功能=0.97552 auc_器官移植=0.91965 auc_时事政治=0.43051 auc_分子与细胞=0.96918 auc_血糖平衡的调节=0.90468 auc_减数分裂与有丝分裂的比较=0.97610 auc_垄断组织的出现=0.90928 auc_细胞大小与物质运输的关系=0.82948 auc_生物技术实践=0.95675 auc_科学社会主义常识=0.94388 auc_人体的体温调节=0.89409 auc_历史=0.99557 auc_现代生物技术专题=0.93373 auc_兴奋在神经元之间的传递=0.95305 auc_人口迁移与人口流动=0.83859 auc_现代史=0.95295 auc_地球与地图=0.88009 auc_溶酶体的结构和功能=0.96903 auc_体液免疫的概念和过程=0.97415 auc_地球所处的宇宙环境=0.93656 auc_人体免疫系统在维持稳态中的作用=0.97624 auc_与细胞分裂有关的细胞器=0.96660 auc_公民道德与伦理常识=0.97058 auc_工业区位因素=0.85333 auc_地理=0.99669 [step/sec: 1.29]
# [2020-03-26 19:54:42,158] [    INFO] - Evaluation on dev dataset start
# [2020-03-26 19:55:22,793] [    EVAL] - [dev dataset evaluation result] loss=1.20603 auc=0.93517 auc_宇宙中的地球=0.99280 auc_地球运动的基本形式=0.94419 auc_地球的内部圈层结构及特点=0.95923 auc_社会主义是中国人民的历史性选择=0.93595 auc_减数分裂的概念=0.96267 auc_基因的分离规律的实质及应用=0.94548 auc_组成细胞的化合物=0.96484 auc_基因工程的概念=0.97072 auc_人体水盐平衡调节=0.91130 auc_拉马克的进化学说=0.79985 auc_地球的外部圈层结构及特点=0.94957 auc_人口增长与人口问题=0.93144 auc_生产活动与地域联系=0.96107 auc_复等位基因=0.97091 auc_液泡的结构和功能=0.97755 auc_人口与城市=0.96670 auc_兴奋在神经纤维上的传导=0.94933 auc_郡县制=0.98106 auc_第三产业的兴起和“新经济”的出现=0.93167 auc_太阳对地球的影响=0.95971 auc_区域可持续发展=0.61012 auc_基因工程的原理及技术=0.97204 auc_社会主义市场经济的伦理要求=0.98058 auc_地球运动的地理意义=0.96914 auc_皇帝制度=0.98606 auc_遗传与进化=0.89333 auc_生物科学与社会=0.96404 auc_中央官制——三公九卿制=0.98162 auc_避孕的原理和方法=0.99404 auc_激素调节=0.89877 auc_近代史=0.95760 auc_生物工程技术=0.95284 auc_内环境的稳态=0.97930 auc_细胞有丝分裂不同时期的特点=0.87629 auc_清末民主革命风潮=0.93122 auc_高尔基体的结构和功能=0.97010 auc_伴性遗传=0.91446 auc_文艺的春天=0.92621 auc_神经调节和体液调节的比较=0.93723 auc_海峡两岸关系的发展=0.90409 auc_科学思维常识=0.76115 auc_遗传的细胞基础=0.98864 auc_劳动就业与守法经营=0.97082 auc_古代史=0.97227 auc_政治=0.99214 auc_农业区位因素=0.87306 auc_选官、用官制度的变化=0.95976 auc_生活中的法律常识=0.66687 auc_人工授精、试管婴儿等生殖技术=0.99369 auc_生物性污染=0.99406 auc_培养基与无菌技术=0.96756 auc_遗传的分子基础=0.98772 auc_内质网的结构和功能=0.97038 auc_基因的自由组合规律的实质及应用=0.95927 auc_生态系统的营养结构=0.85087 auc_“重农抑商”政策=0.98466 auc_免疫系统的功能=0.97950 auc_生命活动离不开细胞=0.93952 auc_蛋白质的合成=0.95299 auc_稳态与环境=0.97903 auc_不完全显性=0.92764 auc_夏商两代的政治制度=0.98492 auc_走进细胞=0.94425 auc_中心体的结构和功能=0.97437 auc_细胞的多样性和统一性=0.94122 auc_胚胎移植=0.92461 auc_群落的结构=0.82537 auc_免疫系统的组成=0.97897 auc_生物技术在其他方面的应用=0.98236 auc_经济学常识=0.89181 auc_生物=0.99885 auc_组成细胞的化学元素=0.96335 auc_核糖体的结构和功能=0.97766 auc_器官移植=0.92889 auc_时事政治=0.43833 auc_分子与细胞=0.97185 auc_血糖平衡的调节=0.91375 auc_减数分裂与有丝分裂的比较=0.97818 auc_垄断组织的出现=0.92183 auc_细胞大小与物质运输的关系=0.84263 auc_生物技术实践=0.96003 auc_科学社会主义常识=0.95069 auc_人体的体温调节=0.90393 auc_历史=0.99618 auc_现代生物技术专题=0.93731 auc_兴奋在神经元之间的传递=0.95824 auc_人口迁移与人口流动=0.85738 auc_现代史=0.95568 auc_地球与地图=0.89333 auc_溶酶体的结构和功能=0.97205 auc_体液免疫的概念和过程=0.97547 auc_地球所处的宇宙环境=0.94421 auc_人体免疫系统在维持稳态中的作用=0.97748 auc_与细胞分裂有关的细胞器=0.96934 auc_公民道德与伦理常识=0.97398 auc_工业区位因素=0.86880 auc_地理=0.99719 [step/sec: 3.69]
# [2020-03-26 19:55:22,794] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.93517]
# [2020-03-26 19:58:02,000] [   TRAIN] - step 1200 / 2981: loss=1.01829 auc=0.94220 auc_宇宙中的地球=0.99374 auc_地球运动的基本形式=0.94908 auc_地球的内部圈层结构及特点=0.96713 auc_社会主义是中国人民的历史性选择=0.94693 auc_减数分裂的概念=0.96601 auc_基因的分离规律的实质及应用=0.94823 auc_组成细胞的化合物=0.96737 auc_基因工程的概念=0.97491 auc_人体水盐平衡调节=0.92002 auc_拉马克的进化学说=0.81731 auc_地球的外部圈层结构及特点=0.95899 auc_人口增长与人口问题=0.94112 auc_生产活动与地域联系=0.96683 auc_复等位基因=0.97491 auc_液泡的结构和功能=0.97931 auc_人口与城市=0.97212 auc_兴奋在神经纤维上的传导=0.95543 auc_郡县制=0.98418 auc_第三产业的兴起和“新经济”的出现=0.94219 auc_太阳对地球的影响=0.96665 auc_区域可持续发展=0.63213 auc_基因工程的原理及技术=0.97566 auc_社会主义市场经济的伦理要求=0.98335 auc_地球运动的地理意义=0.97309 auc_皇帝制度=0.98832 auc_遗传与进化=0.89898 auc_生物科学与社会=0.96588 auc_中央官制——三公九卿制=0.98463 auc_避孕的原理和方法=0.99453 auc_激素调节=0.91405 auc_近代史=0.96064 auc_生物工程技术=0.95859 auc_内环境的稳态=0.98210 auc_细胞有丝分裂不同时期的特点=0.88886 auc_清末民主革命风潮=0.93952 auc_高尔基体的结构和功能=0.97276 auc_伴性遗传=0.92038 auc_文艺的春天=0.93583 auc_神经调节和体液调节的比较=0.94512 auc_海峡两岸关系的发展=0.91787 auc_科学思维常识=0.79348 auc_遗传的细胞基础=0.98960 auc_劳动就业与守法经营=0.97425 auc_古代史=0.97483 auc_政治=0.99345 auc_农业区位因素=0.89292 auc_选官、用官制度的变化=0.96552 auc_生活中的法律常识=0.71255 auc_人工授精、试管婴儿等生殖技术=0.99423 auc_生物性污染=0.99451 auc_培养基与无菌技术=0.97161 auc_遗传的分子基础=0.98881 auc_内质网的结构和功能=0.97315 auc_基因的自由组合规律的实质及应用=0.96164 auc_生态系统的营养结构=0.87384 auc_“重农抑商”政策=0.98716 auc_免疫系统的功能=0.98249 auc_生命活动离不开细胞=0.94448 auc_蛋白质的合成=0.95867 auc_稳态与环境=0.98150 auc_不完全显性=0.93585 auc_夏商两代的政治制度=0.98731 auc_走进细胞=0.94759 auc_中心体的结构和功能=0.97658 auc_细胞的多样性和统一性=0.94815 auc_胚胎移植=0.93457 auc_群落的结构=0.84918 auc_免疫系统的组成=0.98209 auc_生物技术在其他方面的应用=0.98433 auc_经济学常识=0.90522 auc_生物=0.99904 auc_组成细胞的化学元素=0.96605 auc_核糖体的结构和功能=0.97950 auc_器官移植=0.93740 auc_时事政治=0.45184 auc_分子与细胞=0.97436 auc_血糖平衡的调节=0.92255 auc_减数分裂与有丝分裂的比较=0.98010 auc_垄断组织的出现=0.93383 auc_细胞大小与物质运输的关系=0.85997 auc_生物技术实践=0.96216 auc_科学社会主义常识=0.95832 auc_人体的体温调节=0.91391 auc_历史=0.99687 auc_现代生物技术专题=0.94309 auc_兴奋在神经元之间的传递=0.96360 auc_人口迁移与人口流动=0.87807 auc_现代史=0.95900 auc_地球与地图=0.90721 auc_溶酶体的结构和功能=0.97480 auc_体液免疫的概念和过程=0.97910 auc_地球所处的宇宙环境=0.95314 auc_人体免疫系统在维持稳态中的作用=0.98077 auc_与细胞分裂有关的细胞器=0.97265 auc_公民道德与伦理常识=0.97737 auc_工业区位因素=0.88639 auc_地理=0.99771 [step/sec: 1.25]
# [2020-03-26 19:58:02,001] [    INFO] - Evaluation on dev dataset start
# [2020-03-26 19:58:42,851] [    EVAL] - [dev dataset evaluation result] loss=1.09653 auc=0.94663 auc_宇宙中的地球=0.99429 auc_地球运动的基本形式=0.95333 auc_地球的内部圈层结构及特点=0.97056 auc_社会主义是中国人民的历史性选择=0.95292 auc_减数分裂的概念=0.96827 auc_基因的分离规律的实质及应用=0.95109 auc_组成细胞的化合物=0.96943 auc_基因工程的概念=0.97724 auc_人体水盐平衡调节=0.92704 auc_拉马克的进化学说=0.83089 auc_地球的外部圈层结构及特点=0.96373 auc_人口增长与人口问题=0.94732 auc_生产活动与地域联系=0.97003 auc_复等位基因=0.97740 auc_液泡的结构和功能=0.98083 auc_人口与城市=0.97533 auc_兴奋在神经纤维上的传导=0.95885 auc_郡县制=0.98526 auc_第三产业的兴起和“新经济”的出现=0.94886 auc_太阳对地球的影响=0.97018 auc_区域可持续发展=0.65282 auc_基因工程的原理及技术=0.97795 auc_社会主义市场经济的伦理要求=0.98496 auc_地球运动的地理意义=0.97465 auc_皇帝制度=0.98887 auc_遗传与进化=0.90394 auc_生物科学与社会=0.96713 auc_中央官制——三公九卿制=0.98551 auc_避孕的原理和方法=0.99492 auc_激素调节=0.92260 auc_近代史=0.96285 auc_生物工程技术=0.96281 auc_内环境的稳态=0.98303 auc_细胞有丝分裂不同时期的特点=0.89611 auc_清末民主革命风潮=0.94514 auc_高尔基体的结构和功能=0.97515 auc_伴性遗传=0.92451 auc_文艺的春天=0.94241 auc_神经调节和体液调节的比较=0.94874 auc_海峡两岸关系的发展=0.92464 auc_科学思维常识=0.81434 auc_遗传的细胞基础=0.99040 auc_劳动就业与守法经营=0.97679 auc_古代史=0.97644 auc_政治=0.99415 auc_农业区位因素=0.90229 auc_选官、用官制度的变化=0.96873 auc_生活中的法律常识=0.74199 auc_人工授精、试管婴儿等生殖技术=0.99466 auc_生物性污染=0.99487 auc_培养基与无菌技术=0.97366 auc_遗传的分子基础=0.98959 auc_内质网的结构和功能=0.97524 auc_基因的自由组合规律的实质及应用=0.96381 auc_生态系统的营养结构=0.88459 auc_“重农抑商”政策=0.98801 auc_免疫系统的功能=0.98333 auc_生命活动离不开细胞=0.94807 auc_蛋白质的合成=0.96093 auc_稳态与环境=0.98269 auc_不完全显性=0.94132 auc_夏商两代的政治制度=0.98807 auc_走进细胞=0.95108 auc_中心体的结构和功能=0.97837 auc_细胞的多样性和统一性=0.95264 auc_胚胎移植=0.94132 auc_群落的结构=0.86321 auc_免疫系统的组成=0.98303 auc_生物技术在其他方面的应用=0.98553 auc_经济学常识=0.91495 auc_生物=0.99914 auc_组成细胞的化学元素=0.96822 auc_核糖体的结构和功能=0.98114 auc_器官移植=0.94326 auc_时事政治=0.47003 auc_分子与细胞=0.97619 auc_血糖平衡的调节=0.92942 auc_减数分裂与有丝分裂的比较=0.98142 auc_垄断组织的出现=0.94171 auc_细胞大小与物质运输的关系=0.86884 auc_生物技术实践=0.96418 auc_科学社会主义常识=0.96259 auc_人体的体温调节=0.92103 auc_历史=0.99722 auc_现代生物技术专题=0.94557 auc_兴奋在神经元之间的传递=0.96656 auc_人口迁移与人口流动=0.88976 auc_现代史=0.96067 auc_地球与地图=0.91532 auc_溶酶体的结构和功能=0.97682 auc_体液免疫的概念和过程=0.98010 auc_地球所处的宇宙环境=0.95789 auc_人体免疫系统在维持稳态中的作用=0.98175 auc_与细胞分裂有关的细胞器=0.97457 auc_公民道德与伦理常识=0.97940 auc_工业区位因素=0.89663 auc_地理=0.99801 [step/sec: 3.67]
# [2020-03-26 19:58:42,853] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.94663]
# [2020-03-26 20:01:21,904] [   TRAIN] - step 1400 / 2981: loss=1.03597 auc=0.95176 auc_宇宙中的地球=0.99503 auc_地球运动的基本形式=0.95777 auc_地球的内部圈层结构及特点=0.97449 auc_社会主义是中国人民的历史性选择=0.96013 auc_减数分裂的概念=0.97114 auc_基因的分离规律的实质及应用=0.95285 auc_组成细胞的化合物=0.97202 auc_基因工程的概念=0.97998 auc_人体水盐平衡调节=0.93332 auc_拉马克的进化学说=0.84265 auc_地球的外部圈层结构及特点=0.96871 auc_人口增长与人口问题=0.95341 auc_生产活动与地域联系=0.97365 auc_复等位基因=0.97995 auc_液泡的结构和功能=0.98296 auc_人口与城市=0.97879 auc_兴奋在神经纤维上的传导=0.96312 auc_郡县制=0.98746 auc_第三产业的兴起和“新经济”的出现=0.95536 auc_太阳对地球的影响=0.97473 auc_区域可持续发展=0.67756 auc_基因工程的原理及技术=0.98059 auc_社会主义市场经济的伦理要求=0.98671 auc_地球运动的地理意义=0.97737 auc_皇帝制度=0.99048 auc_遗传与进化=0.90933 auc_生物科学与社会=0.96867 auc_中央官制——三公九卿制=0.98768 auc_避孕的原理和方法=0.99525 auc_激素调节=0.93335 auc_近代史=0.96491 auc_生物工程技术=0.96700 auc_内环境的稳态=0.98453 auc_细胞有丝分裂不同时期的特点=0.90582 auc_清末民主革命风潮=0.95200 auc_高尔基体的结构和功能=0.97817 auc_伴性遗传=0.92910 auc_文艺的春天=0.94905 auc_神经调节和体液调节的比较=0.95468 auc_海峡两岸关系的发展=0.93443 auc_科学思维常识=0.83673 auc_遗传的细胞基础=0.99111 auc_劳动就业与守法经营=0.97857 auc_古代史=0.97856 auc_政治=0.99496 auc_农业区位因素=0.91554 auc_选官、用官制度的变化=0.97171 auc_生活中的法律常识=0.77079 auc_人工授精、试管婴儿等生殖技术=0.99506 auc_生物性污染=0.99522 auc_培养基与无菌技术=0.97644 auc_遗传的分子基础=0.99028 auc_内质网的结构和功能=0.97824 auc_基因的自由组合规律的实质及应用=0.96566 auc_生态系统的营养结构=0.89932 auc_“重农抑商”政策=0.98974 auc_免疫系统的功能=0.98500 auc_生命活动离不开细胞=0.95116 auc_蛋白质的合成=0.96538 auc_稳态与环境=0.98416 auc_不完全显性=0.94742 auc_夏商两代的政治制度=0.98983 auc_走进细胞=0.95574 auc_中心体的结构和功能=0.98069 auc_细胞的多样性和统一性=0.95600 auc_胚胎移植=0.94885 auc_群落的结构=0.87803 auc_免疫系统的组成=0.98473 auc_生物技术在其他方面的应用=0.98708 auc_经济学常识=0.92550 auc_生物=0.99927 auc_组成细胞的化学元素=0.97094 auc_核糖体的结构和功能=0.98329 auc_器官移植=0.94992 auc_时事政治=0.49147 auc_分子与细胞=0.97824 auc_血糖平衡的调节=0.93544 auc_减数分裂与有丝分裂的比较=0.98290 auc_垄断组织的出现=0.94922 auc_细胞大小与物质运输的关系=0.88210 auc_生物技术实践=0.96630 auc_科学社会主义常识=0.96804 auc_人体的体温调节=0.92722 auc_历史=0.99765 auc_现代生物技术专题=0.94955 auc_兴奋在神经元之间的传递=0.97009 auc_人口迁移与人口流动=0.90354 auc_现代史=0.96356 auc_地球与地图=0.92569 auc_溶酶体的结构和功能=0.97961 auc_体液免疫的概念和过程=0.98211 auc_地球所处的宇宙环境=0.96395 auc_人体免疫系统在维持稳态中的作用=0.98347 auc_与细胞分裂有关的细胞器=0.97740 auc_公民道德与伦理常识=0.98165 auc_工业区位因素=0.90803 auc_地理=0.99831 [step/sec: 1.29]
# [2020-03-26 20:01:21,905] [    INFO] - Evaluation on dev dataset start
# [2020-03-26 20:02:02,735] [    EVAL] - [dev dataset evaluation result] loss=1.02689 auc=0.95473 auc_宇宙中的地球=0.99539 auc_地球运动的基本形式=0.96066 auc_地球的内部圈层结构及特点=0.97688 auc_社会主义是中国人民的历史性选择=0.96234 auc_减数分裂的概念=0.97258 auc_基因的分离规律的实质及应用=0.95463 auc_组成细胞的化合物=0.97353 auc_基因工程的概念=0.98167 auc_人体水盐平衡调节=0.93813 auc_拉马克的进化学说=0.85167 auc_地球的外部圈层结构及特点=0.97189 auc_人口增长与人口问题=0.95776 auc_生产活动与地域联系=0.97589 auc_复等位基因=0.98173 auc_液泡的结构和功能=0.98400 auc_人口与城市=0.98087 auc_兴奋在神经纤维上的传导=0.96546 auc_郡县制=0.98728 auc_第三产业的兴起和“新经济”的出现=0.95982 auc_太阳对地球的影响=0.97702 auc_区域可持续发展=0.69251 auc_基因工程的原理及技术=0.98217 auc_社会主义市场经济的伦理要求=0.98782 auc_地球运动的地理意义=0.97829 auc_皇帝制度=0.99016 auc_遗传与进化=0.91328 auc_生物科学与社会=0.96981 auc_中央官制——三公九卿制=0.98749 auc_避孕的原理和方法=0.99552 auc_激素调节=0.93900 auc_近代史=0.96652 auc_生物工程技术=0.96977 auc_内环境的稳态=0.98512 auc_细胞有丝分裂不同时期的特点=0.91061 auc_清末民主革命风潮=0.95601 auc_高尔基体的结构和功能=0.97974 auc_伴性遗传=0.93231 auc_文艺的春天=0.95360 auc_神经调节和体液调节的比较=0.95682 auc_海峡两岸关系的发展=0.93883 auc_科学思维常识=0.85086 auc_遗传的细胞基础=0.99175 auc_劳动就业与守法经营=0.98040 auc_古代史=0.97860 auc_政治=0.99511 auc_农业区位因素=0.92233 auc_选官、用官制度的变化=0.97389 auc_生活中的法律常识=0.79187 auc_人工授精、试管婴儿等生殖技术=0.99534 auc_生物性污染=0.99548 auc_培养基与无菌技术=0.97794 auc_遗传的分子基础=0.99088 auc_内质网的结构和功能=0.97967 auc_基因的自由组合规律的实质及应用=0.96725 auc_生态系统的营养结构=0.90589 auc_“重农抑商”政策=0.98948 auc_免疫系统的功能=0.98547 auc_生命活动离不开细胞=0.95419 auc_蛋白质的合成=0.96692 auc_稳态与环境=0.98470 auc_不完全显性=0.95131 auc_夏商两代的政治制度=0.98955 auc_走进细胞=0.95861 auc_中心体的结构和功能=0.98201 auc_细胞的多样性和统一性=0.95897 auc_胚胎移植=0.95357 auc_群落的结构=0.88756 auc_免疫系统的组成=0.98527 auc_生物技术在其他方面的应用=0.98787 auc_经济学常识=0.93215 auc_生物=0.99932 auc_组成细胞的化学元素=0.97254 auc_核糖体的结构和功能=0.98431 auc_器官移植=0.95431 auc_时事政治=0.50691 auc_分子与细胞=0.97956 auc_血糖平衡的调节=0.94027 auc_减数分裂与有丝分裂的比较=0.98384 auc_垄断组织的出现=0.95425 auc_细胞大小与物质运输的关系=0.88799 auc_生物技术实践=0.96763 auc_科学社会主义常识=0.96825 auc_人体的体温调节=0.93231 auc_历史=0.99782 auc_现代生物技术专题=0.95090 auc_兴奋在神经元之间的传递=0.97198 auc_人口迁移与人口流动=0.91165 auc_现代史=0.96492 auc_地球与地图=0.93093 auc_溶酶体的结构和功能=0.98097 auc_体液免疫的概念和过程=0.98262 auc_地球所处的宇宙环境=0.96689 auc_人体免疫系统在维持稳态中的作用=0.98397 auc_与细胞分裂有关的细胞器=0.97860 auc_公民道德与伦理常识=0.98310 auc_工业区位因素=0.91473 auc_地理=0.99849 [step/sec: 3.68]
# [2020-03-26 20:02:02,736] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.95473]
# [2020-03-26 20:04:41,979] [   TRAIN] - step 1600 / 2981: loss=0.95495 auc=0.95858 auc_宇宙中的地球=0.99593 auc_地球运动的基本形式=0.96385 auc_地球的内部圈层结构及特点=0.98041 auc_社会主义是中国人民的历史性选择=0.96739 auc_减数分裂的概念=0.97451 auc_基因的分离规律的实质及应用=0.95657 auc_组成细胞的化合物=0.97471 auc_基因工程的概念=0.98333 auc_人体水盐平衡调节=0.94552 auc_拉马克的进化学说=0.86083 auc_地球的外部圈层结构及特点=0.97619 auc_人口增长与人口问题=0.96207 auc_生产活动与地域联系=0.97831 auc_复等位基因=0.98300 auc_液泡的结构和功能=0.98557 auc_人口与城市=0.98303 auc_兴奋在神经纤维上的传导=0.96814 auc_郡县制=0.98843 auc_第三产业的兴起和“新经济”的出现=0.96458 auc_太阳对地球的影响=0.97970 auc_区域可持续发展=0.71274 auc_基因工程的原理及技术=0.98364 auc_社会主义市场经济的伦理要求=0.98909 auc_地球运动的地理意义=0.98023 auc_皇帝制度=0.99092 auc_遗传与进化=0.91819 auc_生物科学与社会=0.97109 auc_中央官制——三公九卿制=0.98863 auc_避孕的原理和方法=0.99595 auc_激素调节=0.94615 auc_近代史=0.96824 auc_生物工程技术=0.97297 auc_内环境的稳态=0.98635 auc_细胞有丝分裂不同时期的特点=0.91710 auc_清末民主革命风潮=0.96049 auc_高尔基体的结构和功能=0.98180 auc_伴性遗传=0.93638 auc_文艺的春天=0.95867 auc_神经调节和体液调节的比较=0.96027 auc_海峡两岸关系的发展=0.94580 auc_科学思维常识=0.86918 auc_遗传的细胞基础=0.99242 auc_劳动就业与守法经营=0.98215 auc_古代史=0.98040 auc_政治=0.99578 auc_农业区位因素=0.93008 auc_选官、用官制度的变化=0.97664 auc_生活中的法律常识=0.81390 auc_人工授精、试管婴儿等生殖技术=0.99579 auc_生物性污染=0.99590 auc_培养基与无菌技术=0.97941 auc_遗传的分子基础=0.99161 auc_内质网的结构和功能=0.98182 auc_基因的自由组合规律的实质及应用=0.96843 auc_生态系统的营养结构=0.91461 auc_“重农抑商”政策=0.99043 auc_免疫系统的功能=0.98679 auc_生命活动离不开细胞=0.95656 auc_蛋白质的合成=0.96918 auc_稳态与环境=0.98593 auc_不完全显性=0.95584 auc_夏商两代的政治制度=0.99048 auc_走进细胞=0.96224 auc_中心体的结构和功能=0.98394 auc_细胞的多样性和统一性=0.96174 auc_胚胎移植=0.95864 auc_群落的结构=0.89857 auc_免疫系统的组成=0.98669 auc_生物技术在其他方面的应用=0.98874 auc_经济学常识=0.93983 auc_生物=0.99941 auc_组成细胞的化学元素=0.97383 auc_核糖体的结构和功能=0.98584 auc_器官移植=0.95904 auc_时事政治=0.52724 auc_分子与细胞=0.98121 auc_血糖平衡的调节=0.94733 auc_减数分裂与有丝分裂的比较=0.98518 auc_垄断组织的出现=0.95979 auc_细胞大小与物质运输的关系=0.89799 auc_生物技术实践=0.96906 auc_科学社会主义常识=0.97221 auc_人体的体温调节=0.94007 auc_历史=0.99811 auc_现代生物技术专题=0.95361 auc_兴奋在神经元之间的传递=0.97386 auc_人口迁移与人口流动=0.92245 auc_现代史=0.96685 auc_地球与地图=0.93882 auc_溶酶体的结构和功能=0.98299 auc_体液免疫的概念和过程=0.98412 auc_地球所处的宇宙环境=0.97099 auc_人体免疫系统在维持稳态中的作用=0.98542 auc_与细胞分裂有关的细胞器=0.98011 auc_公民道德与伦理常识=0.98489 auc_工业区位因素=0.92233 auc_地理=0.99872 [step/sec: 1.28]
# [2020-03-26 20:04:41,981] [    INFO] - Evaluation on dev dataset start
# [2020-03-26 20:05:22,840] [    EVAL] - [dev dataset evaluation result] loss=0.96410 auc=0.96090 auc_宇宙中的地球=0.99616 auc_地球运动的基本形式=0.96628 auc_地球的内部圈层结构及特点=0.98200 auc_社会主义是中国人民的历史性选择=0.97015 auc_减数分裂的概念=0.97571 auc_基因的分离规律的实质及应用=0.95799 auc_组成细胞的化合物=0.97591 auc_基因工程的概念=0.98436 auc_人体水盐平衡调节=0.94876 auc_拉马克的进化学说=0.86831 auc_地球的外部圈层结构及特点=0.97825 auc_人口增长与人口问题=0.96512 auc_生产活动与地域联系=0.97990 auc_复等位基因=0.98416 auc_液泡的结构和功能=0.98623 auc_人口与城市=0.98441 auc_兴奋在神经纤维上的传导=0.97029 auc_郡县制=0.98763 auc_第三产业的兴起和“新经济”的出现=0.96782 auc_太阳对地球的影响=0.98124 auc_区域可持续发展=0.73047 auc_基因工程的原理及技术=0.98462 auc_社会主义市场经济的伦理要求=0.98985 auc_地球运动的地理意义=0.98081 auc_皇帝制度=0.99005 auc_遗传与进化=0.92118 auc_生物科学与社会=0.97196 auc_中央官制——三公九卿制=0.98796 auc_避孕的原理和方法=0.99616 auc_激素调节=0.94985 auc_近代史=0.96939 auc_生物工程技术=0.97518 auc_内环境的稳态=0.98681 auc_细胞有丝分裂不同时期的特点=0.92133 auc_清末民主革命风潮=0.96314 auc_高尔基体的结构和功能=0.98274 auc_伴性遗传=0.93838 auc_文艺的春天=0.96197 auc_神经调节和体液调节的比较=0.96245 auc_海峡两岸关系的发展=0.94908 auc_科学思维常识=0.87891 auc_遗传的细胞基础=0.99277 auc_劳动就业与守法经营=0.98347 auc_古代史=0.98012 auc_政治=0.99606 auc_农业区位因素=0.93527 auc_选官、用官制度的变化=0.97795 auc_生活中的法律常识=0.82898 auc_人工授精、试管婴儿等生殖技术=0.99601 auc_生物性污染=0.99612 auc_培养基与无菌技术=0.98044 auc_遗传的分子基础=0.99190 auc_内质网的结构和功能=0.98264 auc_基因的自由组合规律的实质及应用=0.96974 auc_生态系统的营养结构=0.91907 auc_“重农抑商”政策=0.98963 auc_免疫系统的功能=0.98719 auc_生命活动离不开细胞=0.95843 auc_蛋白质的合成=0.97030 auc_稳态与环境=0.98634 auc_不完全显性=0.95866 auc_夏商两代的政治制度=0.98972 auc_走进细胞=0.96393 auc_中心体的结构和功能=0.98469 auc_细胞的多样性和统一性=0.96387 auc_胚胎移植=0.96204 auc_群落的结构=0.90532 auc_免疫系统的组成=0.98707 auc_生物技术在其他方面的应用=0.98932 auc_经济学常识=0.94479 auc_生物=0.99945 auc_组成细胞的化学元素=0.97508 auc_核糖体的结构和功能=0.98645 auc_器官移植=0.96245 auc_时事政治=0.54851 auc_分子与细胞=0.98224 auc_血糖平衡的调节=0.95060 auc_减数分裂与有丝分裂的比较=0.98602 auc_垄断组织的出现=0.96344 auc_细胞大小与物质运输的关系=0.90316 auc_生物技术实践=0.97008 auc_科学社会主义常识=0.97422 auc_人体的体温调节=0.94346 auc_历史=0.99824 auc_现代生物技术专题=0.95453 auc_兴奋在神经元之间的传递=0.97562 auc_人口迁移与人口流动=0.92797 auc_现代史=0.96785 auc_地球与地图=0.94297 auc_溶酶体的结构和功能=0.98380 auc_体液免疫的概念和过程=0.98454 auc_地球所处的宇宙环境=0.97318 auc_人体免疫系统在维持稳态中的作用=0.98588 auc_与细胞分裂有关的细胞器=0.98083 auc_公民道德与伦理常识=0.98592 auc_工业区位因素=0.92747 auc_地理=0.99884 [step/sec: 3.67]
# [2020-03-26 20:05:22,842] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.96090]
# [2020-03-26 20:08:00,690] [   TRAIN] - step 1800 / 2981: loss=0.85353 auc=0.96385 auc_宇宙中的地球=0.99653 auc_地球运动的基本形式=0.96875 auc_地球的内部圈层结构及特点=0.98362 auc_社会主义是中国人民的历史性选择=0.97254 auc_减数分裂的概念=0.97716 auc_基因的分离规律的实质及应用=0.95930 auc_组成细胞的化合物=0.97753 auc_基因工程的概念=0.98559 auc_人体水盐平衡调节=0.95264 auc_拉马克的进化学说=0.87474 auc_地球的外部圈层结构及特点=0.98066 auc_人口增长与人口问题=0.96862 auc_生产活动与地域联系=0.98164 auc_复等位基因=0.98526 auc_液泡的结构和功能=0.98694 auc_人口与城市=0.98596 auc_兴奋在神经纤维上的传导=0.97262 auc_郡县制=0.98904 auc_第三产业的兴起和“新经济”的出现=0.97147 auc_太阳对地球的影响=0.98331 auc_区域可持续发展=0.74833 auc_基因工程的原理及技术=0.98593 auc_社会主义市场经济的伦理要求=0.99079 auc_地球运动的地理意义=0.98222 auc_皇帝制度=0.99115 auc_遗传与进化=0.92487 auc_生物科学与社会=0.97295 auc_中央官制——三公九卿制=0.98932 auc_避孕的原理和方法=0.99643 auc_激素调节=0.95425 auc_近代史=0.97060 auc_生物工程技术=0.97626 auc_内环境的稳态=0.98794 auc_细胞有丝分裂不同时期的特点=0.92701 auc_清末民主革命风潮=0.96617 auc_高尔基体的结构和功能=0.98382 auc_伴性遗传=0.94090 auc_文艺的春天=0.96568 auc_神经调节和体液调节的比较=0.96460 auc_海峡两岸关系的发展=0.95429 auc_科学思维常识=0.88961 auc_遗传的细胞基础=0.99325 auc_劳动就业与守法经营=0.98466 auc_古代史=0.98084 auc_政治=0.99641 auc_农业区位因素=0.94075 auc_选官、用官制度的变化=0.97917 auc_生活中的法律常识=0.84440 auc_人工授精、试管婴儿等生殖技术=0.99633 auc_生物性污染=0.99640 auc_培养基与无菌技术=0.98214 auc_遗传的分子基础=0.99244 auc_内质网的结构和功能=0.98379 auc_基因的自由组合规律的实质及应用=0.97120 auc_生态系统的营养结构=0.92600 auc_“重农抑商”政策=0.99081 auc_免疫系统的功能=0.98834 auc_生命活动离不开细胞=0.96115 auc_蛋白质的合成=0.97294 auc_稳态与环境=0.98743 auc_不完全显性=0.96238 auc_夏商两代的政治制度=0.99088 auc_走进细胞=0.96560 auc_中心体的结构和功能=0.98562 auc_细胞的多样性和统一性=0.96643 auc_胚胎移植=0.96519 auc_群落的结构=0.91433 auc_免疫系统的组成=0.98822 auc_生物技术在其他方面的应用=0.99015 auc_经济学常识=0.94999 auc_生物=0.99952 auc_组成细胞的化学元素=0.97685 auc_核糖体的结构和功能=0.98723 auc_器官移植=0.96561 auc_时事政治=0.57998 auc_分子与细胞=0.98351 auc_血糖平衡的调节=0.95439 auc_减数分裂与有丝分裂的比较=0.98680 auc_垄断组织的出现=0.96767 auc_细胞大小与物质运输的关系=0.91125 auc_生物技术实践=0.97081 auc_科学社会主义常识=0.97616 auc_人体的体温调节=0.94814 auc_历史=0.99844 auc_现代生物技术专题=0.95609 auc_兴奋在神经元之间的传递=0.97751 auc_人口迁移与人口流动=0.93518 auc_现代史=0.96927 auc_地球与地图=0.94847 auc_溶酶体的结构和功能=0.98480 auc_体液免疫的概念和过程=0.98597 auc_地球所处的宇宙环境=0.97599 auc_人体免疫系统在维持稳态中的作用=0.98717 auc_与细胞分裂有关的细胞器=0.98181 auc_公民道德与伦理常识=0.98711 auc_工业区位因素=0.93448 auc_地理=0.99897 [step/sec: 1.29]
# [2020-03-26 20:08:00,691] [    INFO] - Evaluation on dev dataset start
# [2020-03-26 20:08:41,302] [    EVAL] - [dev dataset evaluation result] loss=0.92102 auc=0.96565 auc_宇宙中的地球=0.99670 auc_地球运动的基本形式=0.97059 auc_地球的内部圈层结构及特点=0.98479 auc_社会主义是中国人民的历史性选择=0.97437 auc_减数分裂的概念=0.97805 auc_基因的分离规律的实质及应用=0.96039 auc_组成细胞的化合物=0.97841 auc_基因工程的概念=0.98642 auc_人体水盐平衡调节=0.95486 auc_拉马克的进化学说=0.88018 auc_地球的外部圈层结构及特点=0.98219 auc_人口增长与人口问题=0.97094 auc_生产活动与地域联系=0.98268 auc_复等位基因=0.98623 auc_液泡的结构和功能=0.98731 auc_人口与城市=0.98696 auc_兴奋在神经纤维上的传导=0.97398 auc_郡县制=0.98883 auc_第三产业的兴起和“新经济”的出现=0.97374 auc_太阳对地球的影响=0.98453 auc_区域可持续发展=0.76320 auc_基因工程的原理及技术=0.98672 auc_社会主义市场经济的伦理要求=0.99137 auc_地球运动的地理意义=0.98273 auc_皇帝制度=0.99082 auc_遗传与进化=0.92739 auc_生物科学与社会=0.97368 auc_中央官制——三公九卿制=0.98914 auc_避孕的原理和方法=0.99659 auc_激素调节=0.95722 auc_近代史=0.97149 auc_生物工程技术=0.97786 auc_内环境的稳态=0.98802 auc_细胞有丝分裂不同时期的特点=0.93004 auc_清末民主革命风潮=0.96821 auc_高尔基体的结构和功能=0.98431 auc_伴性遗传=0.94301 auc_文艺的春天=0.96817 auc_神经调节和体液调节的比较=0.96563 auc_海峡两岸关系的发展=0.95669 auc_科学思维常识=0.89690 auc_遗传的细胞基础=0.99357 auc_劳动就业与守法经营=0.98558 auc_古代史=0.98098 auc_政治=0.99652 auc_农业区位因素=0.94428 auc_选官、用官制度的变化=0.98018 auc_生活中的法律常识=0.85562 auc_人工授精、试管婴儿等生殖技术=0.99649 auc_生物性污染=0.99657 auc_培养基与无菌技术=0.98286 auc_遗传的分子基础=0.99276 auc_内质网的结构和功能=0.98419 auc_基因的自由组合规律的实质及应用=0.97230 auc_生态系统的营养结构=0.92937 auc_“重农抑商”政策=0.99056 auc_免疫系统的功能=0.98852 auc_生命活动离不开细胞=0.96250 auc_蛋白质的合成=0.97399 auc_稳态与环境=0.98765 auc_不完全显性=0.96450 auc_夏商两代的政治制度=0.99069 auc_走进细胞=0.96674 auc_中心体的结构和功能=0.98592 auc_细胞的多样性和统一性=0.96784 auc_胚胎移植=0.96766 auc_群落的结构=0.91951 auc_免疫系统的组成=0.98843 auc_生物技术在其他方面的应用=0.99057 auc_经济学常识=0.95356 auc_生物=0.99953 auc_组成细胞的化学元素=0.97775 auc_核糖体的结构和功能=0.98743 auc_器官移植=0.96814 auc_时事政治=0.60402 auc_分子与细胞=0.98421 auc_血糖平衡的调节=0.95666 auc_减数分裂与有丝分裂的比较=0.98744 auc_垄断组织的出现=0.97032 auc_细胞大小与物质运输的关系=0.91491 auc_生物技术实践=0.97160 auc_科学社会主义常识=0.97697 auc_人体的体温调节=0.95042 auc_历史=0.99851 auc_现代生物技术专题=0.95680 auc_兴奋在神经元之间的传递=0.97865 auc_人口迁移与人口流动=0.93933 auc_现代史=0.97013 auc_地球与地图=0.95029 auc_溶酶体的结构和功能=0.98518 auc_体液免疫的概念和过程=0.98626 auc_地球所处的宇宙环境=0.97756 auc_人体免疫系统在维持稳态中的作用=0.98740 auc_与细胞分裂有关的细胞器=0.98212 auc_公民道德与伦理常识=0.98791 auc_工业区位因素=0.93831 auc_地理=0.99905 [step/sec: 3.70]
# [2020-03-26 20:08:41,303] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.96565]
# [2020-03-26 20:11:19,840] [   TRAIN] - step 2000 / 2981: loss=0.80583 auc=0.96811 auc_宇宙中的地球=0.99700 auc_地球运动的基本形式=0.97263 auc_地球的内部圈层结构及特点=0.98590 auc_社会主义是中国人民的历史性选择=0.97717 auc_减数分裂的概念=0.97935 auc_基因的分离规律的实质及应用=0.96120 auc_组成细胞的化合物=0.97937 auc_基因工程的概念=0.98736 auc_人体水盐平衡调节=0.95884 auc_拉马克的进化学说=0.88489 auc_地球的外部圈层结构及特点=0.98367 auc_人口增长与人口问题=0.97352 auc_生产活动与地域联系=0.98393 auc_复等位基因=0.98686 auc_液泡的结构和功能=0.98850 auc_人口与城市=0.98817 auc_兴奋在神经纤维上的传导=0.97528 auc_郡县制=0.98992 auc_第三产业的兴起和“新经济”的出现=0.97633 auc_太阳对地球的影响=0.98617 auc_区域可持续发展=0.77912 auc_基因工程的原理及技术=0.98761 auc_社会主义市场经济的伦理要求=0.99221 auc_地球运动的地理意义=0.98405 auc_皇帝制度=0.99168 auc_遗传与进化=0.93079 auc_生物科学与社会=0.97477 auc_中央官制——三公九卿制=0.99018 auc_避孕的原理和方法=0.99690 auc_激素调节=0.96080 auc_近代史=0.97236 auc_生物工程技术=0.97950 auc_内环境的稳态=0.98864 auc_细胞有丝分裂不同时期的特点=0.93442 auc_清末民主革命风潮=0.97051 auc_高尔基体的结构和功能=0.98585 auc_伴性遗传=0.94567 auc_文艺的春天=0.97106 auc_神经调节和体液调节的比较=0.96762 auc_海峡两岸关系的发展=0.96100 auc_科学思维常识=0.90665 auc_遗传的细胞基础=0.99401 auc_劳动就业与守法经营=0.98641 auc_古代史=0.98204 auc_政治=0.99689 auc_农业区位因素=0.94943 auc_选官、用官制度的变化=0.98181 auc_生活中的法律常识=0.86758 auc_人工授精、试管婴儿等生殖技术=0.99682 auc_生物性污染=0.99687 auc_培养基与无菌技术=0.98401 auc_遗传的分子基础=0.99325 auc_内质网的结构和功能=0.98575 auc_基因的自由组合规律的实质及应用=0.97342 auc_生态系统的营养结构=0.93626 auc_“重农抑商”政策=0.99142 auc_免疫系统的功能=0.98928 auc_生命活动离不开细胞=0.96441 auc_蛋白质的合成=0.97576 auc_稳态与环境=0.98855 auc_不完全显性=0.96761 auc_夏商两代的政治制度=0.99165 auc_走进细胞=0.96904 auc_中心体的结构和功能=0.98727 auc_细胞的多样性和统一性=0.96996 auc_胚胎移植=0.97049 auc_群落的结构=0.92701 auc_免疫系统的组成=0.98921 auc_生物技术在其他方面的应用=0.99119 auc_经济学常识=0.95795 auc_生物=0.99958 auc_组成细胞的化学元素=0.97890 auc_核糖体的结构和功能=0.98861 auc_器官移植=0.97090 auc_时事政治=0.62513 auc_分子与细胞=0.98533 auc_血糖平衡的调节=0.96042 auc_减数分裂与有丝分裂的比较=0.98846 auc_垄断组织的出现=0.97328 auc_细胞大小与物质运输的关系=0.92170 auc_生物技术实践=0.97251 auc_科学社会主义常识=0.97950 auc_人体的体温调节=0.95466 auc_历史=0.99868 auc_现代生物技术专题=0.95844 auc_兴奋在神经元之间的传递=0.97983 auc_人口迁移与人口流动=0.94464 auc_现代史=0.97159 auc_地球与地图=0.95478 auc_溶酶体的结构和功能=0.98663 auc_体液免疫的概念和过程=0.98723 auc_地球所处的宇宙环境=0.97963 auc_人体免疫系统在维持稳态中的作用=0.98823 auc_与细胞分裂有关的细胞器=0.98353 auc_公民道德与伦理常识=0.98904 auc_工业区位因素=0.94363 auc_地理=0.99916 [step/sec: 1.29]
# [2020-03-26 20:11:19,842] [    INFO] - Evaluation on dev dataset start
# [2020-03-26 20:12:01,643] [    EVAL] - [dev dataset evaluation result] loss=0.88194 auc=0.96953 auc_宇宙中的地球=0.99712 auc_地球运动的基本形式=0.97404 auc_地球的内部圈层结构及特点=0.98688 auc_社会主义是中国人民的历史性选择=0.97850 auc_减数分裂的概念=0.98001 auc_基因的分离规律的实质及应用=0.96205 auc_组成细胞的化合物=0.98007 auc_基因工程的概念=0.98801 auc_人体水盐平衡调节=0.96093 auc_拉马克的进化学说=0.88904 auc_地球的外部圈层结构及特点=0.98489 auc_人口增长与人口问题=0.97527 auc_生产活动与地域联系=0.98474 auc_复等位基因=0.98761 auc_液泡的结构和功能=0.98890 auc_人口与城市=0.98890 auc_兴奋在神经纤维上的传导=0.97662 auc_郡县制=0.99012 auc_第三产业的兴起和“新经济”的出现=0.97796 auc_太阳对地球的影响=0.98702 auc_区域可持续发展=0.79006 auc_基因工程的原理及技术=0.98823 auc_社会主义市场经济的伦理要求=0.99261 auc_地球运动的地理意义=0.98444 auc_皇帝制度=0.99174 auc_遗传与进化=0.93281 auc_生物科学与社会=0.97534 auc_中央官制——三公九卿制=0.99034 auc_避孕的原理和方法=0.99696 auc_激素调节=0.96310 auc_近代史=0.97313 auc_生物工程技术=0.98077 auc_内环境的稳态=0.98894 auc_细胞有丝分裂不同时期的特点=0.93664 auc_清末民主革命风潮=0.97216 auc_高尔基体的结构和功能=0.98640 auc_伴性遗传=0.94726 auc_文艺的春天=0.97293 auc_神经调节和体液调节的比较=0.96897 auc_海峡两岸关系的发展=0.96279 auc_科学思维常识=0.91178 auc_遗传的细胞基础=0.99415 auc_劳动就业与守法经营=0.98716 auc_古代史=0.98251 auc_政治=0.99693 auc_农业区位因素=0.95212 auc_选官、用官制度的变化=0.98268 auc_生活中的法律常识=0.87636 auc_人工授精、试管婴儿等生殖技术=0.99688 auc_生物性污染=0.99694 auc_培养基与无菌技术=0.98458 auc_遗传的分子基础=0.99337 auc_内质网的结构和功能=0.98625 auc_基因的自由组合规律的实质及应用=0.97432 auc_生态系统的营养结构=0.93862 auc_“重农抑商”政策=0.99159 auc_免疫系统的功能=0.98963 auc_生命活动离不开细胞=0.96542 auc_蛋白质的合成=0.97627 auc_稳态与环境=0.98883 auc_不完全显性=0.96912 auc_夏商两代的政治制度=0.99175 auc_走进细胞=0.97022 auc_中心体的结构和功能=0.98775 auc_细胞的多样性和统一性=0.97101 auc_胚胎移植=0.97236 auc_群落的结构=0.93071 auc_免疫系统的组成=0.98955 auc_生物技术在其他方面的应用=0.99148 auc_经济学常识=0.96066 auc_生物=0.99960 auc_组成细胞的化学元素=0.97959 auc_核糖体的结构和功能=0.98898 auc_器官移植=0.97281 auc_时事政治=0.64276 auc_分子与细胞=0.98578 auc_血糖平衡的调节=0.96251 auc_减数分裂与有丝分裂的比较=0.98889 auc_垄断组织的出现=0.97522 auc_细胞大小与物质运输的关系=0.92442 auc_生物技术实践=0.97320 auc_科学社会主义常识=0.97982 auc_人体的体温调节=0.95682 auc_历史=0.99873 auc_现代生物技术专题=0.95904 auc_兴奋在神经元之间的传递=0.98092 auc_人口迁移与人口流动=0.94790 auc_现代史=0.97224 auc_地球与地图=0.95598 auc_溶酶体的结构和功能=0.98715 auc_体液免疫的概念和过程=0.98766 auc_地球所处的宇宙环境=0.98086 auc_人体免疫系统在维持稳态中的作用=0.98860 auc_与细胞分裂有关的细胞器=0.98402 auc_公民道德与伦理常识=0.98963 auc_工业区位因素=0.94649 auc_地理=0.99922 [step/sec: 3.59]
# [2020-03-26 20:12:01,644] [    EVAL] - best model saved to ckpt_20200326193206/best_model [best auc=0.96953]
# [2020-03-26 20:14:40,285] [   TRAIN] - step 2200 / 2981: loss=0.78705 auc=0.97139 auc_宇宙中的地球=0.99733 auc_地球运动的基本形式=0.97564 auc_地球的内部圈层结构及特点=0.98811 auc_社会主义是中国人民的历史性选择=0.98058 auc_减数分裂的概念=0.98053 auc_基因的分离规律的实质及应用=0.96280 auc_组成细胞的化合物=0.98133 auc_基因工程的概念=0.98901 auc_人体水盐平衡调节=0.96309 auc_拉马克的进化学说=0.89379 auc_地球的外部圈层结构及特点=0.98647 auc_人口增长与人口问题=0.97740 auc_生产活动与地域联系=0.98576 auc_复等位基因=0.98857 auc_液泡的结构和功能=0.98960 auc_人口与城市=0.98982 auc_兴奋在神经纤维上的传导=0.97820 auc_郡县制=0.99106 auc_第三产业的兴起和“新经济”的出现=0.97976 auc_太阳对地球的影响=0.98813 auc_区域可持续发展=0.79838 auc_基因工程的原理及技术=0.98918 auc_社会主义市场经济的伦理要求=0.99316 auc_地球运动的地理意义=0.98532 auc_皇帝制度=0.99251 auc_遗传与进化=0.93588 auc_生物科学与社会=0.97615 auc_中央官制——三公九卿制=0.99125 auc_避孕的原理和方法=0.99710 auc_激素调节=0.96633 auc_近代史=0.97412 auc_生物工程技术=0.98191 auc_内环境的稳态=0.98969 auc_细胞有丝分裂不同时期的特点=0.93995 auc_清末民主革命风潮=0.97437 auc_高尔基体的结构和功能=0.98738 auc_伴性遗传=0.94936 auc_文艺的春天=0.97523 auc_神经调节和体液调节的比较=0.97083 auc_海峡两岸关系的发展=0.96592 auc_科学思维常识=0.91842 auc_遗传的细胞基础=0.99444 auc_劳动就业与守法经营=0.98792 auc_古代史=0.98323 auc_政治=0.99722 auc_农业区位因素=0.95557 auc_选官、用官制度的变化=0.98358 auc_生活中的法律常识=0.88517 auc_人工授精、试管婴儿等生殖技术=0.99703 auc_生物性污染=0.99710 auc_培养基与无菌技术=0.98539 auc_遗传的分子基础=0.99372 auc_内质网的结构和功能=0.98723 auc_基因的自由组合规律的实质及应用=0.97521 auc_生态系统的营养结构=0.94315 auc_“重农抑商”政策=0.99238 auc_免疫系统的功能=0.99042 auc_生命活动离不开细胞=0.96669 auc_蛋白质的合成=0.97831 auc_稳态与环境=0.98957 auc_不完全显性=0.97128 auc_夏商两代的政治制度=0.99251 auc_走进细胞=0.97188 auc_中心体的结构和功能=0.98855 auc_细胞的多样性和统一性=0.97289 auc_胚胎移植=0.97451 auc_群落的结构=0.93546 auc_免疫系统的组成=0.99035 auc_生物技术在其他方面的应用=0.99210 auc_经济学常识=0.96361 auc_生物=0.99964 auc_组成细胞的化学元素=0.98099 auc_核糖体的结构和功能=0.98969 auc_器官移植=0.97497 auc_时事政治=0.66157 auc_分子与细胞=0.98661 auc_血糖平衡的调节=0.96465 auc_减数分裂与有丝分裂的比较=0.98929 auc_垄断组织的出现=0.97724 auc_细胞大小与物质运输的关系=0.92960 auc_生物技术实践=0.97377 auc_科学社会主义常识=0.98167 auc_人体的体温调节=0.95938 auc_历史=0.99885 auc_现代生物技术专题=0.96035 auc_兴奋在神经元之间的传递=0.98227 auc_人口迁移与人口流动=0.95232 auc_现代史=0.97334 auc_地球与地图=0.95958 auc_溶酶体的结构和功能=0.98806 auc_体液免疫的概念和过程=0.98861 auc_地球所处的宇宙环境=0.98252 auc_人体免疫系统在维持稳态中的作用=0.98946 auc_与细胞分裂有关的细胞器=0.98488 auc_公民道德与伦理常识=0.99050 auc_工业区位因素=0.95027 auc_地理=0.99929 [step/sec: 1.29]
# [2020-03-26 20:14:40,287] [    INFO] - Evaluation on dev dataset start
# ...
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3390>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1190250>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36cbbf9850>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36787f1c10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615c90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3ad0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1190110>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36cbbf9150>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36787f1ed0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615850>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3cd0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f11900d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36cbbf9210>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36787f1050>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615d50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e38d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f11905d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36cbbf9110>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36787f1d50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615810>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3e90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1190590>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36cbbf9710>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1190310>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e30d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1190050>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3750>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1190210>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3910>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f11902d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3810>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1190550>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3d10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f11903d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36787f1cd0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3610>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615d90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36787f1f10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e37d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36786159d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36787f1c50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3fd0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615750>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36787f1e90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e34d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615710>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36787f1d10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615e50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615c10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615cd0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615790>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615b90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615e90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36786158d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615bd0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615610>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615f50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615990>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615890>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36786155d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615b50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f3678615690>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12eddd0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f370803e490>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a450>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36cbc01b10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36786154d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edf90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36cbbc9a50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed6d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36cbc01250>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed9d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f36cbbc9b50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edcd0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620e10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed210>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620e50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed610>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620750>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed550>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f10e5050>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed1d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620890>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed850>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620110>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed350>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f86209d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed390>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620210>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12eded0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620b90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed7d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620350>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed650>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f86204d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed890>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620e90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edd50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620410>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12eda90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620250>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edc50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620a10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed590>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620050>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed950>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620610>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed710>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f86200d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12eda10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620c50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a350>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3c50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d410>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ede10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620310>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a2d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3d50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d150>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed790>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620850>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a1d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3490>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d490>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed250>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620390>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a6d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3290>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d350>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed810>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f86202d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a850>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3b90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d050>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed310>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620ed0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a050>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e39d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d390>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edc10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620c90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a110>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3b10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d110>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edb50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f86208d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a590>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3e10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d2d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed290>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620ad0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0c9d310>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3090>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d450>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edb90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620550>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a190>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3890>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d710>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed4d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620710>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a810>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12e3a90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367820a3d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d250>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620c10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ede50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d5d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620690>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed690>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d690>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620810>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edc90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d1d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620150>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edf50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d090>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620d90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed490>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d650>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620bd0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed910>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620990>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12edd90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f370898f3d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d290>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f367825f990>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620590>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed750>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f85fcad0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12eda50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620910>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ed990>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f86207d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f12ede90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d510>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f8620f90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d590>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d310>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d550>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d7d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d0d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d3d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d6d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d210>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d4d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d750>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d190>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f174d610>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776cd0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776c50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776050>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776d10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776ed0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776690>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776590>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776e10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776b10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f1776990>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7a90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db75d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7810>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7b50>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7650>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7710>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7790>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7510>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db76d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7490>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7390>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db71d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db78d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7450>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7590>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7850>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7b90>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7110>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7250>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7290>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db73d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7090>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db70d0>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7b10>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7150>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7990>,
#  <paddlehub.finetune.task.base_task.RunState at 0x7f33f0db7190>]

# %% [markdown]
# # 预测
# 当Finetune完成后，我们使用模型来进行预测，整个预测流程大致可以分为以下几步：
# 1. 构建网络
# 2. 生成预测数据的Reader
# 3. 切换到预测的Program
# 4. 加载预训练好的参数
# 5. 运行Program进行预测
#
# <center> <img width="1024px" src="https://ai-studio-static-online.cdn.bcebos.com/320a7c13fcb044d3b45cb4720012bd26dbc10c283aa747dab43f72d1bad18643" /> </center>
#
# > 预测代码如下：

# %%
import numpy as np

# index 转回 标签
inv_label_map = {val: key for key, val in reader.label_map.items()}
# 预测数据
data = [[d.text_a, d.text_b] for d in dataset.get_test_examples()]
# 预测标签
test_y = np.array([d.label for d in dataset.get_test_examples()])
# 预测
run_states = cls_task.predict(data)
# 把结果提取出来
results = [run_state.run_results for run_state in run_states]
# Out:
# [2020-03-27 14:10:08,479] [    INFO] - The best model has been loaded
# [2020-03-27 14:10:08,480] [    INFO] - PaddleHub predict start
# [2020-03-27 14:10:44,094] [    INFO] - PaddleHub predict finished.

# %%
test_y_pred = np.concatenate([np.argmax(batch_result, axis=2).T for batch_result in results])
test_y_pred.shape, test_y.shape
# Out:
# ((5963, 97), (5963, 97))

# %%
from sklearn.metrics import f1_score, precision_score, recall_score
f1_micro = f1_score(test_y, test_y_pred, average='micro')
f1_macro = f1_score(test_y, test_y_pred, average='macro')
f1_samples = f1_score(test_y, test_y_pred, average='samples')
precision = precision_score(test_y, test_y_pred, average='micro')
recall = recall_score(test_y, test_y_pred, average='micro')

print('f1 micro:{}'.format(f1_micro))
print('f1 samples:{}'.format(f1_macro))
print('f1 macro:{}'.format(f1_samples))
print('precision:{}'.format(precision))
print('recall:{}'.format(recall))
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)
# f1 micro:0.9102579532234123
# f1 samples:0.8318882086938779
# f1 macro:0.9065945223360182
# precision:0.9257445940432476
# recall:0.8952809343434344

# %%
res = [inv_label_map[idx] for idx in np.nonzero(test_y_pred[0])[0]]
res
# Out:
# ['社会主义市场经济的伦理要求', '政治', '公民道德与伦理常识']

# %%
pred =[[inv_label_map[idx] for idx in np.nonzero(line)[0]] for line in test_y_pred]
pred[3:5]
# Out:
# [['减数分裂的概念',
#   '生物科学与社会',
#   '避孕的原理和方法',
#   '人工授精、试管婴儿等生殖技术',
#   '生物性污染',
#   '生物',
#   '减数分裂与有丝分裂的比较'],
#  ['近代史', '清末民主革命风潮', '历史']]

# %%
real =[[inv_label_map[idx] for idx in np.nonzero(line)[0]] for line in test_y]
real[3:5]
# Out:
# [['生物科学与社会', '避孕的原理和方法', '人工授精、试管婴儿等生殖技术', '生物性污染', '生物', '减数分裂与有丝分裂的比较'],
#  ['近代史', '清末民主革命风潮', '历史']]

# %% [markdown]
# # 将刚刚的整个过程封装

# %%
import numpy as np
from sklearn.metrics import f1_score, precision_score, recall_score
def train(model_name="ernie_tiny", learning_rate=3e-5, max_seq_len=256, batch_size=32, epochs=5):
    module = hub.Module(name=model_name)
    inputs, outputs, program = module.context(trainable=True, max_seq_len=max_seq_len)

    dataset = Baidu()
    reader = hub.reader.MultiLabelClassifyReader(
        dataset=dataset,
        vocab_path=module.get_vocab_path(),
        max_seq_len=max_seq_len)

    strategy = hub.AdamWeightDecayStrategy(
        learning_rate=learning_rate,
        weight_decay=0.01,
        warmup_proportion=0.0,
        lr_scheduler="linear_decay",
    )

    config = hub.RunConfig(use_cuda=True, 
                            use_data_parallel=True, 
                            use_pyreader=True, 
                            log_interval=200,
                            eval_interval=200,
                            num_epoch=epochs, 
                            batch_size=batch_size, 
                            strategy=strategy)

    pooled_output = outputs["pooled_output"]

    # feed_list的Tensor顺序不可以调整
    feed_list = [
        inputs["input_ids"].name,
        inputs["position_ids"].name,
        inputs["segment_ids"].name,
        inputs["input_mask"].name,
    ]

    cls_task = hub.MultiLabelClassifierTask(
        data_reader=reader,
        feature=pooled_output,
        feed_list=feed_list,
        num_classes=dataset.num_labels,
        config=config)

    cls_task.finetune_and_eval()

    # index 转回 标签
    inv_label_map = {val: key for key, val in reader.label_map.items()}
    # 预测数据
    data = [[d.text_a, d.text_b] for d in dataset.get_test_examples()]
    # 预测标签
    test_y = np.array([d.label for d in dataset.get_test_examples()])
    # 预测
    run_states = cls_task.predict(data)
    # 把结果提取出来
    results = [run_state.run_results for run_state in run_states]

    test_y_pred = np.concatenate([np.argmax(batch_result, axis=2).T for batch_result in results])
        
    f1_micro = f1_score(test_y, test_y_pred, average='micro')
    f1_macro = f1_score(test_y, test_y_pred, average='macro')
    f1_samples = f1_score(test_y, test_y_pred, average='samples')
    precision = precision_score(test_y, test_y_pred, average='micro')
    recall = recall_score(test_y, test_y_pred, average='micro')

    print('f1 micro:{}'.format(f1_micro))
    print('f1 samples:{}'.format(f1_macro))
    print('f1 macro:{}'.format(f1_samples))
    print('precision:{}'.format(precision))
    print('recall:{}'.format(recall))
    
    return module, dataset, reader, cls_task, (f1_micro, f1_macro, f1_samples)

# %%
# %cd /home/aistudio/
# !mkdir -p .paddlehub/cache
# Out:
# /home/aistudio

# %%
module, dataset, reader, cls_task, res = train(model_name="bert_wwm_ext_chinese_L-12_H-768_A-12", epochs=5)
# Out:
# [2020-03-27 13:03:44,039] [    INFO] - Installing bert_wwm_ext_chinese_L-12_H-768_A-12 module
# [2020-03-27 13:03:44,068] [    INFO] - Module bert_wwm_ext_chinese_L-12_H-768_A-12 already installed in /home/aistudio/.paddlehub/modules/bert_wwm_ext_chinese_L-12_H-768_A-12
# [2020-03-27 13:03:44,687] [    INFO] - Set maximum sequence length of input tensor to 256
# [2020-03-27 13:03:44,694] [    INFO] - The shape of input tensor[input_ids] set to [-1, 256, 1]
# [2020-03-27 13:03:44,695] [    INFO] - The shape of input tensor[position_ids] set to [-1, 256, 1]
# [2020-03-27 13:03:44,695] [    INFO] - The shape of input tensor[segment_ids] set to [-1, 256, 1]
# [2020-03-27 13:03:44,696] [    INFO] - The shape of input tensor[input_mask] set to [-1, 256, 1]
# [2020-03-27 13:03:44,697] [    INFO] - 199 pretrained paramaters loaded by PaddleHub
# [2020-03-27 13:03:47,513] [    INFO] - Dataset label map = {'宇宙中的地球': 0, '地球运动的基本形式': 1, '地球的内部圈层结构及特点': 2, '社会主义是中国人民的历史性选择': 3, '减数分裂的概念': 4, '基因的分离规律的实质及应用': 5, '组成细胞的化合物': 6, '基因工程的概念': 7, '人体水盐平衡调节': 8, '拉马克的进化学说': 9, '地球的外部圈层结构及特点': 10, '人口增长与人口问题': 11, '生产活动与地域联系': 12, '复等位基因': 13, '液泡的结构和功能': 14, '人口与城市': 15, '兴奋在神经纤维上的传导': 16, '郡县制': 17, '第三产业的兴起和“新经济”的出现': 18, '太阳对地球的影响': 19, '区域可持续发展': 20, '基因工程的原理及技术': 21, '社会主义市场经济的伦理要求': 22, '地球运动的地理意义': 23, '皇帝制度': 24, '遗传与进化': 25, '生物科学与社会': 26, '中央官制——三公九卿制': 27, '避孕的原理和方法': 28, '激素调节': 29, '近代史': 30, '生物工程技术': 31, '内环境的稳态': 32, '细胞有丝分裂不同时期的特点': 33, '清末民主革命风潮': 34, '高尔基体的结构和功能': 35, '伴性遗传': 36, '文艺的春天': 37, '神经调节和体液调节的比较': 38, '海峡两岸关系的发展': 39, '科学思维常识': 40, '遗传的细胞基础': 41, '劳动就业与守法经营': 42, '古代史': 43, '政治': 44, '农业区位因素': 45, '选官、用官制度的变化': 46, '生活中的法律常识': 47, '人工授精、试管婴儿等生殖技术': 48, '生物性污染': 49, '培养基与无菌技术': 50, '遗传的分子基础': 51, '内质网的结构和功能': 52, '基因的自由组合规律的实质及应用': 53, '生态系统的营养结构': 54, '“重农抑商”政策': 55, '免疫系统的功能': 56, '生命活动离不开细胞': 57, '蛋白质的合成': 58, '稳态与环境': 59, '不完全显性': 60, '夏商两代的政治制度': 61, '走进细胞': 62, '中心体的结构和功能': 63, '细胞的多样性和统一性': 64, '胚胎移植': 65, '群落的结构': 66, '免疫系统的组成': 67, '生物技术在其他方面的应用': 68, '经济学常识': 69, '生物': 70, '组成细胞的化学元素': 71, '核糖体的结构和功能': 72, '器官移植': 73, '时事政治': 74, '分子与细胞': 75, '血糖平衡的调节': 76, '减数分裂与有丝分裂的比较': 77, '垄断组织的出现': 78, '细胞大小与物质运输的关系': 79, '生物技术实践': 80, '科学社会主义常识': 81, '人体的体温调节': 82, '历史': 83, '现代生物技术专题': 84, '兴奋在神经元之间的传递': 85, '人口迁移与人口流动': 86, '现代史': 87, '地球与地图': 88, '溶酶体的结构和功能': 89, '体液免疫的概念和过程': 90, '地球所处的宇宙环境': 91, '人体免疫系统在维持稳态中的作用': 92, '与细胞分裂有关的细胞器': 93, '公民道德与伦理常识': 94, '工业区位因素': 95, '地理': 96}
# [2020-03-27 13:03:47,542] [    INFO] - Checkpoint dir: ckpt_20200327130347
# 2020-03-27 13:03:48,930-WARNING: paddle.fluid.layers.py_reader() may be deprecated in the near future. Please use paddle.fluid.io.DataLoader.from_generator() instead.
# [2020-03-27 13:03:49,748] [    INFO] - Strategy with scheduler: {'warmup': 0.0, 'linear_decay': {'start_point': 0.0, 'end_learning_rate': 0}, 'noam_decay': False, 'discriminative': {'blocks': 0, 'factor': 2.6}, 'gradual_unfreeze': 0, 'slanted_triangle': {'cut_fraction': 0.0, 'ratio': 32}}, regularization: {'L2': 0.0, 'L2SP': 0.0, 'weight_decay': 0.01} and clip: {'GlobalNorm': 1.0, 'Norm': 0.0}
# [2020-03-27 13:10:06,276] [    INFO] - Try loading checkpoint from ckpt_20200327130347/ckpt.meta
# [2020-03-27 13:10:06,278] [    INFO] - PaddleHub model checkpoint not found, start from scratch...
# [2020-03-27 13:10:06,429] [    INFO] - PaddleHub finetune start
# [2020-03-27 13:12:45,223] [   TRAIN] - step 200 / 2981: loss=5.75600 auc=0.68228 auc_宇宙中的地球=0.86228 auc_地球运动的基本形式=0.66317 auc_地球的内部圈层结构及特点=0.57054 auc_社会主义是中国人民的历史性选择=0.58367 auc_减数分裂的概念=0.75912 auc_基因的分离规律的实质及应用=0.70397 auc_组成细胞的化合物=0.68477 auc_基因工程的概念=0.70310 auc_人体水盐平衡调节=0.58831 auc_拉马克的进化学说=0.62043 auc_地球的外部圈层结构及特点=0.57496 auc_人口增长与人口问题=0.50682 auc_生产活动与地域联系=0.66354 auc_复等位基因=0.75028 auc_液泡的结构和功能=0.77776 auc_人口与城市=0.75106 auc_兴奋在神经纤维上的传导=0.56408 auc_郡县制=0.82604 auc_第三产业的兴起和“新经济”的出现=0.54993 auc_太阳对地球的影响=0.61053 auc_区域可持续发展=0.52833 auc_基因工程的原理及技术=0.76148 auc_社会主义市场经济的伦理要求=0.73531 auc_地球运动的地理意义=0.71041 auc_皇帝制度=0.79654 auc_遗传与进化=0.66156 auc_生物科学与社会=0.86835 auc_中央官制——三公九卿制=0.80831 auc_避孕的原理和方法=0.91526 auc_激素调节=0.48987 auc_近代史=0.71389 auc_生物工程技术=0.60904 auc_内环境的稳态=0.70732 auc_细胞有丝分裂不同时期的特点=0.68093 auc_清末民主革命风潮=0.61039 auc_高尔基体的结构和功能=0.71494 auc_伴性遗传=0.68090 auc_文艺的春天=0.73895 auc_神经调节和体液调节的比较=0.58285 auc_海峡两岸关系的发展=0.65193 auc_科学思维常识=0.48219 auc_遗传的细胞基础=0.87079 auc_劳动就业与守法经营=0.70205 auc_古代史=0.77815 auc_政治=0.84861 auc_农业区位因素=0.48588 auc_选官、用官制度的变化=0.77462 auc_生活中的法律常识=0.53985 auc_人工授精、试管婴儿等生殖技术=0.91704 auc_生物性污染=0.89721 auc_培养基与无菌技术=0.65578 auc_遗传的分子基础=0.87014 auc_内质网的结构和功能=0.75470 auc_基因的自由组合规律的实质及应用=0.77640 auc_生态系统的营养结构=0.40153 auc_“重农抑商”政策=0.75990 auc_免疫系统的功能=0.68313 auc_生命活动离不开细胞=0.65951 auc_蛋白质的合成=0.60005 auc_稳态与环境=0.77056 auc_不完全显性=0.61557 auc_夏商两代的政治制度=0.81884 auc_走进细胞=0.70209 auc_中心体的结构和功能=0.75016 auc_细胞的多样性和统一性=0.70506 auc_胚胎移植=0.54721 auc_群落的结构=0.51373 auc_免疫系统的组成=0.71410 auc_生物技术在其他方面的应用=0.77534 auc_经济学常识=0.53708 auc_生物=0.96403 auc_组成细胞的化学元素=0.68560 auc_核糖体的结构和功能=0.75366 auc_器官移植=0.59485 auc_时事政治=0.37734 auc_分子与细胞=0.77313 auc_血糖平衡的调节=0.52737 auc_减数分裂与有丝分裂的比较=0.78963 auc_垄断组织的出现=0.55348 auc_细胞大小与物质运输的关系=0.51826 auc_生物技术实践=0.63220 auc_科学社会主义常识=0.70029 auc_人体的体温调节=0.57271 auc_历史=0.85129 auc_现代生物技术专题=0.67850 auc_兴奋在神经元之间的传递=0.59251 auc_人口迁移与人口流动=0.58314 auc_现代史=0.74498 auc_地球与地图=0.54173 auc_溶酶体的结构和功能=0.71826 auc_体液免疫的概念和过程=0.67978 auc_地球所处的宇宙环境=0.54532 auc_人体免疫系统在维持稳态中的作用=0.72883 auc_与细胞分裂有关的细胞器=0.67900 auc_公民道德与伦理常识=0.77958 auc_工业区位因素=0.50834 auc_地理=0.91955 [step/sec: 1.26]
# [2020-03-27 13:12:45,225] [    INFO] - Evaluation on dev dataset start
# 2020-03-27 13:12:48,271-WARNING: paddle.fluid.layers.py_reader() may be deprecated in the near future. Please use paddle.fluid.io.DataLoader.from_generator() instead.
# share_vars_from is set, scope is ignored.
# [2020-03-27 13:13:30,619] [    EVAL] - [dev dataset evaluation result] loss=2.73636 auc=0.78753 auc_宇宙中的地球=0.93645 auc_地球运动的基本形式=0.76913 auc_地球的内部圈层结构及特点=0.72883 auc_社会主义是中国人民的历史性选择=0.68891 auc_减数分裂的概念=0.86185 auc_基因的分离规律的实质及应用=0.81556 auc_组成细胞的化合物=0.80890 auc_基因工程的概念=0.85312 auc_人体水盐平衡调节=0.70692 auc_拉马克的进化学说=0.70505 auc_地球的外部圈层结构及特点=0.74480 auc_人口增长与人口问题=0.59476 auc_生产活动与地域联系=0.80577 auc_复等位基因=0.88579 auc_液泡的结构和功能=0.89731 auc_人口与城市=0.86998 auc_兴奋在神经纤维上的传导=0.72326 auc_郡县制=0.93311 auc_第三产业的兴起和“新经济”的出现=0.61535 auc_太阳对地球的影响=0.73504 auc_区域可持续发展=0.35521 auc_基因工程的原理及技术=0.88756 auc_社会主义市场经济的伦理要求=0.86263 auc_地球运动的地理意义=0.82842 auc_皇帝制度=0.91332 auc_遗传与进化=0.75902 auc_生物科学与社会=0.91859 auc_中央官制——三公九卿制=0.92373 auc_避孕的原理和方法=0.96484 auc_激素调节=0.60127 auc_近代史=0.83992 auc_生物工程技术=0.75325 auc_内环境的稳态=0.84051 auc_细胞有丝分裂不同时期的特点=0.77760 auc_清末民主革命风潮=0.73478 auc_高尔基体的结构和功能=0.86100 auc_伴性遗传=0.78269 auc_文艺的春天=0.82523 auc_神经调节和体液调节的比较=0.72510 auc_海峡两岸关系的发展=0.77502 auc_科学思维常识=0.47267 auc_遗传的细胞基础=0.93884 auc_劳动就业与守法经营=0.82681 auc_古代史=0.89650 auc_政治=0.93665 auc_农业区位因素=0.62362 auc_选官、用官制度的变化=0.88539 auc_生活中的法律常识=0.62754 auc_人工授精、试管婴儿等生殖技术=0.96522 auc_生物性污染=0.95834 auc_培养基与无菌技术=0.80209 auc_遗传的分子基础=0.94194 auc_内质网的结构和功能=0.88144 auc_基因的自由组合规律的实质及应用=0.86657 auc_生态系统的营养结构=0.48065 auc_“重农抑商”政策=0.90741 auc_免疫系统的功能=0.83990 auc_生命活动离不开细胞=0.74579 auc_蛋白质的合成=0.74093 auc_稳态与环境=0.88958 auc_不完全显性=0.70813 auc_夏商两代的政治制度=0.92799 auc_走进细胞=0.82164 auc_中心体的结构和功能=0.88319 auc_细胞的多样性和统一性=0.81976 auc_胚胎移植=0.71417 auc_群落的结构=0.56050 auc_免疫系统的组成=0.85221 auc_生物技术在其他方面的应用=0.88662 auc_经济学常识=0.65232 auc_生物=0.98762 auc_组成细胞的化学元素=0.82067 auc_核糖体的结构和功能=0.88557 auc_器官移植=0.73443 auc_时事政治=0.37550 auc_分子与细胞=0.87618 auc_血糖平衡的调节=0.63472 auc_减数分裂与有丝分裂的比较=0.89548 auc_垄断组织的出现=0.65460 auc_细胞大小与物质运输的关系=0.59913 auc_生物技术实践=0.76827 auc_科学社会主义常识=0.80173 auc_人体的体温调节=0.71119 auc_历史=0.94717 auc_现代生物技术专题=0.80701 auc_兴奋在神经元之间的传递=0.74177 auc_人口迁移与人口流动=0.71049 auc_现代史=0.85383 auc_地球与地图=0.52454 auc_溶酶体的结构和功能=0.85427 auc_体液免疫的概念和过程=0.83044 auc_地球所处的宇宙环境=0.67318 auc_人体免疫系统在维持稳态中的作用=0.86539 auc_与细胞分裂有关的细胞器=0.81238 auc_公民道德与伦理常识=0.89121 auc_工业区位因素=0.49789 auc_地理=0.97153 [step/sec: 3.62]
# [2020-03-27 13:13:30,620] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.78753]
# 2020-03-27 13:13:33,006-WARNING: paddle.fluid.layers.py_reader() may be deprecated in the near future. Please use paddle.fluid.io.DataLoader.from_generator() instead.
# [2020-03-27 13:16:11,715] [   TRAIN] - step 400 / 2981: loss=2.29750 auc=0.84973 auc_宇宙中的地球=0.96916 auc_地球运动的基本形式=0.83850 auc_地球的内部圈层结构及特点=0.81350 auc_社会主义是中国人民的历史性选择=0.78097 auc_减数分裂的概念=0.91087 auc_基因的分离规律的实质及应用=0.88437 auc_组成细胞的化合物=0.87114 auc_基因工程的概念=0.91364 auc_人体水盐平衡调节=0.78899 auc_拉马克的进化学说=0.73728 auc_地球的外部圈层结构及特点=0.83145 auc_人口增长与人口问题=0.69754 auc_生产活动与地域联系=0.88990 auc_复等位基因=0.93257 auc_液泡的结构和功能=0.94186 auc_人口与城市=0.92678 auc_兴奋在神经纤维上的传导=0.82479 auc_郡县制=0.96782 auc_第三产业的兴起和“新经济”的出现=0.72492 auc_太阳对地球的影响=0.83493 auc_区域可持续发展=0.35860 auc_基因工程的原理及技术=0.93394 auc_社会主义市场经济的伦理要求=0.91729 auc_地球运动的地理意义=0.89127 auc_皇帝制度=0.95835 auc_遗传与进化=0.80844 auc_生物科学与社会=0.93720 auc_中央官制——三公九卿制=0.96339 auc_避孕的原理和方法=0.97998 auc_激素调节=0.70647 auc_近代史=0.88924 auc_生物工程技术=0.84306 auc_内环境的稳态=0.90060 auc_细胞有丝分裂不同时期的特点=0.83737 auc_清末民主革命风潮=0.80339 auc_高尔基体的结构和功能=0.92238 auc_伴性遗传=0.83976 auc_文艺的春天=0.86297 auc_神经调节和体液调节的比较=0.82089 auc_海峡两岸关系的发展=0.82857 auc_科学思维常识=0.56892 auc_遗传的细胞基础=0.96337 auc_劳动就业与守法经营=0.88925 auc_古代史=0.94113 auc_政治=0.96940 auc_农业区位因素=0.74002 auc_选官、用官制度的变化=0.93100 auc_生活中的法律常识=0.69015 auc_人工授精、试管婴儿等生殖技术=0.98016 auc_生物性污染=0.97671 auc_培养基与无菌技术=0.87659 auc_遗传的分子基础=0.96660 auc_内质网的结构和功能=0.93319 auc_基因的自由组合规律的实质及应用=0.90916 auc_生态系统的营养结构=0.56411 auc_“重农抑商”政策=0.95722 auc_免疫系统的功能=0.90778 auc_生命活动离不开细胞=0.79896 auc_蛋白质的合成=0.82213 auc_稳态与环境=0.93650 auc_不完全显性=0.76517 auc_夏商两代的政治制度=0.96486 auc_走进细胞=0.88895 auc_中心体的结构和功能=0.93421 auc_细胞的多样性和统一性=0.88379 auc_胚胎移植=0.80915 auc_群落的结构=0.63965 auc_免疫系统的组成=0.91445 auc_生物技术在其他方面的应用=0.93451 auc_经济学常识=0.76837 auc_生物=0.99475 auc_组成细胞的化学元素=0.88209 auc_核糖体的结构和功能=0.93544 auc_器官移植=0.82353 auc_时事政治=0.41544 auc_分子与细胞=0.91984 auc_血糖平衡的调节=0.72542 auc_减数分裂与有丝分裂的比较=0.93745 auc_垄断组织的出现=0.76118 auc_细胞大小与物质运输的关系=0.65652 auc_生物技术实践=0.85009 auc_科学社会主义常识=0.86640 auc_人体的体温调节=0.78227 auc_历史=0.97656 auc_现代生物技术专题=0.86602 auc_兴奋在神经元之间的传递=0.82797 auc_人口迁移与人口流动=0.78596 auc_现代史=0.90672 auc_地球与地图=0.62336 auc_溶酶体的结构和功能=0.92046 auc_体液免疫的概念和过程=0.90218 auc_地球所处的宇宙环境=0.78411 auc_人体免疫系统在维持稳态中的作用=0.92120 auc_与细胞分裂有关的细胞器=0.88241 auc_公民道德与伦理常识=0.93671 auc_工业区位因素=0.64247 auc_地理=0.98795 [step/sec: 1.28]
# [2020-03-27 13:16:11,717] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:16:53,254] [    EVAL] - [dev dataset evaluation result] loss=1.77212 auc=0.88187 auc_宇宙中的地球=0.97853 auc_地球运动的基本形式=0.87174 auc_地球的内部圈层结构及特点=0.87060 auc_社会主义是中国人民的历史性选择=0.82895 auc_减数分裂的概念=0.93207 auc_基因的分离规律的实质及应用=0.91147 auc_组成细胞的化合物=0.90270 auc_基因工程的概念=0.93926 auc_人体水盐平衡调节=0.83646 auc_拉马克的进化学说=0.76723 auc_地球的外部圈层结构及特点=0.88177 auc_人口增长与人口问题=0.77497 auc_生产活动与地域联系=0.92247 auc_复等位基因=0.95164 auc_液泡的结构和功能=0.96016 auc_人口与城市=0.95115 auc_兴奋在神经纤维上的传导=0.87408 auc_郡县制=0.97730 auc_第三产业的兴起和“新经济”的出现=0.79342 auc_太阳对地球的影响=0.87875 auc_区域可持续发展=0.40958 auc_基因工程的原理及技术=0.95269 auc_社会主义市场经济的伦理要求=0.93942 auc_地球运动的地理意义=0.91917 auc_皇帝制度=0.97114 auc_遗传与进化=0.83509 auc_生物科学与社会=0.94469 auc_中央官制——三公九卿制=0.97418 auc_避孕的原理和方法=0.98569 auc_激素调节=0.76790 auc_近代史=0.91403 auc_生物工程技术=0.89096 auc_内环境的稳态=0.92529 auc_细胞有丝分裂不同时期的特点=0.86378 auc_清末民主革命风潮=0.84425 auc_高尔基体的结构和功能=0.94780 auc_伴性遗传=0.86553 auc_文艺的春天=0.88335 auc_神经调节和体液调节的比较=0.86424 auc_海峡两岸关系的发展=0.85966 auc_科学思维常识=0.64382 auc_遗传的细胞基础=0.97427 auc_劳动就业与守法经营=0.91627 auc_古代史=0.95519 auc_政治=0.97940 auc_农业区位因素=0.80296 auc_选官、用官制度的变化=0.95164 auc_生活中的法律常识=0.75178 auc_人工授精、试管婴儿等生殖技术=0.98545 auc_生物性污染=0.98321 auc_培养基与无菌技术=0.91013 auc_遗传的分子基础=0.97590 auc_内质网的结构和功能=0.95499 auc_基因的自由组合规律的实质及应用=0.92806 auc_生态系统的营养结构=0.64206 auc_“重农抑商”政策=0.97030 auc_免疫系统的功能=0.93427 auc_生命活动离不开细胞=0.82926 auc_蛋白质的合成=0.86491 auc_稳态与环境=0.95275 auc_不完全显性=0.81686 auc_夏商两代的政治制度=0.97565 auc_走进细胞=0.91726 auc_中心体的结构和功能=0.95494 auc_细胞的多样性和统一性=0.91399 auc_胚胎移植=0.85887 auc_群落的结构=0.70480 auc_免疫系统的组成=0.93924 auc_生物技术在其他方面的应用=0.95332 auc_经济学常识=0.82361 auc_生物=0.99671 auc_组成细胞的化学元素=0.91218 auc_核糖体的结构和功能=0.95601 auc_器官移植=0.86907 auc_时事政治=0.42076 auc_分子与细胞=0.93697 auc_血糖平衡的调节=0.78236 auc_减数分裂与有丝分裂的比较=0.95390 auc_垄断组织的出现=0.81738 auc_细胞大小与物质运输的关系=0.70844 auc_生物技术实践=0.89257 auc_科学社会主义常识=0.89331 auc_人体的体温调节=0.82287 auc_历史=0.98495 auc_现代生物技术专题=0.89312 auc_兴奋在神经元之间的传递=0.87373 auc_人口迁移与人口流动=0.83370 auc_现代史=0.92374 auc_地球与地图=0.70292 auc_溶酶体的结构和功能=0.94682 auc_体液免疫的概念和过程=0.93223 auc_地球所处的宇宙环境=0.83131 auc_人体免疫系统在维持稳态中的作用=0.94267 auc_与细胞分裂有关的细胞器=0.91682 auc_公民道德与伦理常识=0.95275 auc_工业区位因素=0.72362 auc_地理=0.99205 [step/sec: 3.61]
# [2020-03-27 13:16:53,256] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.88187]
# [2020-03-27 13:19:32,668] [   TRAIN] - step 600 / 2981: loss=1.59302 auc=0.90702 auc_宇宙中的地球=0.98525 auc_地球运动的基本形式=0.89733 auc_地球的内部圈层结构及特点=0.91610 auc_社会主义是中国人民的历史性选择=0.87469 auc_减数分裂的概念=0.94958 auc_基因的分离规律的实质及应用=0.92552 auc_组成细胞的化合物=0.92542 auc_基因工程的概念=0.95721 auc_人体水盐平衡调节=0.87149 auc_拉马克的进化学说=0.79201 auc_地球的外部圈层结构及特点=0.92228 auc_人口增长与人口问题=0.82219 auc_生产活动与地域联系=0.94596 auc_复等位基因=0.96519 auc_液泡的结构和功能=0.96933 auc_人口与城市=0.96532 auc_兴奋在神经纤维上的传导=0.90897 auc_郡县制=0.98336 auc_第三产业的兴起和“新经济”的出现=0.84380 auc_太阳对地球的影响=0.91559 auc_区域可持续发展=0.48186 auc_基因工程的原理及技术=0.96621 auc_社会主义市场经济的伦理要求=0.95640 auc_地球运动的地理意义=0.94077 auc_皇帝制度=0.97929 auc_遗传与进化=0.85531 auc_生物科学与社会=0.95131 auc_中央官制——三公九卿制=0.98155 auc_避孕的原理和方法=0.98907 auc_激素调节=0.83155 auc_近代史=0.92826 auc_生物工程技术=0.92233 auc_内环境的稳态=0.94558 auc_细胞有丝分裂不同时期的特点=0.88616 auc_清末民主革命风潮=0.87486 auc_高尔基体的结构和功能=0.96067 auc_伴性遗传=0.88519 auc_文艺的春天=0.90746 auc_神经调节和体液调节的比较=0.89787 auc_海峡两岸关系的发展=0.88892 auc_科学思维常识=0.70363 auc_遗传的细胞基础=0.97953 auc_劳动就业与守法经营=0.93597 auc_古代史=0.96328 auc_政治=0.98550 auc_农业区位因素=0.85504 auc_选官、用官制度的变化=0.96370 auc_生活中的法律常识=0.79967 auc_人工授精、试管婴儿等生殖技术=0.98883 auc_生物性污染=0.98729 auc_培养基与无菌技术=0.93383 auc_遗传的分子基础=0.98052 auc_内质网的结构和功能=0.96552 auc_基因的自由组合规律的实质及应用=0.94160 auc_生态系统的营养结构=0.72186 auc_“重农抑商”政策=0.97885 auc_免疫系统的功能=0.95468 auc_生命活动离不开细胞=0.86171 auc_蛋白质的合成=0.89974 auc_稳态与环境=0.96439 auc_不完全显性=0.85997 auc_夏商两代的政治制度=0.98186 auc_走进细胞=0.93312 auc_中心体的结构和功能=0.96515 auc_细胞的多样性和统一性=0.93201 auc_胚胎移植=0.89628 auc_群落的结构=0.76405 auc_免疫系统的组成=0.95810 auc_生物技术在其他方面的应用=0.96620 auc_经济学常识=0.86499 auc_生物=0.99796 auc_组成细胞的化学元素=0.93244 auc_核糖体的结构和功能=0.96616 auc_器官移植=0.90056 auc_时事政治=0.44266 auc_分子与细胞=0.95149 auc_血糖平衡的调节=0.82794 auc_减数分裂与有丝分裂的比较=0.96534 auc_垄断组织的出现=0.86011 auc_细胞大小与物质运输的关系=0.75555 auc_生物技术实践=0.91867 auc_科学社会主义常识=0.91919 auc_人体的体温调节=0.85402 auc_历史=0.99004 auc_现代生物技术专题=0.91275 auc_兴奋在神经元之间的传递=0.90676 auc_人口迁移与人口流动=0.87187 auc_现代史=0.93739 auc_地球与地图=0.76735 auc_溶酶体的结构和功能=0.95973 auc_体液免疫的概念和过程=0.95402 auc_地球所处的宇宙环境=0.87892 auc_人体免疫系统在维持稳态中的作用=0.95980 auc_与细胞分裂有关的细胞器=0.93649 auc_公民道德与伦理常识=0.96438 auc_工业区位因素=0.80124 auc_地理=0.99446 [step/sec: 1.22]
# [2020-03-27 13:19:32,698] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:20:14,670] [    EVAL] - [dev dataset evaluation result] loss=1.42642 auc=0.92128 auc_宇宙中的地球=0.98834 auc_地球运动的基本形式=0.91246 auc_地球的内部圈层结构及特点=0.93375 auc_社会主义是中国人民的历史性选择=0.89880 auc_减数分裂的概念=0.95834 auc_基因的分离规律的实质及应用=0.93331 auc_组成细胞的化合物=0.93851 auc_基因工程的概念=0.96483 auc_人体水盐平衡调节=0.89242 auc_拉马克的进化学说=0.82026 auc_地球的外部圈层结构及特点=0.93801 auc_人口增长与人口问题=0.85420 auc_生产活动与地域联系=0.95570 auc_复等位基因=0.97161 auc_液泡的结构和功能=0.97549 auc_人口与城市=0.97198 auc_兴奋在神经纤维上的传导=0.92676 auc_郡县制=0.98595 auc_第三产业的兴起和“新经济”的出现=0.87415 auc_太阳对地球的影响=0.93328 auc_区域可持续发展=0.54560 auc_基因工程的原理及技术=0.97205 auc_社会主义市场经济的伦理要求=0.96445 auc_地球运动的地理意义=0.95020 auc_皇帝制度=0.98292 auc_遗传与进化=0.87019 auc_生物科学与社会=0.95583 auc_中央官制——三公九卿制=0.98478 auc_避孕的原理和方法=0.99092 auc_激素调节=0.86204 auc_近代史=0.93776 auc_生物工程技术=0.93880 auc_内环境的稳态=0.95303 auc_细胞有丝分裂不同时期的特点=0.90279 auc_清末民主革命风潮=0.89415 auc_高尔基体的结构和功能=0.96895 auc_伴性遗传=0.89523 auc_文艺的春天=0.92217 auc_神经调节和体液调节的比较=0.91229 auc_海峡两岸关系的发展=0.90507 auc_科学思维常识=0.75128 auc_遗传的细胞基础=0.98281 auc_劳动就业与守法经营=0.94537 auc_古代史=0.96679 auc_政治=0.98874 auc_农业区位因素=0.87896 auc_选官、用官制度的变化=0.97014 auc_生活中的法律常识=0.83295 auc_人工授精、试管婴儿等生殖技术=0.99065 auc_生物性污染=0.98943 auc_培养基与无菌技术=0.94574 auc_遗传的分子基础=0.98349 auc_内质网的结构和功能=0.97260 auc_基因的自由组合规律的实质及应用=0.94726 auc_生态系统的营养结构=0.76663 auc_“重农抑商”政策=0.98263 auc_免疫系统的功能=0.96135 auc_生命活动离不开细胞=0.88248 auc_蛋白质的合成=0.91667 auc_稳态与环境=0.97066 auc_不完全显性=0.88123 auc_夏商两代的政治制度=0.98455 auc_走进细胞=0.94401 auc_中心体的结构和功能=0.97203 auc_细胞的多样性和统一性=0.94475 auc_胚胎移植=0.91723 auc_群落的结构=0.80157 auc_免疫系统的组成=0.96422 auc_生物技术在其他方面的应用=0.97270 auc_经济学常识=0.88505 auc_生物=0.99847 auc_组成细胞的化学元素=0.94413 auc_核糖体的结构和功能=0.97292 auc_器官移植=0.91999 auc_时事政治=0.47394 auc_分子与细胞=0.95997 auc_血糖平衡的调节=0.85640 auc_减数分裂与有丝分裂的比较=0.97102 auc_垄断组织的出现=0.88688 auc_细胞大小与物质运输的关系=0.78063 auc_生物技术实践=0.93290 auc_科学社会主义常识=0.93564 auc_人体的体温调节=0.87649 auc_历史=0.99235 auc_现代生物技术专题=0.92384 auc_兴奋在神经元之间的传递=0.92442 auc_人口迁移与人口流动=0.89197 auc_现代史=0.94340 auc_地球与地图=0.80510 auc_溶酶体的结构和功能=0.96810 auc_体液免疫的概念和过程=0.96132 auc_地球所处的宇宙环境=0.89968 auc_人体免疫系统在维持稳态中的作用=0.96502 auc_与细胞分裂有关的细胞器=0.94901 auc_公民道德与伦理常识=0.97010 auc_工业区位因素=0.83313 auc_地理=0.99572 [step/sec: 3.58]
# [2020-03-27 13:20:14,672] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.92128]
# [2020-03-27 13:22:53,101] [   TRAIN] - step 800 / 2981: loss=1.31001 auc=0.93514 auc_宇宙中的地球=0.99140 auc_地球运动的基本形式=0.92663 auc_地球的内部圈层结构及特点=0.95071 auc_社会主义是中国人民的历史性选择=0.92295 auc_减数分裂的概念=0.96555 auc_基因的分离规律的实质及应用=0.93994 auc_组成细胞的化合物=0.94954 auc_基因工程的概念=0.97092 auc_人体水盐平衡调节=0.91285 auc_拉马克的进化学说=0.84306 auc_地球的外部圈层结构及特点=0.95280 auc_人口增长与人口问题=0.88484 auc_生产活动与地域联系=0.96582 auc_复等位基因=0.97600 auc_液泡的结构和功能=0.97966 auc_人口与城市=0.97869 auc_兴奋在神经纤维上的传导=0.94583 auc_郡县制=0.98923 auc_第三产业的兴起和“新经济”的出现=0.90063 auc_太阳对地球的影响=0.95068 auc_区域可持续发展=0.59355 auc_基因工程的原理及技术=0.97651 auc_社会主义市场经济的伦理要求=0.97227 auc_地球运动的地理意义=0.96048 auc_皇帝制度=0.98701 auc_遗传与进化=0.88208 auc_生物科学与社会=0.95932 auc_中央官制——三公九卿制=0.98843 auc_避孕的原理和方法=0.99245 auc_激素调节=0.89645 auc_近代史=0.94531 auc_生物工程技术=0.95135 auc_内环境的稳态=0.96229 auc_细胞有丝分裂不同时期的特点=0.91929 auc_清末民主革命风潮=0.91138 auc_高尔基体的结构和功能=0.97461 auc_伴性遗传=0.90775 auc_文艺的春天=0.93671 auc_神经调节和体液调节的比较=0.92799 auc_海峡两岸关系的发展=0.92478 auc_科学思维常识=0.79841 auc_遗传的细胞基础=0.98538 auc_劳动就业与守法经营=0.95512 auc_古代史=0.97098 auc_政治=0.99173 auc_农业区位因素=0.90255 auc_选官、用官制度的变化=0.97639 auc_生活中的法律常识=0.86134 auc_人工授精、试管婴儿等生殖技术=0.99223 auc_生物性污染=0.99127 auc_培养基与无菌技术=0.95706 auc_遗传的分子基础=0.98568 auc_内质网的结构和功能=0.97724 auc_基因的自由组合规律的实质及应用=0.95207 auc_生态系统的营养结构=0.81849 auc_“重农抑商”政策=0.98679 auc_免疫系统的功能=0.97006 auc_生命活动离不开细胞=0.90154 auc_蛋白质的合成=0.93342 auc_稳态与环境=0.97711 auc_不完全显性=0.90650 auc_夏商两代的政治制度=0.98818 auc_走进细胞=0.95267 auc_中心体的结构和功能=0.97663 auc_细胞的多样性和统一性=0.95120 auc_胚胎移植=0.93678 auc_群落的结构=0.84117 auc_免疫系统的组成=0.97235 auc_生物技术在其他方面的应用=0.97837 auc_经济学常识=0.90547 auc_生物=0.99892 auc_组成细胞的化学元素=0.95371 auc_核糖体的结构和功能=0.97743 auc_器官移植=0.93821 auc_时事政治=0.52300 auc_分子与细胞=0.96654 auc_血糖平衡的调节=0.88518 auc_减数分裂与有丝分裂的比较=0.97566 auc_垄断组织的出现=0.90974 auc_细胞大小与物质运输的关系=0.80859 auc_生物技术实践=0.94279 auc_科学社会主义常识=0.95182 auc_人体的体温调节=0.89923 auc_历史=0.99437 auc_现代生物技术专题=0.93537 auc_兴奋在神经元之间的传递=0.94390 auc_人口迁移与人口流动=0.91532 auc_现代史=0.95015 auc_地球与地图=0.84162 auc_溶酶体的结构和功能=0.97365 auc_体液免疫的概念和过程=0.97027 auc_地球所处的宇宙环境=0.92376 auc_人体免疫系统在维持稳态中的作用=0.97255 auc_与细胞分裂有关的细胞器=0.95850 auc_公民道德与伦理常识=0.97549 auc_工业区位因素=0.86431 auc_地理=0.99693 [step/sec: 1.27]
# [2020-03-27 13:22:53,102] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:23:34,673] [    EVAL] - [dev dataset evaluation result] loss=1.20060 auc=0.94255 auc_宇宙中的地球=0.99274 auc_地球运动的基本形式=0.93556 auc_地球的内部圈层结构及特点=0.95985 auc_社会主义是中国人民的历史性选择=0.93482 auc_减数分裂的概念=0.96941 auc_基因的分离规律的实质及应用=0.94514 auc_组成细胞的化合物=0.95612 auc_基因工程的概念=0.97457 auc_人体水盐平衡调节=0.92434 auc_拉马克的进化学说=0.85928 auc_地球的外部圈层结构及特点=0.96134 auc_人口增长与人口问题=0.90272 auc_生产活动与地域联系=0.97026 auc_复等位基因=0.97910 auc_液泡的结构和功能=0.98041 auc_人口与城市=0.98210 auc_兴奋在神经纤维上的传导=0.95400 auc_郡县制=0.98904 auc_第三产业的兴起和“新经济”的出现=0.91723 auc_太阳对地球的影响=0.95906 auc_区域可持续发展=0.62641 auc_基因工程的原理及技术=0.97931 auc_社会主义市场经济的伦理要求=0.97642 auc_地球运动的地理意义=0.96560 auc_皇帝制度=0.98709 auc_遗传与进化=0.89132 auc_生物科学与社会=0.96235 auc_中央官制——三公九卿制=0.98881 auc_避孕的原理和方法=0.99346 auc_激素调节=0.91113 auc_近代史=0.95028 auc_生物工程技术=0.95880 auc_内环境的稳态=0.96529 auc_细胞有丝分裂不同时期的特点=0.92604 auc_清末民主革命风潮=0.92202 auc_高尔基体的结构和功能=0.97592 auc_伴性遗传=0.91586 auc_文艺的春天=0.94457 auc_神经调节和体液调节的比较=0.93458 auc_海峡两岸关系的发展=0.93416 auc_科学思维常识=0.82591 auc_遗传的细胞基础=0.98729 auc_劳动就业与守法经营=0.96184 auc_古代史=0.97101 auc_政治=0.99296 auc_农业区位因素=0.91360 auc_选官、用官制度的变化=0.97846 auc_生活中的法律常识=0.87971 auc_人工授精、试管婴儿等生殖技术=0.99325 auc_生物性污染=0.99241 auc_培养基与无菌技术=0.96247 auc_遗传的分子基础=0.98735 auc_内质网的结构和功能=0.97799 auc_基因的自由组合规律的实质及应用=0.95572 auc_生态系统的营养结构=0.83920 auc_“重农抑商”政策=0.98716 auc_免疫系统的功能=0.97323 auc_生命活动离不开细胞=0.91019 auc_蛋白质的合成=0.94199 auc_稳态与环境=0.97895 auc_不完全显性=0.92008 auc_夏商两代的政治制度=0.98808 auc_走进细胞=0.95359 auc_中心体的结构和功能=0.97742 auc_细胞的多样性和统一性=0.95543 auc_胚胎移植=0.94594 auc_群落的结构=0.86267 auc_免疫系统的组成=0.97522 auc_生物技术在其他方面的应用=0.98101 auc_经济学常识=0.91789 auc_生物=0.99911 auc_组成细胞的化学元素=0.95944 auc_核糖体的结构和功能=0.97838 auc_器官移植=0.94717 auc_时事政治=0.57297 auc_分子与细胞=0.97065 auc_血糖平衡的调节=0.90002 auc_减数分裂与有丝分裂的比较=0.97859 auc_垄断组织的出现=0.92449 auc_细胞大小与物质运输的关系=0.82188 auc_生物技术实践=0.94925 auc_科学社会主义常识=0.95726 auc_人体的体温调节=0.91139 auc_历史=0.99531 auc_现代生物技术专题=0.94001 auc_兴奋在神经元之间的传递=0.95240 auc_人口迁移与人口流动=0.92693 auc_现代史=0.95291 auc_地球与地图=0.86415 auc_溶酶体的结构和功能=0.97484 auc_体液免疫的概念和过程=0.97362 auc_地球所处的宇宙环境=0.93498 auc_人体免疫系统在维持稳态中的作用=0.97548 auc_与细胞分裂有关的细胞器=0.96219 auc_公民道德与伦理常识=0.97873 auc_工业区位因素=0.88347 auc_地理=0.99751 [step/sec: 3.61]
# [2020-03-27 13:23:34,674] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.94255]
# [2020-03-27 13:26:12,434] [   TRAIN] - step 1000 / 2981: loss=1.12709 auc=0.95025 auc_宇宙中的地球=0.99413 auc_地球运动的基本形式=0.94481 auc_地球的内部圈层结构及特点=0.96909 auc_社会主义是中国人民的历史性选择=0.94668 auc_减数分裂的概念=0.97281 auc_基因的分离规律的实质及应用=0.94915 auc_组成细胞的化合物=0.96085 auc_基因工程的概念=0.97841 auc_人体水盐平衡调节=0.93529 auc_拉马克的进化学说=0.87417 auc_地球的外部圈层结构及特点=0.96998 auc_人口增长与人口问题=0.91877 auc_生产活动与地域联系=0.97518 auc_复等位基因=0.98195 auc_液泡的结构和功能=0.98253 auc_人口与城市=0.98541 auc_兴奋在神经纤维上的传导=0.96102 auc_郡县制=0.99100 auc_第三产业的兴起和“新经济”的出现=0.93234 auc_太阳对地球的影响=0.96777 auc_区域可持续发展=0.65456 auc_基因工程的原理及技术=0.98219 auc_社会主义市场经济的伦理要求=0.98067 auc_地球运动的地理意义=0.97079 auc_皇帝制度=0.98954 auc_遗传与进化=0.90120 auc_生物科学与社会=0.96453 auc_中央官制——三公九卿制=0.99094 auc_避孕的原理和方法=0.99425 auc_激素调节=0.92698 auc_近代史=0.95533 auc_生物工程技术=0.96362 auc_内环境的稳态=0.97036 auc_细胞有丝分裂不同时期的特点=0.93299 auc_清末民主革命风潮=0.93336 auc_高尔基体的结构和功能=0.97889 auc_伴性遗传=0.92262 auc_文艺的春天=0.95377 auc_神经调节和体液调节的比较=0.94423 auc_海峡两岸关系的发展=0.94500 auc_科学思维常识=0.85422 auc_遗传的细胞基础=0.98856 auc_劳动就业与守法经营=0.96756 auc_古代史=0.97476 auc_政治=0.99432 auc_农业区位因素=0.92525 auc_选官、用官制度的变化=0.98071 auc_生活中的法律常识=0.89841 auc_人工授精、试管婴儿等生殖技术=0.99407 auc_生物性污染=0.99335 auc_培养基与无菌技术=0.96781 auc_遗传的分子基础=0.98827 auc_内质网的结构和功能=0.98053 auc_基因的自由组合规律的实质及应用=0.95955 auc_生态系统的营养结构=0.86534 auc_“重农抑商”政策=0.98968 auc_免疫系统的功能=0.97720 auc_生命活动离不开细胞=0.92050 auc_蛋白质的合成=0.95119 auc_稳态与环境=0.98167 auc_不完全显性=0.93310 auc_夏商两代的政治制度=0.99038 auc_走进细胞=0.95638 auc_中心体的结构和功能=0.98007 auc_细胞的多样性和统一性=0.96236 auc_胚胎移植=0.95536 auc_群落的结构=0.88386 auc_免疫系统的组成=0.97888 auc_生物技术在其他方面的应用=0.98330 auc_经济学常识=0.92995 auc_生物=0.99929 auc_组成细胞的化学元素=0.96400 auc_核糖体的结构和功能=0.98079 auc_器官移植=0.95615 auc_时事政治=0.60802 auc_分子与细胞=0.97404 auc_血糖平衡的调节=0.91521 auc_减数分裂与有丝分裂的比较=0.98146 auc_垄断组织的出现=0.93794 auc_细胞大小与物质运输的关系=0.84072 auc_生物技术实践=0.95441 auc_科学社会主义常识=0.96485 auc_人体的体温调节=0.92397 auc_历史=0.99624 auc_现代生物技术专题=0.94523 auc_兴奋在神经元之间的传递=0.95967 auc_人口迁移与人口流动=0.93894 auc_现代史=0.95708 auc_地球与地图=0.88719 auc_溶酶体的结构和功能=0.97802 auc_体液免疫的概念和过程=0.97760 auc_地球所处的宇宙环境=0.94849 auc_人体免疫系统在维持稳态中的作用=0.97918 auc_与细胞分裂有关的细胞器=0.96760 auc_公民道德与伦理常识=0.98182 auc_工业区位因素=0.90465 auc_地理=0.99808 [step/sec: 1.28]
# [2020-03-27 13:26:12,435] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:26:53,957] [    EVAL] - [dev dataset evaluation result] loss=1.04904 auc=0.95486 auc_宇宙中的地球=0.99472 auc_地球运动的基本形式=0.95032 auc_地球的内部圈层结构及特点=0.97366 auc_社会主义是中国人民的历史性选择=0.95362 auc_减数分裂的概念=0.97517 auc_基因的分离规律的实质及应用=0.95204 auc_组成细胞的化合物=0.96411 auc_基因工程的概念=0.98049 auc_人体水盐平衡调节=0.94282 auc_拉马克的进化学说=0.88412 auc_地球的外部圈层结构及特点=0.97436 auc_人口增长与人口问题=0.92922 auc_生产活动与地域联系=0.97784 auc_复等位基因=0.98382 auc_液泡的结构和功能=0.98411 auc_人口与城市=0.98727 auc_兴奋在神经纤维上的传导=0.96588 auc_郡县制=0.99131 auc_第三产业的兴起和“新经济”的出现=0.94212 auc_太阳对地球的影响=0.97162 auc_区域可持续发展=0.68865 auc_基因工程的原理及技术=0.98375 auc_社会主义市场经济的伦理要求=0.98299 auc_地球运动的地理意义=0.97316 auc_皇帝制度=0.99008 auc_遗传与进化=0.90693 auc_生物科学与社会=0.96615 auc_中央官制——三公九卿制=0.99135 auc_避孕的原理和方法=0.99446 auc_激素调节=0.93491 auc_近代史=0.95858 auc_生物工程技术=0.96788 auc_内环境的稳态=0.97249 auc_细胞有丝分裂不同时期的特点=0.93604 auc_清末民主革命风潮=0.94029 auc_高尔基体的结构和功能=0.98092 auc_伴性遗传=0.92676 auc_文艺的春天=0.95950 auc_神经调节和体液调节的比较=0.95031 auc_海峡两岸关系的发展=0.95083 auc_科学思维常识=0.87169 auc_遗传的细胞基础=0.98957 auc_劳动就业与守法经营=0.97178 auc_古代史=0.97645 auc_政治=0.99500 auc_农业区位因素=0.93322 auc_选官、用官制度的变化=0.98228 auc_生活中的法律常识=0.91018 auc_人工授精、试管婴儿等生殖技术=0.99431 auc_生物性污染=0.99368 auc_培养基与无菌技术=0.97104 auc_遗传的分子基础=0.98915 auc_内质网的结构和功能=0.98232 auc_基因的自由组合规律的实质及应用=0.96185 auc_生态系统的营养结构=0.87770 auc_“重农抑商”政策=0.99024 auc_免疫系统的功能=0.97811 auc_生命活动离不开细胞=0.92636 auc_蛋白质的合成=0.95499 auc_稳态与环境=0.98317 auc_不完全显性=0.93993 auc_夏商两代的政治制度=0.99058 auc_走进细胞=0.95873 auc_中心体的结构和功能=0.98190 auc_细胞的多样性和统一性=0.96594 auc_胚胎移植=0.96089 auc_群落的结构=0.89604 auc_免疫系统的组成=0.97969 auc_生物技术在其他方面的应用=0.98463 auc_经济学常识=0.93826 auc_生物=0.99939 auc_组成细胞的化学元素=0.96682 auc_核糖体的结构和功能=0.98251 auc_器官移植=0.96157 auc_时事政治=0.62988 auc_分子与细胞=0.97647 auc_血糖平衡的调节=0.92550 auc_减数分裂与有丝分裂的比较=0.98305 auc_垄断组织的出现=0.94659 auc_细胞大小与物质运输的关系=0.85162 auc_生物技术实践=0.95789 auc_科学社会主义常识=0.96909 auc_人体的体温调节=0.93297 auc_历史=0.99673 auc_现代生物技术专题=0.94727 auc_兴奋在神经元之间的传递=0.96462 auc_人口迁移与人口流动=0.94617 auc_现代史=0.95956 auc_地球与地图=0.89842 auc_溶酶体的结构和功能=0.98009 auc_体液免疫的概念和过程=0.97861 auc_地球所处的宇宙环境=0.95496 auc_人体免疫系统在维持稳态中的作用=0.97991 auc_与细胞分裂有关的细胞器=0.97011 auc_公民道德与伦理常识=0.98381 auc_工业区位因素=0.91512 auc_地理=0.99838 [step/sec: 3.61]
# [2020-03-27 13:26:53,958] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.95486]
# [2020-03-27 13:29:31,868] [   TRAIN] - step 1200 / 2981: loss=0.82665 auc=0.95990 auc_宇宙中的地球=0.99540 auc_地球运动的基本形式=0.95534 auc_地球的内部圈层结构及特点=0.97855 auc_社会主义是中国人民的历史性选择=0.96109 auc_减数分裂的概念=0.97722 auc_基因的分离规律的实质及应用=0.95438 auc_组成细胞的化合物=0.96663 auc_基因工程的概念=0.98297 auc_人体水盐平衡调节=0.94845 auc_拉马克的进化学说=0.89332 auc_地球的外部圈层结构及特点=0.97904 auc_人口增长与人口问题=0.93908 auc_生产活动与地域联系=0.98112 auc_复等位基因=0.98566 auc_液泡的结构和功能=0.98546 auc_人口与城市=0.98889 auc_兴奋在神经纤维上的传导=0.97045 auc_郡县制=0.99268 auc_第三产业的兴起和“新经济”的出现=0.95208 auc_太阳对地球的影响=0.97657 auc_区域可持续发展=0.71941 auc_基因工程的原理及技术=0.98572 auc_社会主义市场经济的伦理要求=0.98559 auc_地球运动的地理意义=0.97639 auc_皇帝制度=0.99170 auc_遗传与进化=0.91419 auc_生物科学与社会=0.96842 auc_中央官制——三公九卿制=0.99272 auc_避孕的原理和方法=0.99495 auc_激素调节=0.94304 auc_近代史=0.96143 auc_生物工程技术=0.97146 auc_内环境的稳态=0.97594 auc_细胞有丝分裂不同时期的特点=0.94104 auc_清末民主革命风潮=0.94746 auc_高尔基体的结构和功能=0.98259 auc_伴性遗传=0.93221 auc_文艺的春天=0.96451 auc_神经调节和体液调节的比较=0.95558 auc_海峡两岸关系的发展=0.95886 auc_科学思维常识=0.88971 auc_遗传的细胞基础=0.99065 auc_劳动就业与守法经营=0.97539 auc_古代史=0.97889 auc_政治=0.99570 auc_农业区位因素=0.94257 auc_选官、用官制度的变化=0.98346 auc_生活中的法律常识=0.92190 auc_人工授精、试管婴儿等生殖技术=0.99484 auc_生物性污染=0.99424 auc_培养基与无菌技术=0.97489 auc_遗传的分子基础=0.99028 auc_内质网的结构和功能=0.98387 auc_基因的自由组合规律的实质及应用=0.96425 auc_生态系统的营养结构=0.89317 auc_“重农抑商”政策=0.99185 auc_免疫系统的功能=0.98018 auc_生命活动离不开细胞=0.93115 auc_蛋白质的合成=0.96007 auc_稳态与环境=0.98484 auc_不完全显性=0.94862 auc_夏商两代的政治制度=0.99209 auc_走进细胞=0.96072 auc_中心体的结构和功能=0.98355 auc_细胞的多样性和统一性=0.96969 auc_胚胎移植=0.96595 auc_群落的结构=0.91092 auc_免疫系统的组成=0.98194 auc_生物技术在其他方面的应用=0.98644 auc_经济学常识=0.94651 auc_生物=0.99948 auc_组成细胞的化学元素=0.96935 auc_核糖体的结构和功能=0.98393 auc_器官移植=0.96641 auc_时事政治=0.66621 auc_分子与细胞=0.97907 auc_血糖平衡的调节=0.93344 auc_减数分裂与有丝分裂的比较=0.98411 auc_垄断组织的出现=0.95570 auc_细胞大小与物质运输的关系=0.86614 auc_生物技术实践=0.96131 auc_科学社会主义常识=0.97368 auc_人体的体温调节=0.93967 auc_历史=0.99726 auc_现代生物技术专题=0.95068 auc_兴奋在神经元之间的传递=0.96919 auc_人口迁移与人口流动=0.95268 auc_现代史=0.96261 auc_地球与地图=0.91259 auc_溶酶体的结构和功能=0.98200 auc_体液免疫的概念和过程=0.98092 auc_地球所处的宇宙环境=0.96209 auc_人体免疫系统在维持稳态中的作用=0.98181 auc_与细胞分裂有关的细胞器=0.97286 auc_公民道德与伦理常识=0.98605 auc_工业区位因素=0.92680 auc_地理=0.99867 [step/sec: 1.27]
# [2020-03-27 13:29:31,869] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:30:13,893] [    EVAL] - [dev dataset evaluation result] loss=0.97121 auc=0.96303 auc_宇宙中的地球=0.99579 auc_地球运动的基本形式=0.95929 auc_地球的内部圈层结构及特点=0.98085 auc_社会主义是中国人民的历史性选择=0.96515 auc_减数分裂的概念=0.97862 auc_基因的分离规律的实质及应用=0.95610 auc_组成细胞的化合物=0.96874 auc_基因工程的概念=0.98412 auc_人体水盐平衡调节=0.95289 auc_拉马克的进化学说=0.89922 auc_地球的外部圈层结构及特点=0.98129 auc_人口增长与人口问题=0.94604 auc_生产活动与地域联系=0.98286 auc_复等位基因=0.98675 auc_液泡的结构和功能=0.98643 auc_人口与城市=0.99001 auc_兴奋在神经纤维上的传导=0.97339 auc_郡县制=0.99267 auc_第三产业的兴起和“新经济”的出现=0.95791 auc_太阳对地球的影响=0.97899 auc_区域可持续发展=0.74230 auc_基因工程的原理及技术=0.98655 auc_社会主义市场经济的伦理要求=0.98705 auc_地球运动的地理意义=0.97783 auc_皇帝制度=0.99178 auc_遗传与进化=0.91893 auc_生物科学与社会=0.96973 auc_中央官制——三公九卿制=0.99280 auc_避孕的原理和方法=0.99518 auc_激素调节=0.94827 auc_近代史=0.96351 auc_生物工程技术=0.97420 auc_内环境的稳态=0.97738 auc_细胞有丝分裂不同时期的特点=0.94458 auc_清末民主革命风潮=0.95239 auc_高尔基体的结构和功能=0.98379 auc_伴性遗传=0.93446 auc_文艺的春天=0.96830 auc_神经调节和体液调节的比较=0.95940 auc_海峡两岸关系的发展=0.96208 auc_科学思维常识=0.90205 auc_遗传的细胞基础=0.99122 auc_劳动就业与守法经营=0.97799 auc_古代史=0.97997 auc_政治=0.99619 auc_农业区位因素=0.94785 auc_选官、用官制度的变化=0.98472 auc_生活中的法律常识=0.92991 auc_人工授精、试管婴儿等生殖技术=0.99510 auc_生物性污染=0.99451 auc_培养基与无菌技术=0.97655 auc_遗传的分子基础=0.99081 auc_内质网的结构和功能=0.98488 auc_基因的自由组合规律的实质及应用=0.96621 auc_生态系统的营养结构=0.90152 auc_“重农抑商”政策=0.99195 auc_免疫系统的功能=0.98059 auc_生命活动离不开细胞=0.93515 auc_蛋白质的合成=0.96201 auc_稳态与环境=0.98579 auc_不完全显性=0.95293 auc_夏商两代的政治制度=0.99194 auc_走进细胞=0.96168 auc_中心体的结构和功能=0.98454 auc_细胞的多样性和统一性=0.97173 auc_胚胎移植=0.96917 auc_群落的结构=0.91915 auc_免疫系统的组成=0.98222 auc_生物技术在其他方面的应用=0.98729 auc_经济学常识=0.95148 auc_生物=0.99955 auc_组成细胞的化学元素=0.97112 auc_核糖体的结构和功能=0.98501 auc_器官移植=0.96969 auc_时事政治=0.70049 auc_分子与细胞=0.98059 auc_血糖平衡的调节=0.93950 auc_减数分裂与有丝分裂的比较=0.98490 auc_垄断组织的出现=0.96100 auc_细胞大小与物质运输的关系=0.87390 auc_生物技术实践=0.96361 auc_科学社会主义常识=0.97633 auc_人体的体温调节=0.94436 auc_历史=0.99754 auc_现代生物技术专题=0.95192 auc_兴奋在神经元之间的传递=0.97226 auc_人口迁移与人口流动=0.95711 auc_现代史=0.96426 auc_地球与地图=0.91947 auc_溶酶体的结构和功能=0.98324 auc_体液免疫的概念和过程=0.98138 auc_地球所处的宇宙环境=0.96604 auc_人体免疫系统在维持稳态中的作用=0.98211 auc_与细胞分裂有关的细胞器=0.97445 auc_公民道德与伦理常识=0.98723 auc_工业区位因素=0.93345 auc_地理=0.99884 [step/sec: 3.57]
# [2020-03-27 13:30:13,895] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.96303]
# [2020-03-27 13:32:51,810] [   TRAIN] - step 1400 / 2981: loss=0.87047 auc=0.96681 auc_宇宙中的地球=0.99638 auc_地球运动的基本形式=0.96343 auc_地球的内部圈层结构及特点=0.98352 auc_社会主义是中国人民的历史性选择=0.96988 auc_减数分裂的概念=0.98054 auc_基因的分离规律的实质及应用=0.95806 auc_组成细胞的化合物=0.97119 auc_基因工程的概念=0.98518 auc_人体水盐平衡调节=0.95748 auc_拉马克的进化学说=0.90503 auc_地球的外部圈层结构及特点=0.98398 auc_人口增长与人口问题=0.95294 auc_生产活动与地域联系=0.98518 auc_复等位基因=0.98673 auc_液泡的结构和功能=0.98779 auc_人口与城市=0.99131 auc_兴奋在神经纤维上的传导=0.97651 auc_郡县制=0.99382 auc_第三产业的兴起和“新经济”的出现=0.96406 auc_太阳对地球的影响=0.98195 auc_区域可持续发展=0.76838 auc_基因工程的原理及技术=0.98722 auc_社会主义市场经济的伦理要求=0.98883 auc_地球运动的地理意义=0.98007 auc_皇帝制度=0.99308 auc_遗传与进化=0.92519 auc_生物科学与社会=0.97129 auc_中央官制——三公九卿制=0.99392 auc_避孕的原理和方法=0.99572 auc_激素调节=0.95597 auc_近代史=0.96605 auc_生物工程技术=0.97620 auc_内环境的稳态=0.97982 auc_细胞有丝分裂不同时期的特点=0.94860 auc_清末民主革命风潮=0.95819 auc_高尔基体的结构和功能=0.98543 auc_伴性遗传=0.93841 auc_文艺的春天=0.97163 auc_神经调节和体液调节的比较=0.96379 auc_海峡两岸关系的发展=0.96744 auc_科学思维常识=0.91409 auc_遗传的细胞基础=0.99204 auc_劳动就业与守法经营=0.98029 auc_古代史=0.98179 auc_政治=0.99680 auc_农业区位因素=0.95384 auc_选官、用官制度的变化=0.98638 auc_生活中的法律常识=0.93907 auc_人工授精、试管婴儿等生殖技术=0.99568 auc_生物性污染=0.99517 auc_培养基与无菌技术=0.97839 auc_遗传的分子基础=0.99161 auc_内质网的结构和功能=0.98637 auc_基因的自由组合规律的实质及应用=0.96827 auc_生态系统的营养结构=0.91170 auc_“重农抑商”政策=0.99321 auc_免疫系统的功能=0.98269 auc_生命活动离不开细胞=0.94067 auc_蛋白质的合成=0.96575 auc_稳态与环境=0.98743 auc_不完全显性=0.95900 auc_夏商两代的政治制度=0.99320 auc_走进细胞=0.96440 auc_中心体的结构和功能=0.98605 auc_细胞的多样性和统一性=0.97402 auc_胚胎移植=0.97319 auc_群落的结构=0.92800 auc_免疫系统的组成=0.98419 auc_生物技术在其他方面的应用=0.98808 auc_经济学常识=0.95744 auc_生物=0.99962 auc_组成细胞的化学元素=0.97344 auc_核糖体的结构和功能=0.98647 auc_器官移植=0.97361 auc_时事政治=0.72994 auc_分子与细胞=0.98215 auc_血糖平衡的调节=0.94589 auc_减数分裂与有丝分裂的比较=0.98620 auc_垄断组织的出现=0.96671 auc_细胞大小与物质运输的关系=0.88551 auc_生物技术实践=0.96554 auc_科学社会主义常识=0.97964 auc_人体的体温调节=0.94981 auc_历史=0.99793 auc_现代生物技术专题=0.95410 auc_兴奋在神经元之间的传递=0.97541 auc_人口迁移与人口流动=0.96239 auc_现代史=0.96684 auc_地球与地图=0.92981 auc_溶酶体的结构和功能=0.98509 auc_体液免疫的概念和过程=0.98342 auc_地球所处的宇宙环境=0.97081 auc_人体免疫系统在维持稳态中的作用=0.98397 auc_与细胞分裂有关的细胞器=0.97731 auc_公民道德与伦理常识=0.98879 auc_工业区位因素=0.94218 auc_地理=0.99903 [step/sec: 1.28]
# [2020-03-27 13:32:51,812] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:33:33,332] [    EVAL] - [dev dataset evaluation result] loss=0.89005 auc=0.96903 auc_宇宙中的地球=0.99665 auc_地球运动的基本形式=0.96601 auc_地球的内部圈层结构及特点=0.98519 auc_社会主义是中国人民的历史性选择=0.97246 auc_减数分裂的概念=0.98067 auc_基因的分离规律的实质及应用=0.95925 auc_组成细胞的化合物=0.97300 auc_基因工程的概念=0.98599 auc_人体水盐平衡调节=0.96123 auc_拉马克的进化学说=0.90940 auc_地球的外部圈层结构及特点=0.98558 auc_人口增长与人口问题=0.95784 auc_生产活动与地域联系=0.98639 auc_复等位基因=0.98760 auc_液泡的结构和功能=0.98850 auc_人口与城市=0.99197 auc_兴奋在神经纤维上的传导=0.97842 auc_郡县制=0.99360 auc_第三产业的兴起和“新经济”的出现=0.96793 auc_太阳对地球的影响=0.98351 auc_区域可持续发展=0.78597 auc_基因工程的原理及技术=0.98788 auc_社会主义市场经济的伦理要求=0.98975 auc_地球运动的地理意义=0.98106 auc_皇帝制度=0.99291 auc_遗传与进化=0.92861 auc_生物科学与社会=0.97240 auc_中央官制——三公九卿制=0.99373 auc_避孕的原理和方法=0.99592 auc_激素调节=0.95931 auc_近代史=0.96763 auc_生物工程技术=0.97802 auc_内环境的稳态=0.98082 auc_细胞有丝分裂不同时期的特点=0.95093 auc_清末民主革命风潮=0.96164 auc_高尔基体的结构和功能=0.98637 auc_伴性遗传=0.94093 auc_文艺的春天=0.97423 auc_神经调节和体液调节的比较=0.96636 auc_海峡两岸关系的发展=0.96929 auc_科学思维常识=0.92193 auc_遗传的细胞基础=0.99255 auc_劳动就业与守法经营=0.98205 auc_古代史=0.98241 auc_政治=0.99707 auc_农业区位因素=0.95778 auc_选官、用官制度的变化=0.98698 auc_生活中的法律常识=0.94490 auc_人工授精、试管婴儿等生殖技术=0.99589 auc_生物性污染=0.99540 auc_培养基与无菌技术=0.97968 auc_遗传的分子基础=0.99207 auc_内质网的结构和功能=0.98719 auc_基因的自由组合规律的实质及应用=0.96981 auc_生态系统的营养结构=0.91694 auc_“重农抑商”政策=0.99302 auc_免疫系统的功能=0.98320 auc_生命活动离不开细胞=0.94375 auc_蛋白质的合成=0.96754 auc_稳态与环境=0.98801 auc_不完全显性=0.96203 auc_夏商两代的政治制度=0.99299 auc_走进细胞=0.96624 auc_中心体的结构和功能=0.98692 auc_细胞的多样性和统一性=0.97574 auc_胚胎移植=0.97547 auc_群落的结构=0.93363 auc_免疫系统的组成=0.98462 auc_生物技术在其他方面的应用=0.98879 auc_经济学常识=0.96119 auc_生物=0.99965 auc_组成细胞的化学元素=0.97504 auc_核糖体的结构和功能=0.98729 auc_器官移植=0.97582 auc_时事政治=0.75203 auc_分子与细胞=0.98326 auc_血糖平衡的调节=0.95068 auc_减数分裂与有丝分裂的比较=0.98664 auc_垄断组织的出现=0.97026 auc_细胞大小与物质运输的关系=0.89191 auc_生物技术实践=0.96712 auc_科学社会主义常识=0.98146 auc_人体的体温调节=0.95425 auc_历史=0.99810 auc_现代生物技术专题=0.95514 auc_兴奋在神经元之间的传递=0.97738 auc_人口迁移与人口流动=0.96524 auc_现代史=0.96798 auc_地球与地图=0.93416 auc_溶酶体的结构和功能=0.98607 auc_体液免疫的概念和过程=0.98402 auc_地球所处的宇宙环境=0.97331 auc_人体免疫系统在维持稳态中的作用=0.98448 auc_与细胞分裂有关的细胞器=0.97849 auc_公民道德与伦理常识=0.98953 auc_工业区位因素=0.94699 auc_地理=0.99915 [step/sec: 3.61]
# [2020-03-27 13:33:33,333] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.96903]
# [2020-03-27 13:36:10,265] [   TRAIN] - step 1600 / 2981: loss=0.82212 auc=0.97170 auc_宇宙中的地球=0.99699 auc_地球运动的基本形式=0.96894 auc_地球的内部圈层结构及特点=0.98694 auc_社会主义是中国人民的历史性选择=0.97618 auc_减数分裂的概念=0.98132 auc_基因的分离规律的实质及应用=0.96002 auc_组成细胞的化合物=0.97445 auc_基因工程的概念=0.98661 auc_人体水盐平衡调节=0.96489 auc_拉马克的进化学说=0.91552 auc_地球的外部圈层结构及特点=0.98739 auc_人口增长与人口问题=0.96236 auc_生产活动与地域联系=0.98782 auc_复等位基因=0.98821 auc_液泡的结构和功能=0.98950 auc_人口与城市=0.99280 auc_兴奋在神经纤维上的传导=0.98095 auc_郡县制=0.99422 auc_第三产业的兴起和“新经济”的出现=0.97155 auc_太阳对地球的影响=0.98531 auc_区域可持续发展=0.80136 auc_基因工程的原理及技术=0.98833 auc_社会主义市场经济的伦理要求=0.99079 auc_地球运动的地理意义=0.98281 auc_皇帝制度=0.99366 auc_遗传与进化=0.93276 auc_生物科学与社会=0.97380 auc_中央官制——三公九卿制=0.99443 auc_避孕的原理和方法=0.99623 auc_激素调节=0.96371 auc_近代史=0.96963 auc_生物工程技术=0.97904 auc_内环境的稳态=0.98254 auc_细胞有丝分裂不同时期的特点=0.95462 auc_清末民主革命风潮=0.96605 auc_高尔基体的结构和功能=0.98767 auc_伴性遗传=0.94429 auc_文艺的春天=0.97720 auc_神经调节和体液调节的比较=0.96885 auc_海峡两岸关系的发展=0.97243 auc_科学思维常识=0.93109 auc_遗传的细胞基础=0.99312 auc_劳动就业与守法经营=0.98367 auc_古代史=0.98366 auc_政治=0.99747 auc_农业区位因素=0.96231 auc_选官、用官制度的变化=0.98809 auc_生活中的法律常识=0.94959 auc_人工授精、试管婴儿等生殖技术=0.99623 auc_生物性污染=0.99578 auc_培养基与无菌技术=0.98133 auc_遗传的分子基础=0.99269 auc_内质网的结构和功能=0.98836 auc_基因的自由组合规律的实质及应用=0.97161 auc_生态系统的营养结构=0.92671 auc_“重农抑商”政策=0.99374 auc_免疫系统的功能=0.98445 auc_生命活动离不开细胞=0.94738 auc_蛋白质的合成=0.97060 auc_稳态与环境=0.98898 auc_不完全显性=0.96664 auc_夏商两代的政治制度=0.99374 auc_走进细胞=0.96824 auc_中心体的结构和功能=0.98809 auc_细胞的多样性和统一性=0.97726 auc_胚胎移植=0.97813 auc_群落的结构=0.93858 auc_免疫系统的组成=0.98580 auc_生物技术在其他方面的应用=0.98964 auc_经济学常识=0.96525 auc_生物=0.99970 auc_组成细胞的化学元素=0.97647 auc_核糖体的结构和功能=0.98844 auc_器官移植=0.97843 auc_时事政治=0.77623 auc_分子与细胞=0.98454 auc_血糖平衡的调节=0.95570 auc_减数分裂与有丝分裂的比较=0.98732 auc_垄断组织的出现=0.97365 auc_细胞大小与物质运输的关系=0.90099 auc_生物技术实践=0.96802 auc_科学社会主义常识=0.98390 auc_人体的体温调节=0.95868 auc_历史=0.99837 auc_现代生物技术专题=0.95687 auc_兴奋在神经元之间的传递=0.97997 auc_人口迁移与人口流动=0.96918 auc_现代史=0.97003 auc_地球与地图=0.94113 auc_溶酶体的结构和功能=0.98728 auc_体液免疫的概念和过程=0.98539 auc_地球所处的宇宙环境=0.97686 auc_人体免疫系统在维持稳态中的作用=0.98563 auc_与细胞分裂有关的细胞器=0.98017 auc_公民道德与伦理常识=0.99044 auc_工业区位因素=0.95186 auc_地理=0.99927 [step/sec: 1.29]
# [2020-03-27 13:36:10,266] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:36:51,684] [    EVAL] - [dev dataset evaluation result] loss=0.83937 auc=0.97336 auc_宇宙中的地球=0.99715 auc_地球运动的基本形式=0.97079 auc_地球的内部圈层结构及特点=0.98822 auc_社会主义是中国人民的历史性选择=0.97800 auc_减数分裂的概念=0.98166 auc_基因的分离规律的实质及应用=0.96077 auc_组成细胞的化合物=0.97599 auc_基因工程的概念=0.98736 auc_人体水盐平衡调节=0.96765 auc_拉马克的进化学说=0.91899 auc_地球的外部圈层结构及特点=0.98862 auc_人口增长与人口问题=0.96571 auc_生产活动与地域联系=0.98836 auc_复等位基因=0.98896 auc_液泡的结构和功能=0.98998 auc_人口与城市=0.99332 auc_兴奋在神经纤维上的传导=0.98224 auc_郡县制=0.99397 auc_第三产业的兴起和“新经济”的出现=0.97412 auc_太阳对地球的影响=0.98625 auc_区域可持续发展=0.81508 auc_基因工程的原理及技术=0.98895 auc_社会主义市场经济的伦理要求=0.99144 auc_地球运动的地理意义=0.98337 auc_皇帝制度=0.99349 auc_遗传与进化=0.93556 auc_生物科学与社会=0.97468 auc_中央官制——三公九卿制=0.99429 auc_避孕的原理和方法=0.99642 auc_激素调节=0.96638 auc_近代史=0.97081 auc_生物工程技术=0.98055 auc_内环境的稳态=0.98316 auc_细胞有丝分裂不同时期的特点=0.95682 auc_清末民主革命风潮=0.96833 auc_高尔基体的结构和功能=0.98831 auc_伴性遗传=0.94633 auc_文艺的春天=0.97892 auc_神经调节和体液调节的比较=0.97075 auc_海峡两岸关系的发展=0.97372 auc_科学思维常识=0.93701 auc_遗传的细胞基础=0.99343 auc_劳动就业与守法经营=0.98498 auc_古代史=0.98431 auc_政治=0.99766 auc_农业区位因素=0.96520 auc_选官、用官制度的变化=0.98848 auc_生活中的法律常识=0.95400 auc_人工授精、试管婴儿等生殖技术=0.99641 auc_生物性污染=0.99600 auc_培养基与无菌技术=0.98228 auc_遗传的分子基础=0.99293 auc_内质网的结构和功能=0.98895 auc_基因的自由组合规律的实质及应用=0.97304 auc_生态系统的营养结构=0.93111 auc_“重农抑商”政策=0.99361 auc_免疫系统的功能=0.98480 auc_生命活动离不开细胞=0.95009 auc_蛋白质的合成=0.97195 auc_稳态与环境=0.98931 auc_不完全显性=0.96865 auc_夏商两代的政治制度=0.99355 auc_走进细胞=0.96949 auc_中心体的结构和功能=0.98871 auc_细胞的多样性和统一性=0.97855 auc_胚胎移植=0.97966 auc_群落的结构=0.94237 auc_免疫系统的组成=0.98614 auc_生物技术在其他方面的应用=0.99015 auc_经济学常识=0.96783 auc_生物=0.99973 auc_组成细胞的化学元素=0.97782 auc_核糖体的结构和功能=0.98903 auc_器官移植=0.97997 auc_时事政治=0.79360 auc_分子与细胞=0.98527 auc_血糖平衡的调节=0.95915 auc_减数分裂与有丝分裂的比较=0.98798 auc_垄断组织的出现=0.97601 auc_细胞大小与物质运输的关系=0.90625 auc_生物技术实践=0.96932 auc_科学社会主义常识=0.98507 auc_人体的体温调节=0.96192 auc_历史=0.99844 auc_现代生物技术专题=0.95777 auc_兴奋在神经元之间的传递=0.98132 auc_人口迁移与人口流动=0.97146 auc_现代史=0.97078 auc_地球与地图=0.94379 auc_溶酶体的结构和功能=0.98799 auc_体液免疫的概念和过程=0.98580 auc_地球所处的宇宙环境=0.97847 auc_人体免疫系统在维持稳态中的作用=0.98597 auc_与细胞分裂有关的细胞器=0.98108 auc_公民道德与伦理常识=0.99109 auc_工业区位因素=0.95518 auc_地理=0.99933 [step/sec: 3.62]
# [2020-03-27 13:36:51,685] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.97336]
# [2020-03-27 13:39:28,003] [   TRAIN] - step 1800 / 2981: loss=0.68160 auc=0.97537 auc_宇宙中的地球=0.99738 auc_地球运动的基本形式=0.97260 auc_地球的内部圈层结构及特点=0.98977 auc_社会主义是中国人民的历史性选择=0.98068 auc_减数分裂的概念=0.98214 auc_基因的分离规律的实质及应用=0.96162 auc_组成细胞的化合物=0.97763 auc_基因工程的概念=0.98864 auc_人体水盐平衡调节=0.97010 auc_拉马克的进化学说=0.92214 auc_地球的外部圈层结构及特点=0.99010 auc_人口增长与人口问题=0.96922 auc_生产活动与地域联系=0.98934 auc_复等位基因=0.99004 auc_液泡的结构和功能=0.99085 auc_人口与城市=0.99390 auc_兴奋在神经纤维上的传导=0.98351 auc_郡县制=0.99466 auc_第三产业的兴起和“新经济”的出现=0.97684 auc_太阳对地球的影响=0.98748 auc_区域可持续发展=0.82859 auc_基因工程的原理及技术=0.99002 auc_社会主义市场经济的伦理要求=0.99216 auc_地球运动的地理意义=0.98466 auc_皇帝制度=0.99424 auc_遗传与进化=0.93893 auc_生物科学与社会=0.97560 auc_中央官制——三公九卿制=0.99495 auc_避孕的原理和方法=0.99660 auc_激素调节=0.96880 auc_近代史=0.97217 auc_生物工程技术=0.98165 auc_内环境的稳态=0.98457 auc_细胞有丝分裂不同时期的特点=0.95847 auc_清末民主革命风潮=0.97084 auc_高尔基体的结构和功能=0.98936 auc_伴性遗传=0.94854 auc_文艺的春天=0.98103 auc_神经调节和体液调节的比较=0.97222 auc_海峡两岸关系的发展=0.97640 auc_科学思维常识=0.94366 auc_遗传的细胞基础=0.99374 auc_劳动就业与守法经营=0.98593 auc_古代史=0.98542 auc_政治=0.99788 auc_农业区位因素=0.96815 auc_选官、用官制度的变化=0.98916 auc_生活中的法律常识=0.95764 auc_人工授精、试管婴儿等生殖技术=0.99661 auc_生物性污染=0.99623 auc_培养基与无菌技术=0.98381 auc_遗传的分子基础=0.99319 auc_内质网的结构和功能=0.98993 auc_基因的自由组合规律的实质及应用=0.97414 auc_生态系统的营养结构=0.93822 auc_“重农抑商”政策=0.99435 auc_免疫系统的功能=0.98611 auc_生命活动离不开细胞=0.95282 auc_蛋白质的合成=0.97388 auc_稳态与环境=0.99000 auc_不完全显性=0.97139 auc_夏商两代的政治制度=0.99429 auc_走进细胞=0.97139 auc_中心体的结构和功能=0.98974 auc_细胞的多样性和统一性=0.97993 auc_胚胎移植=0.98154 auc_群落的结构=0.94773 auc_免疫系统的组成=0.98742 auc_生物技术在其他方面的应用=0.99109 auc_经济学常识=0.97062 auc_生物=0.99976 auc_组成细胞的化学元素=0.97942 auc_核糖体的结构和功能=0.98997 auc_器官移植=0.98180 auc_时事政治=0.81241 auc_分子与细胞=0.98630 auc_血糖平衡的调节=0.96247 auc_减数分裂与有丝分裂的比较=0.98857 auc_垄断组织的出现=0.97852 auc_细胞大小与物质运输的关系=0.91266 auc_生物技术实践=0.97050 auc_科学社会主义常识=0.98695 auc_人体的体温调节=0.96477 auc_历史=0.99862 auc_现代生物技术专题=0.95906 auc_兴奋在神经元之间的传递=0.98263 auc_人口迁移与人口流动=0.97452 auc_现代史=0.97223 auc_地球与地图=0.94814 auc_溶酶体的结构和功能=0.98905 auc_体液免疫的概念和过程=0.98707 auc_地球所处的宇宙环境=0.98073 auc_人体免疫系统在维持稳态中的作用=0.98729 auc_与细胞分裂有关的细胞器=0.98209 auc_公民道德与伦理常识=0.99182 auc_工业区位因素=0.95917 auc_地理=0.99941 [step/sec: 1.26]
# [2020-03-27 13:39:28,004] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:40:09,373] [    EVAL] - [dev dataset evaluation result] loss=0.80611 auc=0.97656 auc_宇宙中的地球=0.99748 auc_地球运动的基本形式=0.97402 auc_地球的内部圈层结构及特点=0.99066 auc_社会主义是中国人民的历史性选择=0.98193 auc_减数分裂的概念=0.98283 auc_基因的分离规律的实质及应用=0.96252 auc_组成细胞的化合物=0.97856 auc_基因工程的概念=0.98913 auc_人体水盐平衡调节=0.97219 auc_拉马克的进化学说=0.92469 auc_地球的外部圈层结构及特点=0.99096 auc_人口增长与人口问题=0.97178 auc_生产活动与地域联系=0.98980 auc_复等位基因=0.99054 auc_液泡的结构和功能=0.99086 auc_人口与城市=0.99422 auc_兴奋在神经纤维上的传导=0.98452 auc_郡县制=0.99458 auc_第三产业的兴起和“新经济”的出现=0.97884 auc_太阳对地球的影响=0.98828 auc_区域可持续发展=0.83899 auc_基因工程的原理及技术=0.99045 auc_社会主义市场经济的伦理要求=0.99263 auc_地球运动的地理意义=0.98500 auc_皇帝制度=0.99417 auc_遗传与进化=0.94106 auc_生物科学与社会=0.97629 auc_中央官制——三公九卿制=0.99487 auc_避孕的原理和方法=0.99675 auc_激素调节=0.97085 auc_近代史=0.97309 auc_生物工程技术=0.98267 auc_内环境的稳态=0.98512 auc_细胞有丝分裂不同时期的特点=0.95989 auc_清末民主革命风潮=0.97260 auc_高尔基体的结构和功能=0.98938 auc_伴性遗传=0.95006 auc_文艺的春天=0.98234 auc_神经调节和体液调节的比较=0.97373 auc_海峡两岸关系的发展=0.97732 auc_科学思维常识=0.94798 auc_遗传的细胞基础=0.99405 auc_劳动就业与守法经营=0.98684 auc_古代史=0.98586 auc_政治=0.99804 auc_农业区位因素=0.96970 auc_选官、用官制度的变化=0.98964 auc_生活中的法律常识=0.96101 auc_人工授精、试管婴儿等生殖技术=0.99676 auc_生物性污染=0.99639 auc_培养基与无菌技术=0.98444 auc_遗传的分子基础=0.99345 auc_内质网的结构和功能=0.98990 auc_基因的自由组合规律的实质及应用=0.97538 auc_生态系统的营养结构=0.94056 auc_“重农抑商”政策=0.99428 auc_免疫系统的功能=0.98652 auc_生命活动离不开细胞=0.95481 auc_蛋白质的合成=0.97463 auc_稳态与环境=0.99022 auc_不完全显性=0.97308 auc_夏商两代的政治制度=0.99416 auc_走进细胞=0.97172 auc_中心体的结构和功能=0.98974 auc_细胞的多样性和统一性=0.98075 auc_胚胎移植=0.98260 auc_群落的结构=0.95097 auc_免疫系统的组成=0.98778 auc_生物技术在其他方面的应用=0.99142 auc_经济学常识=0.97263 auc_生物=0.99978 auc_组成细胞的化学元素=0.98022 auc_核糖体的结构和功能=0.98998 auc_器官移植=0.98283 auc_时事政治=0.82570 auc_分子与细胞=0.98684 auc_血糖平衡的调节=0.96510 auc_减数分裂与有丝分裂的比较=0.98923 auc_垄断组织的出现=0.98039 auc_细胞大小与物质运输的关系=0.91610 auc_生物技术实践=0.97142 auc_科学社会主义常识=0.98780 auc_人体的体温调节=0.96726 auc_历史=0.99868 auc_现代生物技术专题=0.95964 auc_兴奋在神经元之间的传递=0.98369 auc_人口迁移与人口流动=0.97640 auc_现代史=0.97303 auc_地球与地图=0.94910 auc_溶酶体的结构和功能=0.98906 auc_体液免疫的概念和过程=0.98750 auc_地球所处的宇宙环境=0.98187 auc_人体免疫系统在维持稳态中的作用=0.98767 auc_与细胞分裂有关的细胞器=0.98229 auc_公民道德与伦理常识=0.99231 auc_工业区位因素=0.96162 auc_地理=0.99947 [step/sec: 3.63]
# [2020-03-27 13:40:09,374] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.97656]
# [2020-03-27 13:42:47,011] [   TRAIN] - step 2000 / 2981: loss=0.67170 auc=0.97825 auc_宇宙中的地球=0.99772 auc_地球运动的基本形式=0.97554 auc_地球的内部圈层结构及特点=0.99171 auc_社会主义是中国人民的历史性选择=0.98382 auc_减数分裂的概念=0.98366 auc_基因的分离规律的实质及应用=0.96371 auc_组成细胞的化合物=0.97992 auc_基因工程的概念=0.98985 auc_人体水盐平衡调节=0.97424 auc_拉马克的进化学说=0.92851 auc_地球的外部圈层结构及特点=0.99196 auc_人口增长与人口问题=0.97443 auc_生产活动与地域联系=0.99067 auc_复等位基因=0.99110 auc_液泡的结构和功能=0.99173 auc_人口与城市=0.99470 auc_兴奋在神经纤维上的传导=0.98581 auc_郡县制=0.99511 auc_第三产业的兴起和“新经济”的出现=0.98108 auc_太阳对地球的影响=0.98948 auc_区域可持续发展=0.84765 auc_基因工程的原理及技术=0.99103 auc_社会主义市场经济的伦理要求=0.99327 auc_地球运动的地理意义=0.98608 auc_皇帝制度=0.99475 auc_遗传与进化=0.94383 auc_生物科学与社会=0.97718 auc_中央官制——三公九卿制=0.99538 auc_避孕的原理和方法=0.99702 auc_激素调节=0.97336 auc_近代史=0.97430 auc_生物工程技术=0.98391 auc_内环境的稳态=0.98633 auc_细胞有丝分裂不同时期的特点=0.96192 auc_清末民主革命风潮=0.97485 auc_高尔基体的结构和功能=0.99039 auc_伴性遗传=0.95269 auc_文艺的春天=0.98392 auc_神经调节和体液调节的比较=0.97498 auc_海峡两岸关系的发展=0.97932 auc_科学思维常识=0.95305 auc_遗传的细胞基础=0.99449 auc_劳动就业与守法经营=0.98786 auc_古代史=0.98664 auc_政治=0.99825 auc_农业区位因素=0.97230 auc_选官、用官制度的变化=0.99018 auc_生活中的法律常识=0.96411 auc_人工授精、试管婴儿等生殖技术=0.99704 auc_生物性污染=0.99671 auc_培养基与无菌技术=0.98531 auc_遗传的分子基础=0.99390 auc_内质网的结构和功能=0.99086 auc_基因的自由组合规律的实质及应用=0.97671 auc_生态系统的营养结构=0.94649 auc_“重农抑商”政策=0.99485 auc_免疫系统的功能=0.98775 auc_生命活动离不开细胞=0.95771 auc_蛋白质的合成=0.97641 auc_稳态与环境=0.99083 auc_不完全显性=0.97528 auc_夏商两代的政治制度=0.99475 auc_走进细胞=0.97380 auc_中心体的结构和功能=0.99071 auc_细胞的多样性和统一性=0.98200 auc_胚胎移植=0.98385 auc_群落的结构=0.95490 auc_免疫系统的组成=0.98890 auc_生物技术在其他方面的应用=0.99197 auc_经济学常识=0.97495 auc_生物=0.99981 auc_组成细胞的化学元素=0.98148 auc_核糖体的结构和功能=0.99095 auc_器官移植=0.98410 auc_时事政治=0.84031 auc_分子与细胞=0.98773 auc_血糖平衡的调节=0.96783 auc_减数分裂与有丝分裂的比较=0.99005 auc_垄断组织的出现=0.98248 auc_细胞大小与物质运输的关系=0.92215 auc_生物技术实践=0.97234 auc_科学社会主义常识=0.98897 auc_人体的体温调节=0.96987 auc_历史=0.99882 auc_现代生物技术专题=0.96083 auc_兴奋在神经元之间的传递=0.98506 auc_人口迁移与人口流动=0.97851 auc_现代史=0.97417 auc_地球与地图=0.95363 auc_溶酶体的结构和功能=0.99015 auc_体液免疫的概念和过程=0.98863 auc_地球所处的宇宙环境=0.98339 auc_人体免疫系统在维持稳态中的作用=0.98878 auc_与细胞分裂有关的细胞器=0.98358 auc_公民道德与伦理常识=0.99292 auc_工业区位因素=0.96469 auc_地理=0.99953 [step/sec: 1.29]
# [2020-03-27 13:42:47,013] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:43:28,346] [    EVAL] - [dev dataset evaluation result] loss=0.78261 auc=0.97916 auc_宇宙中的地球=0.99781 auc_地球运动的基本形式=0.97672 auc_地球的内部圈层结构及特点=0.99236 auc_社会主义是中国人民的历史性选择=0.98451 auc_减数分裂的概念=0.98402 auc_基因的分离规律的实质及应用=0.96438 auc_组成细胞的化合物=0.98064 auc_基因工程的概念=0.99024 auc_人体水盐平衡调节=0.97566 auc_拉马克的进化学说=0.93070 auc_地球的外部圈层结构及特点=0.99260 auc_人口增长与人口问题=0.97628 auc_生产活动与地域联系=0.99095 auc_复等位基因=0.99150 auc_液泡的结构和功能=0.99176 auc_人口与城市=0.99493 auc_兴奋在神经纤维上的传导=0.98655 auc_郡县制=0.99503 auc_第三产业的兴起和“新经济”的出现=0.98251 auc_太阳对地球的影响=0.99007 auc_区域可持续发展=0.85589 auc_基因工程的原理及技术=0.99136 auc_社会主义市场经济的伦理要求=0.99361 auc_地球运动的地理意义=0.98639 auc_皇帝制度=0.99469 auc_遗传与进化=0.94538 auc_生物科学与社会=0.97775 auc_中央官制——三公九卿制=0.99532 auc_避孕的原理和方法=0.99712 auc_激素调节=0.97489 auc_近代史=0.97498 auc_生物工程技术=0.98474 auc_内环境的稳态=0.98665 auc_细胞有丝分裂不同时期的特点=0.96346 auc_清末民主革命风潮=0.97605 auc_高尔基体的结构和功能=0.99044 auc_伴性遗传=0.95389 auc_文艺的春天=0.98490 auc_神经调节和体液调节的比较=0.97625 auc_海峡两岸关系的发展=0.97996 auc_科学思维常识=0.95635 auc_遗传的细胞基础=0.99470 auc_劳动就业与守法经营=0.98864 auc_古代史=0.98705 auc_政治=0.99831 auc_农业区位因素=0.97343 auc_选官、用官制度的变化=0.99058 auc_生活中的法律常识=0.96672 auc_人工授精、试管婴儿等生殖技术=0.99714 auc_生物性污染=0.99682 auc_培养基与无菌技术=0.98587 auc_遗传的分子基础=0.99407 auc_内质网的结构和功能=0.99088 auc_基因的自由组合规律的实质及应用=0.97789 auc_生态系统的营养结构=0.94855 auc_“重农抑商”政策=0.99482 auc_免疫系统的功能=0.98788 auc_生命活动离不开细胞=0.95935 auc_蛋白质的合成=0.97671 auc_稳态与环境=0.99099 auc_不完全显性=0.97635 auc_夏商两代的政治制度=0.99467 auc_走进细胞=0.97426 auc_中心体的结构和功能=0.99073 auc_细胞的多样性和统一性=0.98287 auc_胚胎移植=0.98493 auc_群落的结构=0.95723 auc_免疫系统的组成=0.98901 auc_生物技术在其他方面的应用=0.99222 auc_经济学常识=0.97651 auc_生物=0.99982 auc_组成细胞的化学元素=0.98207 auc_核糖体的结构和功能=0.99098 auc_器官移植=0.98517 auc_时事政治=0.85072 auc_分子与细胞=0.98813 auc_血糖平衡的调节=0.96970 auc_减数分裂与有丝分裂的比较=0.99053 auc_垄断组织的出现=0.98379 auc_细胞大小与物质运输的关系=0.92541 auc_生物技术实践=0.97304 auc_科学社会主义常识=0.98915 auc_人体的体温调节=0.97169 auc_历史=0.99884 auc_现代生物技术专题=0.96129 auc_兴奋在神经元之间的传递=0.98585 auc_人口迁移与人口流动=0.97987 auc_现代史=0.97475 auc_地球与地图=0.95431 auc_溶酶体的结构和功能=0.99021 auc_体液免疫的概念和过程=0.98879 auc_地球所处的宇宙环境=0.98431 auc_人体免疫系统在维持稳态中的作用=0.98890 auc_与细胞分裂有关的细胞器=0.98377 auc_公民道德与伦理常识=0.99333 auc_工业区位因素=0.96647 auc_地理=0.99957 [step/sec: 3.63]
# [2020-03-27 13:43:28,348] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.97916]
# ...
# [2020-03-27 13:50:04,864] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.98290]
# [2020-03-27 13:52:42,047] [   TRAIN] - step 2600 / 2981: loss=0.56198 auc=0.98387 auc_宇宙中的地球=0.99831 auc_地球运动的基本形式=0.98192 auc_地球的内部圈层结构及特点=0.99516 auc_社会主义是中国人民的历史性选择=0.98921 auc_减数分裂的概念=0.98603 auc_基因的分离规律的实质及应用=0.96835 auc_组成细胞的化合物=0.98460 auc_基因工程的概念=0.99228 auc_人体水盐平衡调节=0.98226 auc_拉马克的进化学说=0.94020 auc_地球的外部圈层结构及特点=0.99530 auc_人口增长与人口问题=0.98357 auc_生产活动与地域联系=0.99311 auc_复等位基因=0.99342 auc_液泡的结构和功能=0.99350 auc_人口与城市=0.99614 auc_兴奋在神经纤维上的传导=0.98964 auc_郡县制=0.99555 auc_第三产业的兴起和“新经济”的出现=0.98819 auc_太阳对地球的影响=0.99276 auc_区域可持续发展=0.89262 auc_基因工程的原理及技术=0.99314 auc_社会主义市场经济的伦理要求=0.99552 auc_地球运动的地理意义=0.98901 auc_皇帝制度=0.99530 auc_遗传与进化=0.95363 auc_生物科学与社会=0.98051 auc_中央官制——三公九卿制=0.99586 auc_避孕的原理和方法=0.99775 auc_激素调节=0.98236 auc_近代史=0.97822 auc_生物工程技术=0.98832 auc_内环境的稳态=0.98907 auc_细胞有丝分裂不同时期的特点=0.97007 auc_清末民主革命风潮=0.98261 auc_高尔基体的结构和功能=0.99250 auc_伴性遗传=0.96262 auc_文艺的春天=0.98891 auc_神经调节和体液调节的比较=0.98069 auc_海峡两岸关系的发展=0.98501 auc_科学思维常识=0.96979 auc_遗传的细胞基础=0.99577 auc_劳动就业与守法经营=0.99160 auc_古代史=0.98908 auc_政治=0.99884 auc_农业区位因素=0.98071 auc_选官、用官制度的变化=0.99232 auc_生活中的法律常识=0.97608 auc_人工授精、试管婴儿等生殖技术=0.99779 auc_生物性污染=0.99752 auc_培养基与无菌技术=0.98911 auc_遗传的分子基础=0.99510 auc_内质网的结构和功能=0.99284 auc_基因的自由组合规律的实质及应用=0.98267 auc_生态系统的营养结构=0.96154 auc_“重农抑商”政策=0.99546 auc_免疫系统的功能=0.98987 auc_生命活动离不开细胞=0.96690 auc_蛋白质的合成=0.98150 auc_稳态与环境=0.99272 auc_不完全显性=0.98322 auc_夏商两代的政治制度=0.99522 auc_走进细胞=0.97905 auc_中心体的结构和功能=0.99268 auc_细胞的多样性和统一性=0.98679 auc_胚胎移植=0.98940 auc_群落的结构=0.96909 auc_免疫系统的组成=0.99091 auc_生物技术在其他方面的应用=0.99391 auc_经济学常识=0.98325 auc_生物=0.99989 auc_组成细胞的化学元素=0.98568 auc_核糖体的结构和功能=0.99298 auc_器官移植=0.98959 auc_时事政治=0.89279 auc_分子与细胞=0.99032 auc_血糖平衡的调节=0.97823 auc_减数分裂与有丝分裂的比较=0.99261 auc_垄断组织的出现=0.98905 auc_细胞大小与物质运输的关系=0.94311 auc_生物技术实践=0.97566 auc_科学社会主义常识=0.99231 auc_人体的体温调节=0.97931 auc_历史=0.99914 auc_现代生物技术专题=0.96464 auc_兴奋在神经元之间的传递=0.98921 auc_人口迁移与人口流动=0.98571 auc_现代史=0.97847 auc_地球与地图=0.96303 auc_溶酶体的结构和功能=0.99243 auc_体液免疫的概念和过程=0.99070 auc_地球所处的宇宙环境=0.98886 auc_人体免疫系统在维持稳态中的作用=0.99069 auc_与细胞分裂有关的细胞器=0.98689 auc_公民道德与伦理常识=0.99524 auc_工业区位因素=0.97528 auc_地理=0.99973 [step/sec: 1.29]
# [2020-03-27 13:52:42,049] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:53:23,593] [    EVAL] - [dev dataset evaluation result] loss=0.72003 auc=0.98435 auc_宇宙中的地球=0.99832 auc_地球运动的基本形式=0.98255 auc_地球的内部圈层结构及特点=0.99545 auc_社会主义是中国人民的历史性选择=0.98949 auc_减数分裂的概念=0.98628 auc_基因的分离规律的实质及应用=0.96896 auc_组成细胞的化合物=0.98499 auc_基因工程的概念=0.99250 auc_人体水盐平衡调节=0.98315 auc_拉马克的进化学说=0.94139 auc_地球的外部圈层结构及特点=0.99559 auc_人口增长与人口问题=0.98447 auc_生产活动与地域联系=0.99330 auc_复等位基因=0.99365 auc_液泡的结构和功能=0.99344 auc_人口与城市=0.99621 auc_兴奋在神经纤维上的传导=0.99004 auc_郡县制=0.99551 auc_第三产业的兴起和“新经济”的出现=0.98886 auc_太阳对地球的影响=0.99290 auc_区域可持续发展=0.89724 auc_基因工程的原理及技术=0.99332 auc_社会主义市场经济的伦理要求=0.99565 auc_地球运动的地理意义=0.98905 auc_皇帝制度=0.99527 auc_遗传与进化=0.95445 auc_生物科学与社会=0.98079 auc_中央官制——三公九卿制=0.99580 auc_避孕的原理和方法=0.99780 auc_激素调节=0.98293 auc_近代史=0.97856 auc_生物工程技术=0.98879 auc_内环境的稳态=0.98921 auc_细胞有丝分裂不同时期的特点=0.97097 auc_清末民主革命风潮=0.98332 auc_高尔基体的结构和功能=0.99244 auc_伴性遗传=0.96373 auc_文艺的春天=0.98933 auc_神经调节和体液调节的比较=0.98134 auc_海峡两岸关系的发展=0.98522 auc_科学思维常识=0.97149 auc_遗传的细胞基础=0.99587 auc_劳动就业与守法经营=0.99198 auc_古代史=0.98926 auc_政治=0.99887 auc_农业区位因素=0.98149 auc_选官、用官制度的变化=0.99256 auc_生活中的法律常识=0.97745 auc_人工授精、试管婴儿等生殖技术=0.99784 auc_生物性污染=0.99758 auc_培养基与无菌技术=0.98942 auc_遗传的分子基础=0.99516 auc_内质网的结构和功能=0.99279 auc_基因的自由组合规律的实质及应用=0.98340 auc_生态系统的营养结构=0.96277 auc_“重农抑商”政策=0.99543 auc_免疫系统的功能=0.98991 auc_生命活动离不开细胞=0.96784 auc_蛋白质的合成=0.98199 auc_稳态与环境=0.99275 auc_不完全显性=0.98378 auc_夏商两代的政治制度=0.99515 auc_走进细胞=0.97921 auc_中心体的结构和功能=0.99262 auc_细胞的多样性和统一性=0.98712 auc_胚胎移植=0.98996 auc_群落的结构=0.97046 auc_免疫系统的组成=0.99094 auc_生物技术在其他方面的应用=0.99404 auc_经济学常识=0.98395 auc_生物=0.99989 auc_组成细胞的化学元素=0.98602 auc_核糖体的结构和功能=0.99295 auc_器官移植=0.99014 auc_时事政治=0.89822 auc_分子与细胞=0.99055 auc_血糖平衡的调节=0.97933 auc_减数分裂与有丝分裂的比较=0.99291 auc_垄断组织的出现=0.98967 auc_细胞大小与物质运输的关系=0.94482 auc_生物技术实践=0.97604 auc_科学社会主义常识=0.99240 auc_人体的体温调节=0.98033 auc_历史=0.99915 auc_现代生物技术专题=0.96479 auc_兴奋在神经元之间的传递=0.98961 auc_人口迁移与人口流动=0.98641 auc_现代史=0.97872 auc_地球与地图=0.96291 auc_溶酶体的结构和功能=0.99240 auc_体液免疫的概念和过程=0.99076 auc_地球所处的宇宙环境=0.98924 auc_人体免疫系统在维持稳态中的作用=0.99074 auc_与细胞分裂有关的细胞器=0.98692 auc_公民道德与伦理常识=0.99541 auc_工业区位因素=0.97622 auc_地理=0.99974 [step/sec: 3.61]
# [2020-03-27 13:53:23,594] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.98435]
# [2020-03-27 13:56:00,272] [   TRAIN] - step 2800 / 2981: loss=0.56000 auc=0.98518 auc_宇宙中的地球=0.99842 auc_地球运动的基本形式=0.98328 auc_地球的内部圈层结构及特点=0.99580 auc_社会主义是中国人民的历史性选择=0.99035 auc_减数分裂的概念=0.98666 auc_基因的分离规律的实质及应用=0.96983 auc_组成细胞的化合物=0.98578 auc_基因工程的概念=0.99296 auc_人体水盐平衡调节=0.98427 auc_拉马克的进化学说=0.94359 auc_地球的外部圈层结构及特点=0.99592 auc_人口增长与人口问题=0.98534 auc_生产活动与地域联系=0.99373 auc_复等位基因=0.99402 auc_液泡的结构和功能=0.99394 auc_人口与城市=0.99642 auc_兴奋在神经纤维上的传导=0.99064 auc_郡县制=0.99582 auc_第三产业的兴起和“新经济”的出现=0.98960 auc_太阳对地球的影响=0.99343 auc_区域可持续发展=0.90337 auc_基因工程的原理及技术=0.99373 auc_社会主义市场经济的伦理要求=0.99592 auc_地球运动的地理意义=0.98960 auc_皇帝制度=0.99559 auc_遗传与进化=0.95617 auc_生物科学与社会=0.98130 auc_中央官制——三公九卿制=0.99610 auc_避孕的原理和方法=0.99793 auc_激素调节=0.98398 auc_近代史=0.97922 auc_生物工程技术=0.98933 auc_内环境的稳态=0.98961 auc_细胞有丝分裂不同时期的特点=0.97214 auc_清末民主革命风潮=0.98433 auc_高尔基体的结构和功能=0.99301 auc_伴性遗传=0.96509 auc_文艺的春天=0.98999 auc_神经调节和体液调节的比较=0.98206 auc_海峡两岸关系的发展=0.98612 auc_科学思维常识=0.97338 auc_遗传的细胞基础=0.99609 auc_劳动就业与守法经营=0.99236 auc_古代史=0.98977 auc_政治=0.99896 auc_农业区位因素=0.98261 auc_选官、用官制度的变化=0.99292 auc_生活中的法律常识=0.97886 auc_人工授精、试管婴儿等生殖技术=0.99797 auc_生物性污染=0.99773 auc_培养基与无菌技术=0.98980 auc_遗传的分子基础=0.99537 auc_内质网的结构和功能=0.99334 auc_基因的自由组合规律的实质及应用=0.98412 auc_生态系统的营养结构=0.96510 auc_“重农抑商”政策=0.99575 auc_免疫系统的功能=0.99028 auc_生命活动离不开细胞=0.96916 auc_蛋白质的合成=0.98300 auc_稳态与环境=0.99315 auc_不完全显性=0.98446 auc_夏商两代的政治制度=0.99549 auc_走进细胞=0.98034 auc_中心体的结构和功能=0.99318 auc_细胞的多样性和统一性=0.98782 auc_胚胎移植=0.99053 auc_群落的结构=0.97244 auc_免疫系统的组成=0.99136 auc_生物技术在其他方面的应用=0.99431 auc_经济学常识=0.98511 auc_生物=0.99990 auc_组成细胞的化学元素=0.98672 auc_核糖体的结构和功能=0.99349 auc_器官移植=0.99066 auc_时事政治=0.90486 auc_分子与细胞=0.99103 auc_血糖平衡的调节=0.98074 auc_减数分裂与有丝分裂的比较=0.99324 auc_垄断组织的出现=0.99034 auc_细胞大小与物质运输的关系=0.94766 auc_生物技术实践=0.97637 auc_科学社会主义常识=0.99303 auc_人体的体温调节=0.98167 auc_历史=0.99921 auc_现代生物技术专题=0.96548 auc_兴奋在神经元之间的传递=0.99023 auc_人口迁移与人口流动=0.98716 auc_现代史=0.97949 auc_地球与地图=0.96528 auc_溶酶体的结构和功能=0.99298 auc_体液免疫的概念和过程=0.99118 auc_地球所处的宇宙环境=0.99011 auc_人体免疫系统在维持稳态中的作用=0.99109 auc_与细胞分裂有关的细胞器=0.98775 auc_公民道德与伦理常识=0.99570 auc_工业区位因素=0.97792 auc_地理=0.99976 [step/sec: 1.29]
# [2020-03-27 13:56:00,274] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:56:41,698] [    EVAL] - [dev dataset evaluation result] loss=0.70720 auc=0.98557 auc_宇宙中的地球=0.99844 auc_地球运动的基本形式=0.98373 auc_地球的内部圈层结构及特点=0.99604 auc_社会主义是中国人民的历史性选择=0.99059 auc_减数分裂的概念=0.98689 auc_基因的分离规律的实质及应用=0.97036 auc_组成细胞的化合物=0.98614 auc_基因工程的概念=0.99313 auc_人体水盐平衡调节=0.98499 auc_拉马克的进化学说=0.94462 auc_地球的外部圈层结构及特点=0.99616 auc_人口增长与人口问题=0.98609 auc_生产活动与地域联系=0.99384 auc_复等位基因=0.99420 auc_液泡的结构和功能=0.99389 auc_人口与城市=0.99651 auc_兴奋在神经纤维上的传导=0.99094 auc_郡县制=0.99576 auc_第三产业的兴起和“新经济”的出现=0.99015 auc_太阳对地球的影响=0.99354 auc_区域可持续发展=0.90713 auc_基因工程的原理及技术=0.99388 auc_社会主义市场经济的伦理要求=0.99604 auc_地球运动的地理意义=0.98966 auc_皇帝制度=0.99552 auc_遗传与进化=0.95691 auc_生物科学与社会=0.98156 auc_中央官制——三公九卿制=0.99602 auc_避孕的原理和方法=0.99798 auc_激素调节=0.98446 auc_近代史=0.97945 auc_生物工程技术=0.98974 auc_内环境的稳态=0.98973 auc_细胞有丝分裂不同时期的特点=0.97284 auc_清末民主革命风潮=0.98489 auc_高尔基体的结构和功能=0.99297 auc_伴性遗传=0.96595 auc_文艺的春天=0.99035 auc_神经调节和体液调节的比较=0.98259 auc_海峡两岸关系的发展=0.98624 auc_科学思维常识=0.97478 auc_遗传的细胞基础=0.99619 auc_劳动就业与守法经营=0.99269 auc_古代史=0.98990 auc_政治=0.99899 auc_农业区位因素=0.98317 auc_选官、用官制度的变化=0.99311 auc_生活中的法律常识=0.97999 auc_人工授精、试管婴儿等生殖技术=0.99802 auc_生物性污染=0.99778 auc_培养基与无菌技术=0.99005 auc_遗传的分子基础=0.99544 auc_内质网的结构和功能=0.99329 auc_基因的自由组合规律的实质及应用=0.98471 auc_生态系统的营养结构=0.96625 auc_“重农抑商”政策=0.99569 auc_免疫系统的功能=0.99032 auc_生命活动离不开细胞=0.96988 auc_蛋白质的合成=0.98338 auc_稳态与环境=0.99317 auc_不完全显性=0.98495 auc_夏商两代的政治制度=0.99540 auc_走进细胞=0.98055 auc_中心体的结构和功能=0.99312 auc_细胞的多样性和统一性=0.98809 auc_胚胎移植=0.99099 auc_群落的结构=0.97349 auc_免疫系统的组成=0.99139 auc_生物技术在其他方面的应用=0.99440 auc_经济学常识=0.98569 auc_生物=0.99991 auc_组成细胞的化学元素=0.98704 auc_核糖体的结构和功能=0.99346 auc_器官移植=0.99113 auc_时事政治=0.90939 auc_分子与细胞=0.99122 auc_血糖平衡的调节=0.98163 auc_减数分裂与有丝分裂的比较=0.99349 auc_垄断组织的出现=0.99085 auc_细胞大小与物质运输的关系=0.94902 auc_生物技术实践=0.97670 auc_科学社会主义常识=0.99315 auc_人体的体温调节=0.98251 auc_历史=0.99921 auc_现代生物技术专题=0.96560 auc_兴奋在神经元之间的传递=0.99054 auc_人口迁移与人口流动=0.98774 auc_现代史=0.97970 auc_地球与地图=0.96527 auc_溶酶体的结构和功能=0.99295 auc_体液免疫的概念和过程=0.99123 auc_地球所处的宇宙环境=0.99038 auc_人体免疫系统在维持稳态中的作用=0.99114 auc_与细胞分裂有关的细胞器=0.98772 auc_公民道德与伦理常识=0.99585 auc_工业区位因素=0.97863 auc_地理=0.99978 [step/sec: 3.62]
# [2020-03-27 13:56:41,699] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.98557]
# [2020-03-27 13:59:06,181] [    INFO] - Evaluation on dev dataset start
# [2020-03-27 13:59:47,930] [    EVAL] - [dev dataset evaluation result] loss=0.70420 auc=0.98650 auc_宇宙中的地球=0.99853 auc_地球运动的基本形式=0.98486 auc_地球的内部圈层结构及特点=0.99653 auc_社会主义是中国人民的历史性选择=0.99129 auc_减数分裂的概念=0.98734 auc_基因的分离规律的实质及应用=0.97149 auc_组成细胞的化合物=0.98700 auc_基因工程的概念=0.99360 auc_人体水盐平衡调节=0.98613 auc_拉马克的进化学说=0.94653 auc_地球的外部圈层结构及特点=0.99663 auc_人口增长与人口问题=0.98750 auc_生产活动与地域联系=0.99426 auc_复等位基因=0.99459 auc_液泡的结构和功能=0.99421 auc_人口与城市=0.99680 auc_兴奋在神经纤维上的传导=0.99158 auc_郡县制=0.99593 auc_第三产业的兴起和“新经济”的出现=0.99119 auc_太阳对地球的影响=0.99393 auc_区域可持续发展=0.91392 auc_基因工程的原理及技术=0.99427 auc_社会主义市场经济的伦理要求=0.99638 auc_地球运动的地理意义=0.99013 auc_皇帝制度=0.99572 auc_遗传与进化=0.95852 auc_生物科学与社会=0.98218 auc_中央官制——三公九卿制=0.99618 auc_避孕的原理和方法=0.99813 auc_激素调节=0.98542 auc_近代史=0.98018 auc_生物工程技术=0.99059 auc_内环境的稳态=0.99029 auc_细胞有丝分裂不同时期的特点=0.97416 auc_清末民主革命风潮=0.98617 auc_高尔基体的结构和功能=0.99335 auc_伴性遗传=0.96799 auc_文艺的春天=0.99123 auc_神经调节和体液调节的比较=0.98371 auc_海峡两岸关系的发展=0.98719 auc_科学思维常识=0.97736 auc_遗传的细胞基础=0.99643 auc_劳动就业与守法经营=0.99337 auc_古代史=0.99033 auc_政治=0.99907 auc_农业区位因素=0.98441 auc_选官、用官制度的变化=0.99353 auc_生活中的法律常识=0.98213 auc_人工授精、试管婴儿等生殖技术=0.99816 auc_生物性污染=0.99795 auc_培养基与无菌技术=0.99074 auc_遗传的分子基础=0.99567 auc_内质网的结构和功能=0.99365 auc_基因的自由组合规律的实质及应用=0.98575 auc_生态系统的营养结构=0.96902 auc_“重农抑商”政策=0.99588 auc_免疫系统的功能=0.99084 auc_生命活动离不开细胞=0.97152 auc_蛋白质的合成=0.98454 auc_稳态与环境=0.99349 auc_不完全显性=0.98620 auc_夏商两代的政治制度=0.99557 auc_走进细胞=0.98160 auc_中心体的结构和功能=0.99346 auc_细胞的多样性和统一性=0.98882 auc_胚胎移植=0.99187 auc_群落的结构=0.97539 auc_免疫系统的组成=0.99185 auc_生物技术在其他方面的应用=0.99472 auc_经济学常识=0.98706 auc_生物=0.99992 auc_组成细胞的化学元素=0.98785 auc_核糖体的结构和功能=0.99383 auc_器官移植=0.99202 auc_时事政治=0.91744 auc_分子与细胞=0.99164 auc_血糖平衡的调节=0.98308 auc_减数分裂与有丝分裂的比较=0.99402 auc_垄断组织的出现=0.99183 auc_细胞大小与物质运输的关系=0.95242 auc_生物技术实践=0.97739 auc_科学社会主义常识=0.99358 auc_人体的体温调节=0.98386 auc_历史=0.99926 auc_现代生物技术专题=0.96621 auc_兴奋在神经元之间的传递=0.99119 auc_人口迁移与人口流动=0.98899 auc_现代史=0.98045 auc_地球与地图=0.96674 auc_溶酶体的结构和功能=0.99335 auc_体液免疫的概念和过程=0.99173 auc_地球所处的宇宙环境=0.99124 auc_人体免疫系统在维持稳态中的作用=0.99163 auc_与细胞分裂有关的细胞器=0.98827 auc_公民道德与伦理常识=0.99621 auc_工业区位因素=0.98009 auc_地理=0.99981 [step/sec: 3.60]
# [2020-03-27 13:59:47,932] [    EVAL] - best model saved to ckpt_20200327130347/best_model [best auc=0.98650]
# [2020-03-27 13:59:49,890] [    INFO] - Load the best model from ckpt_20200327130347/best_model
# [2020-03-27 13:59:50,751] [    INFO] - Evaluation on test dataset start
# [2020-03-27 14:00:43,472] [    EVAL] - [test dataset evaluation result] loss=0.73106 auc=0.98686 auc_宇宙中的地球=0.99847 auc_地球运动的基本形式=0.98507 auc_地球的内部圈层结构及特点=0.99645 auc_社会主义是中国人民的历史性选择=0.99154 auc_减数分裂的概念=0.98763 auc_基因的分离规律的实质及应用=0.97202 auc_组成细胞的化合物=0.98740 auc_基因工程的概念=0.99373 auc_人体水盐平衡调节=0.98667 auc_拉马克的进化学说=0.94777 auc_地球的外部圈层结构及特点=0.99653 auc_人口增长与人口问题=0.98825 auc_生产活动与地域联系=0.99408 auc_复等位基因=0.99472 auc_液泡的结构和功能=0.99412 auc_人口与城市=0.99673 auc_兴奋在神经纤维上的传导=0.99188 auc_郡县制=0.99601 auc_第三产业的兴起和“新经济”的出现=0.99156 auc_太阳对地球的影响=0.99424 auc_区域可持续发展=0.91770 auc_基因工程的原理及技术=0.99440 auc_社会主义市场经济的伦理要求=0.99647 auc_地球运动的地理意义=0.99025 auc_皇帝制度=0.99580 auc_遗传与进化=0.95927 auc_生物科学与社会=0.98234 auc_中央官制——三公九卿制=0.99619 auc_避孕的原理和方法=0.99813 auc_激素调节=0.98610 auc_近代史=0.98045 auc_生物工程技术=0.99098 auc_内环境的稳态=0.99056 auc_细胞有丝分裂不同时期的特点=0.97480 auc_清末民主革命风潮=0.98675 auc_高尔基体的结构和功能=0.99325 auc_伴性遗传=0.96899 auc_文艺的春天=0.99144 auc_神经调节和体液调节的比较=0.98437 auc_海峡两岸关系的发展=0.98747 auc_科学思维常识=0.97778 auc_遗传的细胞基础=0.99644 auc_劳动就业与守法经营=0.99353 auc_古代史=0.99057 auc_政治=0.99910 auc_农业区位因素=0.98505 auc_选官、用官制度的变化=0.99351 auc_生活中的法律常识=0.98295 auc_人工授精、试管婴儿等生殖技术=0.99817 auc_生物性污染=0.99796 auc_培养基与无菌技术=0.99100 auc_遗传的分子基础=0.99564 auc_内质网的结构和功能=0.99353 auc_基因的自由组合规律的实质及应用=0.98619 auc_生态系统的营养结构=0.97055 auc_“重农抑商”政策=0.99594 auc_免疫系统的功能=0.99095 auc_生命活动离不开细胞=0.97226 auc_蛋白质的合成=0.98520 auc_稳态与环境=0.99347 auc_不完全显性=0.98688 auc_夏商两代的政治制度=0.99563 auc_走进细胞=0.98190 auc_中心体的结构和功能=0.99337 auc_细胞的多样性和统一性=0.98820 auc_胚胎移植=0.99212 auc_群落的结构=0.97667 auc_免疫系统的组成=0.99197 auc_生物技术在其他方面的应用=0.99479 auc_经济学常识=0.98760 auc_生物=0.99992 auc_组成细胞的化学元素=0.98818 auc_核糖体的结构和功能=0.99373 auc_器官移植=0.99227 auc_时事政治=0.92251 auc_分子与细胞=0.99167 auc_血糖平衡的调节=0.98380 auc_减数分裂与有丝分裂的比较=0.99421 auc_垄断组织的出现=0.99217 auc_细胞大小与物质运输的关系=0.95408 auc_生物技术实践=0.97732 auc_科学社会主义常识=0.99368 auc_人体的体温调节=0.98452 auc_历史=0.99930 auc_现代生物技术专题=0.96654 auc_兴奋在神经元之间的传递=0.99150 auc_人口迁移与人口流动=0.98953 auc_现代史=0.98079 auc_地球与地图=0.96731 auc_溶酶体的结构和功能=0.99328 auc_体液免疫的概念和过程=0.99182 auc_地球所处的宇宙环境=0.99167 auc_人体免疫系统在维持稳态中的作用=0.99177 auc_与细胞分裂有关的细胞器=0.98789 auc_公民道德与伦理常识=0.99636 auc_工业区位因素=0.98055 auc_地理=0.99981 [step/sec: 3.55]
# [2020-03-27 14:00:43,479] [    INFO] - Saving model checkpoint to ckpt_20200327130347/step_2985
# [2020-03-27 14:00:46,216] [    INFO] - PaddleHub finetune finished.
# [2020-03-27 14:00:46,302] [    INFO] - The best model has been loaded
# [2020-03-27 14:00:46,304] [    INFO] - PaddleHub predict start
# share_vars_from is set, scope is ignored.
# [2020-03-27 14:01:22,280] [    INFO] - PaddleHub predict finished.
# f1 micro:0.9102579532234123
# f1 samples:0.8318882086938779
# f1 macro:0.9065945223360182
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)
